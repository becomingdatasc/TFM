# %% [markdown]
# # Sentiment Analysis: Optimized Classifiers

# %%
# Importing Libraries 
import pandas as pd
import nltk
import re
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split  
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score, recall_score
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier
import preprocessor as p
from nltk.stem import WordNetLemmatizer                      
from pywsd.utils import lemmatize_sentence
from sklearn import svm
import emoji    
import matplotlib.pyplot as plt
import numpy as np
import itertools
from sklearn import tree
from sklearn import svm
# Out:
# Warming up PyWSD (takes ~10 secs)... took 6.965258836746216 secs.

# %%
# The dataset ('Tweets.csv) is imported and saved in the variable 'data'
# Only the text of the tweets is saved in the variable 'tweets'. 
# A sample is printed to verify that they have been loaded correctly.

data= pd.read_csv('Tweets.csv')
tweets = data['text']
tweets.head()
# Out:
# 0                  @VirginAmerica What @dhepburn said.
# 1    @VirginAmerica plus you've added commercials t...
# 2    @VirginAmerica I didn't today... Must mean I n...
# 3    @VirginAmerica it's really aggressive to blast...
# 4    @VirginAmerica and it's a really big bad thing...
# Name: text, dtype: object

# %%
# The sentiment expressed with the "neutral" token is replaced by the "positive" token. 
# We get a more equal amount of tweets labeled with positive and negative polarity.
# The result is a series of pandas stored in the variable 'target' that contains the polarity of each of the tweets
# of the main dataset ('data').

data.replace({'airline_sentiment' : 'neutral'}, 'positive', inplace=True)
target = data['airline_sentiment']
print(data['airline_sentiment'])
# Out:
# 0        positive
# 1        positive
# 2        positive
# 3        negative
# 4        negative
# 5        negative
# 6        positive
# 7        positive
# 8        positive
# 9        positive
# 10       positive
# 11       positive
# 12       positive
# 13       positive
# 14       positive
# 15       negative
# 16       positive
# 17       negative
# 18       positive
# 19       positive
# 20       negative
# 21       positive
# 22       positive
# 23       positive
# 24       negative
# 25       negative
# 26       negative
# 27       positive
# 28       negative
# 29       positive
#            ...
# 14610    negative
# 14611    positive
# 14612    negative
# 14613    negative
# 14614    negative
# 14615    negative
# 14616    negative
# 14617    positive
# 14618    negative
# 14619    positive
# 14620    negative
# 14621    negative
# 14622    negative
# 14623    positive
# 14624    negative
# 14625    positive
# 14626    negative
# 14627    negative
# 14628    positive
# 14629    negative
# 14630    positive
# 14631    negative
# 14632    positive
# 14633    negative
# 14634    negative
# 14635    positive
# 14636    negative
# 14637    positive
# 14638    negative
# 14639    positive
# Name: airline_sentiment, Length: 14640, dtype: object

# %%
# Check that the variable 'tweets' and the variable 'target' have the same length, to corraborate that
# there have been no errors in the previous processes.

print('Número de tweets: ' + ' ' + str(len(tweets)),'\nNúmero de targets:' + ' ' + str(len(target)))
# Out:
# Número de tweets:  14640
# Número de targets: 14640

# %%
print(target.value_counts())
# Out:
# negative    9178
# positive    5462
# Name: airline_sentiment, dtype: int64

# %%
Index=[1, 2]
print(target.value_counts())
plt.bar(Index, target.value_counts(),color=['r','g'])
plt.xticks(Index, ['NEGATIVE', 'POSITIVE'], rotation = 5)
plt.ylabel('NUM. TWEETS')
plt.xlabel('SENTIMENTS BY TWEETS')
# Out:
# negative    9178
# positive    5462
# Name: airline_sentiment, dtype: int64
# Text(0.5,0,'SENTIMENTS BY TWEETS')

# %%
Tweets_df_gr=data.groupby(["airline",target]).size().unstack()
print(Tweets_df_gr)
# Out:
# airline_sentiment  negative  positive
# airline
# American               1960       799
# Delta                   955      1267
# Southwest              1186      1234
# US Airways             2263       650
# United                 2633      1189
# Virgin America          181       323

# %%
Tweets_df_gr=data.groupby(["airline",target]).size().unstack()
Tweets_df_gr=Tweets_df_gr.div(Tweets_df_gr.sum(axis=1),axis='index')
print(Tweets_df_gr)
# Out:
# airline_sentiment  negative  positive
# airline
# American           0.710402  0.289598
# Delta              0.429793  0.570207
# Southwest          0.490083  0.509917
# US Airways         0.776862  0.223138
# United             0.688906  0.311094
# Virgin America     0.359127  0.640873

# %%
Tweets_df_gr=data.groupby(["airline",target]).size().unstack()
Tweets_df_gr=Tweets_df_gr.div(Tweets_df_gr.sum(axis=1),axis='index')
print(Tweets_df_gr)
ax=Tweets_df_gr.plot.bar(stacked=True)
plt.ylabel('percentage tweets')
plt.xticks(rotation=15)
plt.legend(bbox_to_anchor=(-0.5, 1), loc=3, borderaxespad=-3)
# Out:
# airline_sentiment  negative  positive
# airline
# American           0.710402  0.289598
# Delta              0.429793  0.570207
# Southwest          0.490083  0.509917
# US Airways         0.776862  0.223138
# United             0.688906  0.311094
# Virgin America     0.359127  0.640873

# %%
# It is pre-processed -the mentions, hashtags and links are deleted- each of the tweets saved in the variable
# 'tweets' with tweet-preprocessor 5.0.
# The tweets are saved in a list ('tweets_preprocessed'), which contains all the tweets without hashtags, 
# mentions or links.

tweets_preprocessed = []
for tweet in tweets:
    p.set_options(p.OPT.MENTION, p.OPT.HASHTAG, p.OPT.URL)
    tweets_preprocessed.append(p.clean(tweet))

# %%
# The list containing each of the pre-processed tweets -the mentions, hashtags and links- is printed to verify
# that the previous process has been performed correctly.

tweets_preprocessed
# Out:
# ['What said.',
#  "plus you've added commercials to the experience... tacky.",
#  "I didn't today... Must mean I need to take another trip!",
#  'it\'s really aggressive to blast obnoxious "entertainment" in your guests\' faces &amp; they have little recourse',
#  "and it's a really big bad thing about it",
#  "seriously would pay $30 a flight for seats that didn't have this playing. it's really the only bad thing about flying VA",
#  'yes, nearly every time I fly VX this “ear worm” won’t go away :)',
#  'Really missed a prime opportunity for Men Without Hats parody, there.',
#  "Well, I didn't…but NOW I DO! :-D",
#  "it was amazing, and arrived an hour early. You're too good to me.",
#  'did you know that suicide is the second leading cause of death among teens 10-24',
#  'I &lt;3 pretty graphics. so much better than minimal iconography. :D',
#  "This is such a great deal! Already thinking about my 2nd trip to &amp; I haven't even gone on my 1st trip yet! ;p",
#  "I'm flying your skies again! U take all the away from travel",
#  'Thanks!',
#  'SFO-PDX schedule is still MIA.',
#  "So excited for my first cross country flight LAX to MCO I've heard nothing but great things about Virgin America.",
#  "I flew from NYC to SFO last week and couldn't fully sit in my seat due to two large gentleman on either side of me. HELP!",
#  'I ❤️ flying . ☺️👍',
#  'you know what would be amazingly awesome? BOS-FLL PLEASE!!!!!!! I want to fly with only you.',
#  'why are your first fares in May over three times more than other carriers when all seats are available to select???',
#  'I love this graphic.',
#  'I love the hipster innovation. You are a feel good brand.',
#  'will you be making BOS&gt;LAS non stop permanently anytime soon?',
#  'you guys messed up my seating.. I reserved seating with my friends and you guys gave my seat away ... 😡 I want free internet',
#  "status match program. I applied and it's been three weeks. Called and emailed with no response.",
#  "What happened 2 ur vegan food options?! At least say on ur site so i know I won't be able 2 eat anything for next 6 hrs",
#  "do you miss me? Don't worry we'll be together very soon.",
#  "amazing to me that we can't get any cold air from the vents.",
#  'LAX to EWR - Middle seat on a red eye. Such a noob maneuver.',
#  "hi! I just bked a cool birthday trip with you, but i can't add my elevate no. cause i entered my middle name during Flight Booking Problems 😢",
#  'Are the hours of operation for the Club at SFO that are posted online current?',
#  'help, left expensive headphones on flight 89 IAD to LAX today. Seat 2A. No one answering L&amp;F number at LAX!',
#  'awaiting my return phone call, just would prefer to use your online self-service option :(',
#  'this is great news! America could start flights to Hawaii by end of year via',
#  'Nice RT : Vibe with the moodlight from takeoff to touchdown.',
#  'Moodlighting is the only way to fly! Best experience EVER! Cool and calming. 💜✈',
#  'Done and done! Best airline around, hands down!',
#  'when can I book my flight to Hawaii??',
#  'Your chat support is not working on your site:',
#  'View of downtown Los Angeles, the Hollywood Sign, and beyond that rain in the mountains!',
#  "Hey, first time flyer next week - excited! But I'm having a hard time getting my flights added to my Elevate account. Help?",
#  'plz help me win my bid upgrade for my flight 2/27 LAX---&gt;SEA!!! 🍷👍💺✈️',
#  "I have an unused ticket but moved to a new city where you don't fly. How can I fly with you before it expires?",
#  'are flights leaving Dallas for Seattle on time Feb 24?',
#  "I'm for a good reason: you rock!!",
#  'DREAM',
#  'wow this just blew my mind',
#  'After last night ! I think agree',
#  'All were entertaining',
#  'Is flight 769 on it\'s way? Was supposed to take off 30 minutes ago. Website still shows "On Time" not "In Flight". Thanks.',
#  'Julie Andrews all the way though was very impressive! NO to',
#  'wish you flew out of Atlanta... Soon?',
#  'Julie Andrews. Hands down.',
#  'Will flights be leaving Dallas for LA on February 24th?',
#  "hi! i'm so excited about your $99 LGA-&gt;DAL deal- but i've been trying 2 book since last week &amp; the page never loads. thx!",
#  'you know it. Need it on my spotify stat',
#  "I'm Lady Gaga!!! She is amazing! 😊",
#  '- Carrie!',
#  'New marketing song? let us know what you think?',
#  "Julie Andrews first but Lady Gaga wow'd me last night. Carrie? Meh.",
#  "I called a 3-4 weeks ago about adding 3 flights from 2014 to my Elevate...they still haven't shown up...help!",
#  'all are great , but I have to go with 😍👌',
#  'Sorry, Mary Martin had it first!',
#  "love all three but you really can't beat the classics!",
#  'Flight 0736 DAL to DCA 2/24 2:10pm. Tried to check in could not. Status please.',
#  'heyyyy guyyyys.. been trying to get through for an hour. can someone call me please? :/',
#  "Hi, Virgin! I'm on hold for 40-50 minutes -- are there any earlier flights from LA to NYC tonight; earlier than 11:50pm?",
#  'Congrats on winning the award for Best Deals from an Airline (US)',
#  'everything was fine until you lost my bag',
#  'Need to change reservation. Have Virgin credit card. Do I need to modify on phone to waive change fee? Or can I do online?',
#  'I emailed your customer service team. Let me know if you need the tracking number.',
#  'hi I just booked a flight but need to add baggage, how can I do this?',
#  'your airline is awesome but your lax loft needs to step up its game. $40 for dirty tables and floors?',
#  "not worried, it's been a great ride in a new plane with great crew. All airlines should be like this.",
#  'awesome. I flew yall Sat morning. Any way we can correct my bill ?',
#  'Or watch some of the best student films in the country at 35,000 feet!',
#  'first time flying you all. do you have a different rate/policy for media Bags? Thanks',
#  'what is going on with customer service? Is there anyway to speak to a human asap? Thank you.',
#  'what happened to Doom?!',
#  "why can't you supp the biz traveler like and have customer service like",
#  "I've applied more then once to be a member of the crew team...Im 100% interested. -G",
#  "you're the best!! Whenever I (begrudgingly) use any other airline I'm delayed and Late Flight :(",
#  'I have no interesting flying with you after this. I will Cancelled Flight my next four flights I planned.',
#  'it was a disappointing experience which will be shared with every business traveler I meet.',
#  'I’m having trouble adding this flight my wife booked to my Elevate account. Help?',
#  "Can't bring up my reservation online using Flight Booking Problems code",
#  "Random Q: what's the distribution of elevate avatars? I bet that kitty has a disproportionate share",
#  'I &lt;3 Flying VA But Life happens and I am trying to my trip JPERHI Can you help.VA home page will not let me ?',
#  'Why is the site down? When will it be back up?',
#  '"You down with RNP?" "Yeah you know me!"',
#  'hi, i did not get points on my elevate account for my most recent flight, how do i add the flight and points to my account?',
#  'I like the TV and interesting video . Just disappointed in Cancelled Flightled flight when other flights went out to jfk on Saturday .',
#  'just landed in LAX, an hour after I should of been here. Your no Late Flight bag check is not business travel friendly',
#  'why is flight 345 redirected?',
#  "Is it me, or is your website down? BTW, your new website isn't a great user experience. Time for another redesign.",
#  "I can't check in or add a bag. Your website isn't working. I've tried both desktop and mobile",
#  '- Let 2 scanned in passengers leave the plane than told someone to remove their bag from 1st class bin?',
#  "What is your phone number. I can't find who to call about a flight reservation.",
#  'is anyone doing anything there today? Website is useless and no one is answering the phone.',
#  'trying to add my boy Prince to my ressie. SF this Thursday from LAX',
#  'why must a traveler miss a flight to Late Flight check a bag? I missed my morning appointments and you lost my business.',
#  'check out new music',
#  "how's a direct flight FLL-&gt;SFO have unexpected layover in Vegas 4 fuel yet peeps next to me bought for Vegas flight.",
#  'your no Late Flight bag check just lost you my business. I missed flight and AM apt. Three other people on flight had same exp.',
#  "- amazing customer service, again! 💕💕 RaeAnn in SF - she's the best!",
#  'called your service line and was hung up on. This is awesome.',
#  "your site is tripping. I'm trying to check in and I'm getting the plain text version. I am reluctant to enter any card info.",
#  'I was scheduled for SFO 2 DAL flight 714 today. Changed to 24th due weather. Looks like flight still on?',
#  'has getaway deals through May, from $59 one-way. Lots of cool cities',
#  'has getaway deals through May, from $59 one-way. Lots of cool cities',
#  'has getaway deals through May, from $59 one-way. Lots of cool cities',
#  'has getaway deals through May, from $59 one-way. Lots of cool cities',
#  'Have a great week 🌞✈',
#  'come back to already. We need you to take us out of this horrible cold.',
#  'should I be concerned that I am about to fly on a plane that needs to be delayed due to a "tech stop"?',
#  'is the best airline I have flown on.Easy to change your reservation,helpful representatives &amp; a comfortable flying experience',
#  'and again! Another rep kicked butt! Naelah represents your team so beautifully!! Thank you!!!',
#  'your beautiful front-end design is down right now; but it was cool to still book my ticket b/c all your back-end was secure.',
#  'Love the team running Gate E9 at LAS tonight. Waited for a delayed flight, and they kept things entertaining',
#  "Use another browser! 2015 &amp; a brand with a reputation built on tech response doesn't have a cross-browser compatible website?",
#  'And now the flight Flight Booking Problems site is totally down. Folks, what is the problem?',
#  'I like the customer service but a 40 min delay just for connecting passengers seems too long. VA370',
#  'thanks to your outstanding NYC-JFK crew who moved mountains to get me home to San Francisco tonight!',
#  "you have the absolute best team and customer service ever. Every time I fly with you I'm delighted. Thank you!",
#  'Do you provide complimentary upgrades to first class, if there are available seats?',
#  'i need to change my flight thats scheduled in 9 hours and 120 min wait time on phone. Im calling intern. Help!!',
#  'completely awesome experience last month BOS-LAS nonstop. Thanks for such an awesome flight and depart time.',
#  'How can I watch the on my JFK-&gt;SFO flight?',
#  'is flight 882 Cancelled Flightled and what do I do if it is?',
#  'you are failing your customers because your check in process does not link to TSA pre-check.',
#  'us too! Terrible airline! Just gave us a hotel hotline number and said sorry',
#  'has flight number 276 from SFO to Cabo San Lucas arrived yet?',
#  'your assistance yesterday when u Cancelled Flightled our flight was to give us a hotel hotline Shame on you!',
#  'Another delayed flight?',
#  'I need to register a service dog for a first class ticket from SFO &gt; Dulles. The phone queue is an hour or longer. Pls advise',
#  'you ROCK for making it so I can watch on my flight!!',
#  ', dropped a track on you...',
#  'always!!! Xoxo',
#  "why can't we book seats on your flights when we buy them or even during check in? Creates so much anxiety!",
#  "You'd think paying an extra $100 bucks RT for luggage might afford you hiring an extra hand at",
#  'best customer service rep in the world! takes the cake!!!',
#  'Can you find us a flt out of LAX that is sooner than midnight on Monday? That would be great customer service 😃',
#  "please provide status for flight 769. I cant imagine it's on time as the Web indicates dude to weather here and/or Dallas",
#  'you have amazing staff &amp; super helpful as I just ran the they have spoiled me with comfort!!!',
#  'I paid the premium to fly you across the country, you Cancelled Flight my flight and offer no check fee or upgrade love? Sad face :(',
#  "question: is it not possible to book a seat for an infant under 2? It's not giving me the option but we want a seat for him.",
#  "Always have it together!!! You're welcome! RT : You're so welcome.",
#  "home to in' back to !",
#  ". I don't understand why you need a DM to give me an answer on if you have a damaged luggage policy.",
#  ". does that mean you don't have a policy for destroyed luggage?",
#  'is there special assistance if I travel alone w/2 kids and 1 infant? Priority boarding?',
#  'thank you for checking in. tickets are purchased and customer is happy ;-)',
#  'is your website ever coming back online?',
#  '- Is Flight 713 from Love Field to SFO definitely Cancelled Flightled for Monday, February 23?',
#  'Is flight 0769 out of LGA to DFW on time?',
#  'my drivers license is expired by a little over a month. Can I fly Friday morning using my expired license?',
#  'having problems Flight Booking Problems on the web site. keeps giving me an error and to contact by phone. phone is 30 minute wait.',
#  'How do I reschedule my Cancelled Flightled flights online? The change button is greyed out!',
#  'I rang, but there is a wait for 35 minutes!! I can book the same ticket through a vendor, fix your site',
#  'got a flight (we were told) for 4:50 today..,checked my email and its for 4;50 TOMORROW. This is unacceptable.',
#  "our flight into lga was Cancelled Flighted. We're stuck in Dallas. I called to reschedule, told I could get a flight for today...(1/2)",
#  "why don't any of the pairings include red wine?! Only white is offered :(",
#  'is the website down?',
#  '- Your site seems a little wonked right now. May want to have a look. Tried on two browsers. No CSS?',
#  "I'm disappointed that the agent at the designated silver status check in line closed to assist all pasengers",
#  'Plans to Include Austin to its Dallas Route - TopNews Arab',
#  'Is it normal to receive no reply from Central Baggage',
#  'at Logan airport and waiting to checkin for my 9am flight. Checkin desk not open !!!!! Why?!',
#  'to jump into the Dallas-Austin market -',
#  "Beats EPS Views, Takes On VA LUV - Investor's Business Daily",
#  'Lister to my show my on Monday 1230 130',
#  'to begin Dallas-Austin in April - 88.9 KETR',
#  'congrats, you just got all my business from EWR to SFO/LAX. Fuck you fl1289 SFO/EWR was the clincher...',
#  "I applied over 2 weeks ago. Haven't heard back and I'm flying this week",
#  "I'd love to know what your policy is for damaged luggage.",
#  'Thank you for the follow',
#  "- too many apologies! You r the worse airlines! Don't even respond to your cudtomers",
#  'shame on VA for making people spend money in stranded cities when other airlines are landing at JFK! Who will reimburse me?',
#  'I DM you',
#  'can you please have flights in SJC ? I have no choice but to fly Southwest to Vegas 😩😭',
#  'too bad you say it takes 10 to 14 days via YOUR confirmation email. When I inquired after 3 weeks you claim 6 to 8 weeks!',
#  'Flight from BOS &gt; LAS tomorrow was Cancelled Flightled. No notification; wait times are 1+ hour. Will you rebook on another airline?',
#  '😎 RT : You’ve met your match. Got status on another airline? Upgrade (+restr): .',
#  'Only way to fly!',
#  'If only you guys had flights from CMH.',
#  'a lot of "apologies" being thrown out to customers from what I can see.Very sad. Thanks for nothing. Worst airline ever.',
#  'for all my flight stuff wrong and did nothing about it. Had ever',
#  'Having an issue finding a missing item on a plane. Can you help me find which airport my plane headed to next?',
#  'you will match my status? Cool!',
#  "“:You've met your match.Got status on another airline? Upgrade : ” ? 🙉",
#  "trying to book a flight with you guys and your website won't let me... about to lose my business",
#  'you suck!',
#  'thanks!',
#  "Just DM'd. Same issue persisting.",
#  "Because we never rec'd Cancelled Flightlation notice we were left w no options to fly out of PS. Driving to LA for a red eye Mon w kids",
#  'trying to book a flight &amp; your site is down 😁',
#  "You have any flights flying into Boston tomorrow? I need to be home and you Cancelled Flightled my flight and didn't do anything",
#  'you stink. Flight Cancelled Flighted from PSP to JFK and no notification or ability to rebook . better',
#  "I love your guy's song! We're dancing to it for our high school dance revue",
#  "Your website is down and I'm trying to check in!",
#  'done! Thank you for the quick response, apparently faster than sitting on hold ;)',
#  'nervous about my flight from DC to LAX getting Cancelled Flightled tomorrow! Just sent you a DM to help me!',
#  'cool picture of another VirginAmerica plane off our wing. What a site!',
#  'Keep up the great work :)',
#  'my goodness your people field are amazing under pressure ❤️from Texas in crisis Please fly me to NY',
#  'Thanks for a great flight from LA to Boston! Pilots did a great job landing in the snow. Can we go back to LA now?',
#  'can you please get me to the new york area before monday afternoon',
#  'Thanks so much for the awesome support, you guys rock!',
#  "seats in Row 8 don't recline should mention that on your website",
#  'flight 404 delayed 2 hours in LA due to mechanical problems. Handle like pros but you could have tossed us a free drink.',
#  'why Cancelled Flight flights today? No precipitation to be scared of! ❄️❄️❄️',
#  'twitter team. you guys killed it for rescheduling me asap. thank you!',
#  "You guys charged me $100 to reschedule a flight that was then Cancelled Flighted and are now refusing to refund it. What's the deal?",
#  'can’t access your website from Safari on iPhone 6. Seems to work on Mac and iPad. Need iPhone to add Passbook.',
#  'on iPad and iPhone, clicking the CHECKIN link in the email I received at 24hrs before flight',
#  'your mobile site is broken, shows "{{header.elevateUser.numOfPointsAvailable || \'0\' | number}} Points", won\'t let me checkin',
#  'I was really looking forward to my flight. can you let me know when it will be rescheduled?',
#  'why Cancelled Flight flight VX413? One sec its delayed, on my to airport, the next its Cancelled Flightled?Gonna email or call me to reschedule?',
#  'I did it but there was a problem in the link from the email for check-in. thanks',
#  'had to change to another airline to get to DC today ... Why is able to land in DC but not you? Cost me $800 ...ugh',
#  'I was so looking forward to my first flight with you today but it was Cancelled Flightled along with the subsequent one ...',
#  'when are you putting some great deals from PDX to LAS or from LAS to PDX show me your love!',
#  'wish I can afford to fly with you next Friday going back home.. love everything about your airline',
#  'how are you gonna have a deal from Dallas to DC but no deal from DC to Dallas?',
#  'it’s just a bug report, guys',
#  'hold times at call center are a bit much',
#  'Like',
#  'Site down?',
#  'You have the best flight attendant ever!!!',
#  'Awesome! RT : Watch nominated films at 35,000 feet.',
#  'thanks so much!',
#  'Trying to reset my password, email never arrives. Help?',
#  ", the only airline based in Silicon Valley! 's",
#  'Very nicely done. 👏',
#  'I’m looking forward to watching the Oscars on my flight home tomorrow. I might even get something bubbly to drink! ;)',
#  'What is the reason for the delay of the departure of VX 413 from JFK this afternoon?',
#  'is todays flight from Palm Springs, Ca to JFK in NY Cancelled Flightled?',
#  'hahaha 😂 YOU GUYS ARE AMAZING. I LOVE YOU GUYS!!!💗',
#  'sounds like fun !',
#  'any updates on flight 413 from Jfk &gt; Lax',
#  'spruce moose!',
#  'the CSS on your site is a 404 right now, please fix. Site unusable.',
#  "We're on flight 910 Vegas to Boston today, checked in online but our bag count didn't register. Can I fix that somehow?",
#  'classiq, luv Virgin America. Greetingz',
#  "Hi, I'm trying to do check-in but the website is not working. I tried 3 different browsers and the problem continues",
#  'Thanks for your great customer service today &amp; for helping me get all my travel sorted out!',
#  'thanks guys! Sweet route over the Rockies',
#  'love the 90s music blasting at gate in while waiting for flight to . Only if I could get an iced coffee!',
#  "- the passenger in 7D, Flt 338 that assaulted me shouldn't have flown. I trust he's banned. Crew filed report to",
#  'current bug on website shows ‘select departure city’ when selecting destination city',
#  "luggage was severely dented/missing wheel coming off baggage claim in SAN. Luggage agent Miranda (I think) wasn't any help.",
#  'thank you for the easy itinerary shift for impending weather. Quick, painless &amp; free.',
#  "If you'd love to see more girls be inspired to become pilots, RT our free WOAW event March 2-8 at ABQ.",
#  'Thanks! Good times there and back! the entire flight🍸',
#  'beats expectations, shares take off - Santa Cruz Sentinel',
#  'any plans to start flying direct from DAL to LAS?',
#  'BIG Love/gratitude.mpower w/ weRin VIPswagbags',
#  ", you're doing a great job adding little luxuries/aesthetics that improve the air travel experience. Thank you. Keep it up!",
#  'requested window seat and confirmed window but got stuck in middle seat. Not a good way to treat silver member😒',
#  'Grand Budapest Hotel',
#  'This is what you missed . Next trip to the 407.',
#  'I paid for direct flight on purpose not to have to stop for fuel exhausted frequent flier and nothing for inconvenience!',
#  'there is something wrong with you website in Safari iPhone',
#  'thanks for gate checking my baggage on your full flight dfw-lax 883 and giving me early boarding too',
#  'Already checked in so the page expired :X',
#  'Boo for a not refunding a seat upgrade fee I did not want to buy in the first place!',
#  'shares rise on Q4 financial results - USA TODAY',
#  'Adds Pillows Instead of Lie-Flat Seats in First Class Arms Race',
#  'I see what you did there ;)',
#  'way to take advantage of :)',
#  "you know I'm flying virgin for the fight",
#  'your inflight team makes the experience !',
#  "cutest salt and pepper shaker ever. Just when I think you guys can't get any better you just do!",
#  'moved my seat with no notice. "Better seat" is cabin select not behind the row I selected👎',
#  'shares up on 4Q results -',
#  'fav airline',
#  'we have a hot female pilot! Sweet! DCA to SFO! :-)',
#  "👍👍✈️✈️💗 When are you guys going to start flying to Paris? : You're welcome.”",
#  'what is your policy on flying after surgery? I am still waiting for answer so I can tell me doctor.',
#  'already contacted Central Baggage &amp; sent DM. is charging me for the dress that was in the lost suitcase',
#  'Thank you!!',
#  "Is there anything going on with the website? I've been getting a lot of errors past 30 minutes.",
#  'I think i left something on the plane yesterday. who do i call...ah!',
#  'I need you to follow back in order to DM.',
#  'Need to start flying to . 😊😀😃😄',
#  'they told to check with the airline regulation first so that is why I contacted you.',
#  'I have just checked in flight to SFO from LAX &amp; been told as Atlantic Flying Club Gold I get no benefits?!',
#  'husband and I ordered three drinks via my screen and they never came. Awesome!',
#  'soooo are you guys going to leave the seatbelt light on all flight? You can barely call this turbulence :-)',
#  'what is your policy on flying after surgery?',
#  'posts second consecutive full-year net profit -',
#  'Funny story, your website is broken, you have missing javascript and stylesheets on the checkin process. I dislike this!',
#  'would love to do more for virgin just like I do for',
#  'Results Handily Exceed Forecasts -',
#  'I applied for a position in ,and I was wondering if you guys received my application.',
#  'achieves a second year of profitability despite revenue pressure ... -',
#  'gives positive outlook, but sees increased competition -',
#  "I'm trying to check into my 10:50AM CT flight tmm on the desktop website and it's not working (some sort of caching bug) SOS",
#  'weather delays &gt; next few weeks ;)',
#  'check the website before you go to the airport!',
#  'Do you guys know your check-in links from emails are broken?',
#  'pilot says we expect a choppy landing in NYC due to some gusty winds w/a temperature of about 5 degrees &amp; w/the windchill -8',
#  "loved it. Can't wait for Monday's return flight... Mostly just to watch the inflight safety video again.",
#  "lost my luggage 4 days ago on flight VX 112 from LAX to IAD &amp; I'm calling every day, no response.Please give me back my stuff",
#  'The Flight Booking Problems section of your website seems to be broken on Chrome. Might wanna look into that.',
#  'Hi! Just wanted to see if you have any new routes planned this year for Newark. Love flying you guys and hope to do so more!',
#  "I mean. Probably inappropriate while on board.. But, it's on!",
#  "happy to spend the day together. Let's do this!",
#  'is saving my sanity right now:',
#  'missed my flight. How does standby work?',
#  '. They were very understanding and helped me out. Thx!',
#  'brought it all the way across the country today I see',
#  'thank you! I absolutely will 😎',
#  'Looks like a broken link for your assets',
#  "are you ready!? Let's say it together.. 'Noooo turbulence today!' 😘",
#  'the manage itinerary section of your website seems to be broken for me',
#  "can't check in, your site looks like this every time it loads",
#  'can u help this 👸 needs urgent treatment in🇺🇸2y old battling cancer could u help with flights 💗',
#  'may start service to Hawaii from this year',
#  'Other carriers are less than half price for a round trip fare. I am stunned.',
#  'WTF is happening in PDX Late Flight March such that one way from SFO is ~$550?',
#  "add DTW and I'm sold!",
#  'How about some free drinks on the flight back for the free promo?',
#  'thanks!',
#  'momma I made it! 😁😁😁',
#  'please contact me about portfolio left on flight VX 27 from JFK to SFO tonite seat 7AM. Need it returned. Call 914-329-0185.',
#  'help. I was On Flight 27 from JKF tonight. seat 7C left portfolio. Need it back!!',
#  "Seattle bound. Wifey got me the duffle for vday. She's a keeper!!! Holla!!!",
#  "my luggage is gone. I've filed my paperwork, promised a call/email. Still no resolution or response from central luggage.",
#  'Debbie Baldwin gave a performance of the safety demo this evening on VX919',
#  'Thanks!',
#  'thanks for taking care of on her flight!!',
#  'Thanks for the lovely soft views! to',
#  "I requested a mileage challenge for status several weeks ago online but haven't heard back. How do I get help with this?",
#  "Just trying to book tickets to NYC and facing super fun broken styling. Don't worry, I'll keep trying :)",
#  'Many Thanks for the Follow. Looking for Any Help😍 💗🇬🇧💗🇺🇸💗 🎀🌏🎀',
#  'Nice, Lofty View .',
#  'Applied for Status Match on Feb 1. Got confirmation email same day. Still no news though. You guys have dropped ball Late Flightly 😥',
#  'is my new go to airline',
#  'Can You Help in need of some help in 🎀🇬🇧🎀🇺🇸🎀',
#  'I adore you, and am so looking forward to my flight to Austin in two weeks.',
#  'I was so glad it was mentioned. I took my first virgin flight a few years back and it was a transformative experience.',
#  'Flight Booking Problems flight to uphold my status match. Do taxes on ticket count as earned status points?',
#  'trying to check-in...but looks like your site is down?',
#  'spending my birthday night with you, DAL-DCA. Get me home!',
#  'Sent a couple messages to the email you provided but to no avail. Will try again next year. Cheers.',
#  'first time flying Virgin, went to .Thanks for the smooth ride. Easily my new fav airline!',
#  'seriously, though. will there not be direct flights from SFO-FLL in may???',
#  "It's fine. Already done with my purchase. But you should try it. Just go most of the way through then go back 3",
#  'not really the experience I was hoping 4, I ws forced 2 check in a small carry on, w/ nothing but empty cabin space on board',
#  'wjere is our luggage slow at lax',
#  'to jump into the market',
#  'I spoke with a representative that offered no solution, I am a loyal customer who flies on as well',
#  'I am deeply disappointed that your birthday promo was not applied to a trip I booked mere days before I received the email',
#  'what happened to direct flights from SFO-FLL? Looking in May, only see connecting',
#  '.. Can you help? Left my blazer in. Kooples jacket bag at 3rd row second seat from right gate 36 T3 lax.. Flight to sfo',
#  'partners with Checkout as mobile payment method to help boost mobile conversion rates',
#  'just promoting the product is all, had a problem with southwest and recommend noneother than the best!',
#  'love you guys, but pls get some direct routes LAS to AUS!',
#  'i would like help with some flights please.',
#  'Bruh “: Turn down for what. ”',
#  "of course! I work for and I'm obsessed with the entire Virgin family!!",
#  'ok! first time flying with you tonight :)',
#  'Digging the swanky pink mood lighting during the flight from NYC to SFO. Just needs a cabaret singer. Think about it!',
#  'Done, but I need the receipt ASAP. Could you please help? -000114',
#  'I have 2d and 3d embossed badges and patches superior to the ones you are currently using.',
#  'on VX399 from JFK to LA - dirty plane - not up to your standards.',
#  'on flight VX399 headed to LA from JFK - dirtiest VA plane I have ever been on. Sad for a great airline.',
#  'got it squared away. Someone picked up as soon as I tweeted. Should have tweeted sooner. 😉',
#  "your Avis rental continue button doesn't work on your website to book car. Tried 4 times on phone. This sucks!",
#  'delayed to10.30!!',
#  'currently in minute 10 of being on hold with cust. service. Do I need to do anything to add a lap child to my reservation?',
#  'Adds Pillows Instead of Lie-Flat Seats in First Class Arms Race by',
#  '“: Of course. Have fun celebrating!” Thanks! Happy Chinese New Year!',
#  'Flight Booking Problems last second flight for next week from SFO- to SAN any chance you want to gift me a promo code since I love you guys',
#  'Comenity Bank is a joke! Please change. Nothing but constant problems with this bank',
#  'I just did, how can I DM? Do u have to also add me?',
#  "For my Grandma Ella's 80th, she would &lt;3 a bday greeting from your flight crew! She was a stewardess for Eastern Airlines.",
#  'Just bought tix for ATX - Dallas route - thanks for adding that! Love yr airline &amp; yr website is BEST transactional site EVER',
#  'Anytime, sugafly.',
#  "gave a credit for my Late Flight flight yesterday. Great service !!!! That's a Wow moment! Unexpected gesture!",
#  'I need a receipt for a flight change. Can you send one?',
#  ', I submitted a status match request a while back and still haven’t heard! I’m flying on Monday. Can you look / accelerate?',
#  'had me at their safety video . . . LOVED my first cross country flight.',
#  "that doesn't look to fat to me! It looks yummy!",
#  'CEO says &amp; have strayed from low cost model.',
#  'a brilliant brisk am in Boston in cue for vx363',
#  'Atlantic ploughs a lone furrow in the',
#  'Atlantic ploughs a lone furrow in the',
#  'Atlantic ploughs a lone furrow in the',
#  'omg omg😍😍 nonstop Dallas to Austin on virgin✨😱✈️',
#  'Your planes are really pretty. Just thought u should know that. :)',
#  'when are you flying to hawaii',
#  "I'm pulling my hair out trying to book a flight with u. Your site doesn't work on iPhone or iPad.don't have a computer",
#  'thank you',
#  "Can I get some help with a support ticket? It's been 15 days.... Incident: 150202-000419 Thank you!",
#  'good to be home',
#  'I cannot even open my laptop in seat 4C and I paid a premium for this?!! Let me out of here!',
#  'I am in seat 4C and I cannot even open my laptop; and I paid extra for this seat!!',
#  '. If only you guys were starting those flights at the end of the month! Guess I’m still road tripping on Feb 27…',
#  "thanks for that. Been needing a way to make those Austin trips from DCA, and now you've come through!",
#  'announced New Route to Austin w/fares from $39/way.',
#  "Really? Sprint? I thought you guys were 'kewl'! 0_0",
#  'this is too cool! Never been on ur planes but now I will!!',
#  'you should have 39 dollar LAX-Las fares!!!',
#  'great. Well deserved.',
#  "FYI the info.com email address you say to contact in password reset emails doesn't exist. Emails bounce.",
#  'Status match - 2 weeks have gone by and no news.Flt next week - hope flt will count towards requirement. Cust Svc no help!!!',
#  'your website sucks donkey dicks. Just thought you should know. All best.',
#  'You should still develop an app - then you will be my favorite airline.',
#  'all crap channels which is why I pay to watch UK tv',
#  'got it. All set - Thanks!',
#  "no A's channel this year?",
#  'Only thing I see on passbook is Virgin Mobile Mexico. How do I integrate?',
#  'Giants and Virgin America. A match made in heaven.',
#  'thank goodness!! Also, see you friday, nwk&gt;sf.. BOOM!',
#  "how come you don't have an iPhone app? Still using and making me waste paper.",
#  'Your back of seat entertainment system does not accept credit cards that have an apostrophe in the surname.',
#  'When will VX use all 6 LGA slots instead of 4 today? Adding AUS makes this less likely :(',
#  'is helping me step up my game!',
#  "I luv ur people and product! 1 thing is y do u charge for herbal tea but not black tea? I'm not a caffeine drinker",
#  "thank you! See y'all soon! I'm excited to see the expansion of destinations. Spread those wings!",
#  'announces new nonstop connecting &amp; , $39 intro:',
#  'adds Austin-Dallas Love Field route.',
#  'sad to learn you no longer fly SFO &gt; PHL. Hope it returns!',
#  '- can you tweet me the Cancelled Flight/chng fee for a flight? or can I rebook under one of your affiliates? If so, who are afiliates?',
#  "has the most INCREDIBLE customer service I've ever experienced! So refreshing!",
#  'Now, when will we see VirginAmerica come to Philadelphia (PHL).',
#  ', am I dreaming? Did you really just open up a route between Dallas and Austin?! And does this mean Houston might be next?',
#  'OMG FINALLY',
#  'to start 5xweekly flights from to on 28APR',
#  "Nice to see you expanding in Texas but don't forget about us here in . I would love to see more flights out of here!",
#  "kinda sucked my earphone jack didn't work on my flight. They may want to look into that for future passengers",
#  'Very poor experience. First computer problem now seat malfunction. Stuck. Missing meeting in San Diego.',
#  'to battle on - route via',
#  'the DAL-AUS route makes my day!!!!',
#  'awesome deals DAL-AUS for only $39 each way!',
#  'I miss the in San Jose',
#  'love it, taking on in their backyard! Consumers win when biz competes.',
#  '\u200b is flying from Love to Austin now. That is most excellent news.',
#  'can we make every VX plane with ? Why should Austin be the only one getting nerd love?',
#  'please add more frequency to PDX Portland',
#  'Congrats VX on the new route! ✈️🎉',
#  'I tried that. You offered to charge me an additional $1k for a new ticket or be stranded until Thurs. 1st time, last time.',
#  'can u help with flights to get a 2y old battling cancer who needs treatment in 🇺🇸 💗 🎀 💗',
#  'Never had a bad experience before, but this one took the cake. Now extortion for carry on items as well?',
#  "Had to spend 5 hours worrying that items in carryon would be broken/stolen since I couldn't carry them on plane or lock bag.",
#  'All of group E was told there was no more room in the bins. when I got on the plane, was room for at least 4 bags in my row!',
#  'Thanks for making my flight from LAX to JFK a nightmare by forcing me to check my carry on bag at the gate. (1)',
#  "I have lots of flights to book and your site it not working!!!! I've been on the phone waiting for over 10 minutes..........",
#  'I am all about the in flight artisanal cheese and wine pairing.',
#  'does Virgin America fly direct from Seattle to NYC or Boston?',
#  "That's classy.",
#  "I'm sure a lot of your 747 and 777 JFK-LHR flights go a lot faster than 513mph with a strong tailwind.",
#  "now it's just t-minus 32 minutes until my Elevate a Silver upgrade window opens . 😃👍",
#  'save some for 871 tomorrow AM!',
#  'Why is it taking 12 years to fly home to Dallas? Get your shit together.',
#  'club Virgin is bumping in New York',
#  'would have been a rough trip but LUCKILY we were on a flight.',
#  'is that ??😁',
#  '...Please come to Minneapolis St. Paul!',
#  'YES FYI MY BFF',
#  'another perfect flight. How come on your planes, the sun visors can stay down? Other carriers make you raise them?',
#  'Nice RT : The man of steel might be faster, but we have WiFi – just saying.',
#  'I love the dancing little richard. cool beans.',
#  'I don’t use Passbook =/ I still love you though &lt;3 :) I’ll just use my email in the future.',
#  "thanks for the free birthday points! y'all are ALL RIGHT with me!",
#  'do you have an application for iOS? Was looking and only saw Virgin Mexico :( &lt;/3',
#  'Man of steel flies to more cities though...and with more frequency too.',
#  'thanks so much for sharing. Just added it to my site',
#  'Good point!',
#  '. I heard he has a virgin mobile hotspot ;)',
#  'you got cheese pLate Flights too.',
#  'On all your flights?',
#  'Dad on Segway is the best part of this whole infographic!',
#  'Are there any plans for a short haul airline in Europe? Would defiantly fly with you guys :)',
#  'wifi AND better seating.',
#  "how come ABC is the only one of the network channels you don't have?",
#  'started my flight with a scolding for using an overhead bin that was then offered to the person seated next to me.',
#  ". not only was it great, but you return my calls the day after. Couldn't ask for more.",
#  "While other airlines weren't Cancelled Flighting flights into BOS, and helping their customers get home, Virgin was saying Good luck!",
#  "Dear Virgin customer, while you're stranded in SF for 3 days &amp; $1000cost- we'll do the very least we can to accommodate you!",
#  'should use this in their next airline commercial lol ::',
#  'Grouping Virgin in with the others now. BOS weather has exposed their actual Cus Serv model. Never Flight Booking Problems with Virgin again!',
#  "As one of the travelers affected by the Boston storm, I'm shocked at Virgin's complete apathy toward their customers.",
#  'Umm so no reason as to why this is? Is there someone different I should contact (or contact me) to get a definitive answer?',
#  'Trying to make the change in advance (not just 24 hours prior)…tried it online earlier and it wanted $300 in change fees.',
#  "so loyal that I'm driving to from , to fly Virgin, since you cut flights ;)",
#  'Any way to change from Main Cabin to Main Cabin Select (on same flight) without paying a change fee penalty?',
#  'you guys are perfect as always! &lt;3',
#  "thanks! Y'all have some of the best customer service left in the industry.",
#  'Can you give me Silver Status for 12 months?',
#  "really wish you'd fly out of those fares are amazings",
#  'mood lighting on point🙌 Reclining my seat, kickin up my feet💤',
#  'my flight (6000) scheduled for 1pm departure still says on time but no plane at gate. Any update on how long of a delay?',
#  "my group got their Cancelled Flightlation fees waived but I can't because my ticket is booked for 2/18? Your reps were no help either 😡",
#  'Are there any sign up bonuses to enroll in Elevate?',
#  'just got on the 1pm in Newark home to LA. Your folks at EWR are incredible',
#  'morning. If I have a question regarding elevate points &amp; flights can I DM you?',
#  'still waiting to see 😞',
#  "was wondering if you guys recieved my dm and we're able to potentially respond asap",
#  'Flying LAX to SFO and after looking at the awesome movie lineup I actually wish I was on a long haul.',
#  '“: Book out of town with fares from $59/way (+restr). ”',
#  'thanks',
#  'Thanks for taking care of that MR!! Happy customer.',
#  "still no refund or word via DM. Please resolve this issue as your Cancelled Flightled flight was useless to my assistant's trip.",
#  "Delayed due to lack of crew and now delayed again because there's a long line for deicing... Still need to improve service",
#  "thanks -- we filled it out. How's our luck with this? Is it common?",
#  'Your ERI-ORD express connections are hugely popular .. now if only we could have an ERI-EWR hop! :)',
#  'even on international flight Glasgow to the U.S.? Then what about orlando to Newark? All 90 mins?',
#  'you think you boarded flight AU1066 too early? I think so.',
#  "I understand, but it's tough when there is no way to get to the airport w/o serious risk of an accident. It's a steep price.",
#  'Gate agent hooked me up with alternate flights. If you have a way to PREVENT the constant issues, that would rock.',
#  'flying gla-mco in a few weeks. How long do we have to be at airport for before departure for both international and domestic? Ta',
#  'thanks',
#  'Thanks. It is on the same ticket.',
#  'why not? Is it a law or a policy?',
#  'is the worst. Nonrefundable First class tickets? Oh because when you select Global/FC their system auto selects economy w/upgrade.',
#  "So I can buy tix 3 days before flight but can't transfer the tix. Flawed security logic. Flawed customer service",
#  'I did start a claim but 8-10 weeks is unrealistic, am I really supposed to go that long with out a car seat for my child.Ridiculous!',
#  'follow me please this airline is beautifull ♥',
#  "no I don't, but I'm sure United have my info on its system.",
#  "if the car seat is lost should just reimburse me for a new one, this is not a pair of shoes, it's a necessity for my child",
#  'Just submitted my response on the link you sent.',
#  'yes, David Allan send an email with this number (KMM24999563V99860L0KM) and case',
#  'that totally sucks my cousin worked at PHL said',
#  'just wanted to let you know how wonderful Rosetta the gate agent was working flight 6457 Dan to Ase. Let her know she wasappreciated',
#  'yes, a paper voucher that I got on January 26th 2015',
#  'beginning of Feb I called United they said they would send another voucher by mail. Never got anything.',
#  'the internet is a great thing. I am emailing executives in your company, maybe they will respond to me in a timely manner.',
#  'Do I need to use a Chase United Club pass for my 8yr old son, or can he come in with me on my pass?',
#  'and what am I suppose to do with that number?',
#  'thats weak. See ya 👋 Hey !!',
#  'I flew back w other company since United didnt have an earlier flight',
#  'I lost a voucher that I was given in Miami aeroport on jan 26. I did not use it.',
#  'I am trying to book awards for September and need flights on but they will not show even w/ many award seats availab',
#  "I sure did. I had to drive a total of 3 hours to get my own bag. I'd like to explain that debacle but no one wants to talk to me.",
#  "Gee that's like almost caring about ppl more than $$. Think I'm more int in having a trusted adult w/ daughter .",
#  'See? We were told repeatedly that the pilot was Late Flight and kept getting Late Flightr. After we boarded, there was a defibrillator issue.',
#  "why no preferred security line anymore. My TSA pre-check didn't pull on my partner flight!",
#  "Airport need to indicate different gate's for terminals A&amp;C.",
#  'yes please! I am newly married and trying to update my last name on a preexisting international flight! It seems so easy, but...',
#  "How does United refuse to reissue a $400 lost voucher when their plane didn't take off due to mechanics?",
#  'also during the run I was instructed to do, I shattered my computer.',
#  "yes, we've been with the agents for the last 50 minutes. One of the agents have been very rude, but thankfully Ladan has been nice.",
#  "that's right- with an overnight Miami.",
#  'Have clients with an 11 hr layover at IAH (during the day). Will they have to claim &amp; recheck luggage. Or will it be taken care of?',
#  'I am trying to find out if the loaner seat is new or used, a used car seat is illegal according to safety regulations',
#  'i DMed you the details',
#  'iah to charlotte. Baggage claim rep latrice h. non existent, Ignored customer then inappropriately touched customer',
#  'Kewl. Will also let them know the overhead bin over my row was "Inop". I love a good abbreve.',
#  '- thanks for your help...got me what I need, but its an issue with . I guess I sit awhile longer.',
#  '- I would have loved to respond to your website until I saw the really long form. In business the new seats are bad',
#  'A refund and flight vouchers or another flight on a different airline at your expense for today. 8 hour drive is very inconvenient',
#  "then why have I not received my call back its been 3 days...it's an infant car seat how am I supposed to go anywhere with my child",
#  'thanks again for your concern. I will contact customer care upon our return from Australia.',
#  "well sitting on the ground 'on time' but waiting for a gate....again",
#  '"Airport snow removal method ..." Keep up the good work folks, this is where Cessna\'s become 747\'s!',
#  "No, I need you guys to not over book planes. It's not a concern, I'll just travel with someone else moving forward.",
#  'A measly $50 e-certificate is not how you appreciate loyal customers after they wait 3hrs on the tarmac during UA1116.',
#  "When will email address/username sign-on be available? It's been a while.",
#  'Thank you for that. Am I able to claim any interim expenses or is the cost of the stuff up on me?',
#  'rude rude',
#  "- Why can't I get a boarding pass for my Austrian Airlines codeshare flight. Rebook incls a 6 hour layover &amp; I am stuck outside sec",
#  '. ..I received on other flights. truly breaks guitars.',
#  "just flew to paid $100 from a third suitcase which didn't even make it on the plane! Besides for the impolite service...",
#  'My bag is still in Colo Springs. I am disabled and have to search an unfamiliar airport and look for my bag. Not a good outcome',
#  "Shame that there's no flex to tickets transfer rules. Even calling from Neurosurgery ICU isn't enough!",
#  "No. Denver said they don't handle baggage that made it to Colo. Springs. They gave me an 800 number to call. No help there either.",
#  'you guys need some serious training in customer service. Too many better options to put up with the way you guys handle ur mistakes',
#  '6533 ORD to DCA',
#  'once he found out we had a problem he avoided me like the plague. Was told "we can\'t find a supervisor."',
#  "ZCC82U Cancelled Flight flight 16h in advance??? Need connect flight reschedule so the link isn't helping. Help!? Gf waited months to see me.",
#  'I will not be flying you again',
#  "in addition, my first flight was delayed an hour and I'm arriving at my destination 8 hrs Late Flight.",
#  "Cancelled Flighted our flight, didn't rebook us on added flight, now have to drive from a Denver to KC....thanks!",
#  'your announcement for pre boarding only addresses mobility. My disability requires me to travel with a lot of stuff. Do I preboard?',
#  'I flew United last month and the experience was AWESOME!',
#  'our travel booked thru United group dept. Okc ticket agent less than willing to help with our connection in LAX.',
#  'v upset with your disability "services". When I told one of your employees I was carrying medical equipment she was very rude.',
#  "thnx for quick reply but don't think you can assist. Our intl grp will be put to considerable inconvenience today.",
#  "wont transfer flight ticket to accompany an 11 yr old who's active military mom had to have emergency brain surgery? WOW!!",
#  '7 WEEKS Late FlightR AND I STILL HAVE NOT RECEIVED MY MILES FROM THE MileagePlus Gift Card $150 STARBUCKS CARD I HANDED OVER!!!',
#  "as a 1k, I'm always hoping for improvement.",
#  'not yet. I complained about the guy who checked my luggage in as he was throwing the bags around. Unfortunate coincidence I hope?',
#  "OKC ticket agent Roger McLarren(sp?) LESS than helpful with our Intl group travel problems Can't find a supervisor for help.",
#  "mobile apps need construction from the ground up for each OS category. It's expensive to get right .",
#  'another fail for the United ticket agents in OKC. LESS than helpful and could care less about our problems. American here we come.',
#  '441, which also had 1 working WC in coach. Good thing this bird landed ahead of schedule. I have to use the WC stat.',
# ...
#  "Thanks for the reminder. It's been a fun ride.",
#  "I received my luggage that also looked to be left in the snow when I arrived. I'm asking for all 50 people to be refunded.",
#  "updated A320 aircraft has wifi and device entertainment but no outlets. I don't get it. How can I charge devices?",
#  'was no one between the scan and inside the plane. I just asked the people in line around me where the plane was going',
#  '5 gate changes, two delays. Even the crew thinks the airline sucks',
#  "I'm very frustrated and have wasted 2 days now due to your equipment failures.",
#  "computers are down but you stopped giving updates and took my flight info off the app. That's just ridiculous keep people updated!",
#  "Soooo, it's been 15 days and you've offered no response. So I assume poor treatment by gate agents is the norm now?",
#  'Terrific. Many thanks. Looking forward to being back on UA tomorrow. Had a great flight up to Vancouver.',
#  'Calls to 800 resulted in 2hrs of hold time &amp; 2day wait to check suspect code share fare. Nothing investigated—my time wasted (2/2)',
#  "It's taken ~3 weeks for Cust Care to respond to Case , requesting a refund for wi-fi not working. Where can I get an update?",
#  'I appreciate your efforts getting me home!',
#  "That's correct—I've spent hours trying to book online only to receive an error when clicking final purchase button. (1/2)",
#  'Today was not your finest. All could have been prevented by one gate agent advising 200 passengers.',
#  'what is the real deal with the delay on flight UA 1032 from Denver to Vegas?',
#  'UA63 from Madrid arrived no agent mass confusion we sent to and fro by 3 UA employees. MaryJo was rude and unhelpful.',
#  "system failure again = bad trend. Software projects are like flying an airplane; there's no such thing as an emergency takeoff.",
#  'lots of reports of system failures delaying flights over the last week. Currently sitting on the tarmac at OGG for over an hour.',
#  "rebooting Chicago dispatch system, need as I'm tired of sitting on planes",
#  "despite shaky connections, looks like I'll get home tonight. Great job, - was touch and go for a while..",
#  ', however, is completely under your control—the price was and still is displayed on .',
#  'the aircraft closest to gate was for the other flight and the one closest to our gate was going to Chicago.',
#  'can you tell me how to file a claim for clothing that had to be purchased?',
#  'comically on the return flight from ASE there were two United flights boarding at adjacent gates and not clear which plane to board',
#  'GRK13575M is the file reference',
#  'we would...how do I contact you to discuss? A few poor experiences with customer service but would give it a shot!',
#  'UA 746. Pacific Rim and Date Night cut out. Not constantly or randomly, but one spot, repeatably.',
#  'Been trying since 1230 to file a report.',
#  "I send an email about my bad experience and you send back a generic response. Yet another reason why I'll never fly with you again.",
#  'My mom left her Kindle on flight 1544 today. Burgundy case with a light. Seat 27D. Did anyone find it?',
#  'here is the ticket 0162424965446 please refund my unnecessary upgrade fee',
#  "is horrible!! They lost our carseat and expect us to use a loner carseat, safety regulations say it's illegal to use a used car seat",
#  'thank you.',
#  "Decisions Decisions : We'd love for you to try our service. We offer status match too. ^KP”",
#  "Need more info on that! : We have great amenity kits. PJ's not included. We status match AA. ^KP”",
#  ': I don\'t care that a link showed me a "wrong" price on your site—it\'s your site &amp; responsibility to ensure correctness.',
#  'Do you have any flights with lie flat seating from STL to PDX around the date of March 5?',
#  "He needs to get to home the 24th, they're telling him it'll be the 25th night. Is there compensation or anything that can be done?",
#  "“: The baggage fee is waived for Premier members. Please see . ^JP” what's the point of membership?",
#  'wonderful bag claim people - finally have my bag. But why did I catch earlier flight? Original flight just landed.',
#  'Dmed you. Thank you',
#  "thanks we'll be in touch!",
#  "Thanks to Karen Salisbury at IAH for amazing customer service! Found my daughter's bag lost on UA1516. Made her day!",
#  '3 days Late Flightr and my bag has not left IAD, United is not helping at all. Everyone tells me a different story',
#  "hi, when do direct flights from Houston to Reno begin? Don't see any days in March?",
#  "like continental's chicken feat fairs",
#  'can you assist with current flight status for flt 1016 out of DFW tomorrow at 6:55am?',
#  'I left my comment with customer care. Thanks for contacting me.',
#  'how do you lose a gate checked bag DEN to ORD? Direct flight. Ugh.',
#  "caught earlier flight to ORD. Gate checked bag, and you've lost it at O'Hare. original flight lands in 20minutes. !",
#  "Yes!! Thanks so much!!! 💜“: We see you spoke with our Reservations team and they've reinstated the flight. Thanks. ^EY”",
#  'captain "on behalf of the front office, welcome on board.".... Never heard that before. I laughed...hard.',
#  'Can you please follow for a Dm on a missing bag?',
#  'to be clear on my luggage comment, I am referencing the photo attached. Flight 6232 to JAC',
#  'These are great fares!!!!!',
#  'i left an item on the plane and have been calling non stop and no one has been answering can you please help',
#  "awesome I'll book my next Christmas vacatinn this December any other ways you want to devalue mileage plus.",
#  "what's a good number to call to speak with someone about how you can fix what you did to 50 people and their luggage on Saturday?",
#  'THANK U! Secured room for the night Thx to VERY helpful customer service rep N. Dorns.. I thanked her.. Can u 2?',
#  "where's my damn bag??",
#  'well someone should tell that to the employees at the Denver baggage claim. Still no bag!!!!',
#  'Greetings. UA Club member here. Any idea if I can use the Air Canada Lounge at YVR. Flying UA tomorrow.',
#  'how is Mexico not international from the us?',
#  "diverted and missed our connecting flight. Was just told that my bag is on it's way to MSY. If you only had people that cared",
#  "Male agnt in LAS threatens Canadian cust when cust takes pic of him at gate after agents announce can't help rebook. ?",
#  'we just want to go home tonight - why did you Cancelled Flight the last leg of our reserv. w/out our permission??!',
#  'Stressed and rude agents. Overwhelmed by delyd flight LAS-DEN 1657. Yelling at several people. Not pretty. This is ??',
#  'landed in Boston at 9 last night. The 15 hours of traveling was rough tho.',
#  'FAIL You Cancelled Flightled our flight frm GJT and then used our reserv home to IAH (from SEA) for reFlight Booking Problems w/out OUR PERMISSION!!',
#  'Just sent thank u RT : Please DM your confirmation number if reFlight Booking Problems is needed. Thank you. ^EY',
#  'has made my no fly list. Other airlines wait when connector Late Flight. Stuck in IAH.',
#  'so what’s the deal? Do u provide voucher for overnight or am I cozy on the floor at ?',
#  'also, the mere fact that I have to go online to issue a statement vice calling and talking to some directly is one good example.',
#  'thank you. I flew into Newark from Vail/Eagle.',
#  'i have a weekend of dealing with your company that would say otherwise.',
#  'now what?!? flight was gone when I got off plane!',
#  "the proper response: sorry for your wait, what flight were you on so we can look into the issue. That's how would handle.",
#  'your customer service is terrible! Stood inline 3 hours no flights and 4 hours Late Flightr still no bag',
#  'please upload the March on-demand entertainment listing on your website! ✈️',
#  'So you are inadequate by accident?',
#  'Denver International Airport',
#  'Thank you for responding so quickly with a helpful tool!',
#  'boarding time shows 35 min and your gate agent started at 45. showed up at 4:00 and they had to check bag.',
#  "Agent in LAS letting 20 customers know they can't help them rebook delayed flight to DEN",
#  'empathizes w/ my disappointment that 1stClass flight w/nonworking entertainmnt is worth $50.',
#  "...and when that doesn't work...",
#  'did you have seen my message today?? About a mcdonnell Douglas dc 10 model?? I will hear it if you read it, Goodnight now',
#  "searched for mileage tickets to BOM couldn't find a single one is saver awards - I see how you play. Earn miles but can't use them.",
#  'flight arrives 30 minutes early, but then have we to wait for an hour for our bags.',
#  "That's not the issue. The fact that no one even called (despite promises) to confirm the bag's location is.",
#  "what's a girl gotta do to get a flight name change when SHE bought one for a mean ex boyfriend and needs a girl's trip stat?!",
#  'thank you. We are signed up for notifications. We shall watch and wait! ❄️❄️',
#  'still waiting to hear back. My wallet was stolen from one of your planes so would appreciate a resolution here',
#  'I would love if someone could get me back to Austin tonight and I do not wish to wait til tomorrow morning.',
#  'or has lost my baggage… heard different things from different employees of . has said nothing.',
#  'cs thinks that miles can repair the damage done, it will be interesting if they travel in and exp the worst flight ever!',
#  'I have a 0530 flight out of DFW on Tuesday. How far in advance will you give notice if Cancelled Flightled?',
#  'I am signed up for notifications. This is the first trip I was not updated on. Not sure why this happened.',
#  "Thank you. Took care of everything and made it right. That's the experience I'm used to. Opened the app to find flight changed.",
#  "that is not in line with your responses here. And now I'm waiting until tomorrow morning because all the flights are overbooked.",
#  'I took the exact same aircraft in to LAX 3 days ago. It fit, no problem. The agent today told some nonsense about a policy change',
#  'your helpful agents in Club helped. I am just out baggage fees and a night of my life.stop doing business with',
#  'never heard of this?',
#  'doesn\'t charge ticket change fees. Do they not incur the same mysterious "costs" that you incur, ?',
#  'Exhausted &amp; frustrated! Link to a FB post abt my travel issue',
#  "I was denied getting on the plane w/o getting the chance to prove it fits. I'm not a rookie. Read my bio.",
#  "that's exactly the point. It fits. I'm premier access. Boarding group 2. This was a return ticket. I've been doing this for 15 yrs",
#  "I've never experienced worst customer service. Placing blame on codeshare partners and not assuming responsibility is unacceptable",
#  'currently on board so not now. Check in was terrible. Staff rude. Expensive luggage thrown around etc.',
#  'fucked up, then voided my ticket, and KEPT MY MONEY. Not even an apology. I will never fly with your airline again.',
#  "has the WORST customer svcs! This Kevin rep at call center must be investigated. My baggage's lost and there's no help but argument!",
#  'should NOT sell tickets for on . has terrible service and UA staff cannot reach Silver',
#  'Just got demoted from Gold cuz my hubby got 100% of the PQD, tho there were enuf $ spent for 4 Golds..discrimination/angry.',
#  'Thank you!',
#  'When will direct flights from Belfast Intl to Newark resume from their winter break? Thanks.',
#  'My favorite way to travel! Thank you!',
#  'yes, after this awful weather it appears I can get home',
#  'yes lots. You have terrible customer service at Newark and despite raising a complaint there we were ignored hence the tweet',
#  'Lovely new plane from LGA to ORD but no power outlets?',
#  "but if i tweet the ID number, won't that reveal my home address to anyone on the web?",
#  'I filed a delayed bag report on Saturday! my flight was Cancelled Flightled and I never went anywhere!',
#  'the person is currently bettween gates 71A and 73 in LAX',
#  'i need it there before she lands so she can have the EWR baggage claim file to have it sent but the employee has not droppeditoffyet',
#  'rarely ceases to amaze...for the worse. i hope this is the last time i "have" to fly with you.',
#  'thank you for the quick response but I cannot dm you until you follow me as well',
#  'iCloud it is not there yet -- PLEASE HELP 917 703 1472',
#  'I need the phone number to baggage claim in LAX, my mom left her phone and someone called saying they would put it there but on',
#  'I did... no response back',
#  'this is atrocious customer service.',
#  'will not have to honor absurdly low mistake fares. vía',
#  'delayed departure to check bags at gate claiming space filled and walk on to open spaces a delay',
#  'you Cancelled Flighted our flights for no reason &amp; now we have been on the phone for AN HOUR on our vacation. Why?',
#  "THAT'S your response? Shaking my head back and forth with a tsk. You can do better-from customer service to your apology",
#  "thanks! It's 35K miles from RTB to Europe, to do a multiple destination so we could stop over in US on way/way back- mileage diff?",
#  'of course I did. The bag should be here by now :(',
#  'you are the worst. I will avoid you like the plague.',
#  'is the worst airline in the world.',
#  'someone needs to DM me and resolve this correctly. Extremely disappointed with the service I received. Terrible management.',
#  'Premier Gold desk changes flight. Waives fees. Gives me wrong flight. Now Jana Acosta in Salt Lake refuses the same service. Angry.',
#  'I will give you one thing, you are consistent but unfortunately you are consistent at not doing your job well',
#  "I will but right now I'm to angry",
#  'first time flying with United. Also last time. back to for me.',
#  'I used to be a committed flyer until merger. I remember now why I switched to',
#  'the least you could do is offer me a ticket in coach instead of just Cancelled Flighting my reservation because of your glitch!!!',
#  "I'm saying I made the flight but with poor/non-communication, unaccounted for lost time &amp; lots of frustrated flyers standing around",
#  'I think DM would be better',
#  'gate announcement states delay due to maintenance yet app says Late Flight arriving aircraft tell the truth!',
#  "you are easily the worst company I have ever experienced. You have lost someone's personal possessions &amp; you couldn't care less!....",
#  'how can your app show arriving aircraft is early but departing flight is delayed due to Late Flight arriving aircraft?',
#  'already did that at the airport and 12 hrs Late Flightr its still not here! you guys are really killing me today. trying to stay positive..',
#  "once united's service levels reaches those of Etihad or lets be more realistically Lufthansa then ill consider it again",
#  'really? Someone called in sick and then someone FORGOT to call a replacement?! Now an hour Late Flight to take off.',
#  'Asked Flight attendant what typical compensation would be &amp; says we might get free TV.',
#  'done',
#  'Thank you, ^JH, appreciate the prompt responses--me and other passengers will be doing so.',
#  'has been such a disappointment today. Simply put. Rather unpleased with things currently. Flight delayed; cant wait to just get home',
#  'During the same round trip, my NON-English speaking friend was stranded TWICE for 12+ hours each time! Most staff members were rude.',
#  'found a group of people who actually hates people more than ISIS, thats right United Airlines.',
#  'Nope. Walked up &amp; down the ORF terminal, &amp; not a United agent to be found. Showed up last minute to board us. Many panicked people',
#  'thank you',
#  'by the time I finally get to Dallas I could have driven with less frustration and cheaper.',
#  "I'm trying to get to my final destination, we need compensation. Just about 2hrs of personal time wasted.",
#  'that guy really has no customer service clue.Could have spent effort clearing bins for rollerboards instead of art projects in mine!',
#  'he has no priority and Iove it',
#  'Pleased to be a Premier Platinum',
#  ...]

# %%
# A list ('tweets_cleaned_0') is created containing each tweet with the emojis preprocessed. 
# That is, each emoji is replaced and represented with a linguistic expression (token).

tweets_cleaned_0= []  

for tweet in tweets_preprocessed:   
    tweet = emoji.demojize(tweet).replace('_','')
    tweet = re.sub(r'\b\w{1,1}\b', '', tweet)
    tweets_cleaned_0.append(tweet)

# %%
# The list containing each of the pre-processed tweets -the mentions, hashtags, links, emojis- are printed
# to verify that the previous process has been performed correctly.

tweets_cleaned_0
# Out:
# ['What said.',
#  "plus you've added commercials to the experience... tacky.",
#  " didn' today... Must mean  need to take another trip!",
#  'it\' really aggressive to blast obnoxious "entertainment" in your guests\' faces &amp; they have little recourse',
#  "and it'  really big bad thing about it",
#  "seriously would pay $30  flight for seats that didn' have this playing. it' really the only bad thing about flying VA",
#  'yes, nearly every time  fly VX this “ear worm” won’ go away :)',
#  'Really missed  prime opportunity for Men Without Hats parody, there.',
#  "Well,  didn'…but NOW  DO! :-",
#  "it was amazing, and arrived an hour early. You're too good to me.",
#  'did you know that suicide is the second leading cause of death among teens 10-24',
#  ' &lt; pretty graphics. so much better than minimal iconography. :',
#  "This is such  great deal! Already thinking about my 2nd trip to &amp;  haven' even gone on my 1st trip yet! ;",
#  "' flying your skies again!  take all the away from travel",
#  'Thanks!',
#  'SFO-PDX schedule is still MIA.',
#  "So excited for my first cross country flight LAX to MCO 've heard nothing but great things about Virgin America.",
#  " flew from NYC to SFO last week and couldn' fully sit in my seat due to two large gentleman on either side of me. HELP!",
#  ' :redheart: flying . :smilingface::thumbsup:',
#  'you know what would be amazingly awesome? BOS-FLL PLEASE!!!!!!!  want to fly with only you.',
#  'why are your first fares in May over three times more than other carriers when all seats are available to select???',
#  ' love this graphic.',
#  ' love the hipster innovation. You are  feel good brand.',
#  'will you be making BOS&gt;LAS non stop permanently anytime soon?',
#  'you guys messed up my seating..  reserved seating with my friends and you guys gave my seat away ... :poutingface:  want free internet',
#  "status match program.  applied and it' been three weeks. Called and emailed with no response.",
#  "What happened  ur vegan food options?! At least say on ur site so  know  won' be able  eat anything for next  hrs",
#  "do you miss me? Don' worry we'll be together very soon.",
#  "amazing to me that we can' get any cold air from the vents.",
#  'LAX to EWR - Middle seat on  red eye. Such  noob maneuver.',
#  "hi!  just bked  cool birthday trip with you, but  can' add my elevate no. cause  entered my middle name during Flight Booking Problems :cryingface:",
#  'Are the hours of operation for the Club at SFO that are posted online current?',
#  'help, left expensive headphones on flight 89 IAD to LAX today. Seat 2A. No one answering &amp; number at LAX!',
#  'awaiting my return phone call, just would prefer to use your online self-service option :(',
#  'this is great news! America could start flights to Hawaii by end of year via',
#  'Nice RT : Vibe with the moodlight from takeoff to touchdown.',
#  'Moodlighting is the only way to fly! Best experience EVER! Cool and calming. :purpleheart::airplane:',
#  'Done and done! Best airline around, hands down!',
#  'when can  book my flight to Hawaii??',
#  'Your chat support is not working on your site:',
#  'View of downtown Los Angeles, the Hollywood Sign, and beyond that rain in the mountains!',
#  "Hey, first time flyer next week - excited! But ' having  hard time getting my flights added to my Elevate account. Help?",
#  'plz help me win my bid upgrade for my flight /27 LAX---&gt;SEA!!! :wineglass::thumbsup::seat::airplane:',
#  " have an unused ticket but moved to  new city where you don' fly. How can  fly with you before it expires?",
#  'are flights leaving Dallas for Seattle on time Feb 24?',
#  "' for  good reason: you rock!!",
#  'DREAM',
#  'wow this just blew my mind',
#  'After last night !  think agree',
#  'All were entertaining',
#  'Is flight 769 on it\' way? Was supposed to take off 30 minutes ago. Website still shows "On Time" not "In Flight". Thanks.',
#  'Julie Andrews all the way though was very impressive! NO to',
#  'wish you flew out of Atlanta... Soon?',
#  'Julie Andrews. Hands down.',
#  'Will flights be leaving Dallas for LA on February 24th?',
#  "hi! ' so excited about your $99 LGA-&gt;DAL deal- but 've been trying  book since last week &amp; the page never loads. thx!",
#  'you know it. Need it on my spotify stat',
#  "' Lady Gaga!!! She is amazing! :smilingfacewithsmilingeyes:",
#  '- Carrie!',
#  'New marketing song? let us know what you think?',
#  "Julie Andrews first but Lady Gaga wow' me last night. Carrie? Meh.",
#  " called  - weeks ago about adding  flights from 2014 to my Elevate...they still haven' shown up...help!",
#  'all are great , but  have to go with :smilingfacewithheart-eyes::OKhand:',
#  'Sorry, Mary Martin had it first!',
#  "love all three but you really can' beat the classics!",
#  'Flight 0736 DAL to DCA /24 :10pm. Tried to check in could not. Status please.',
#  'heyyyy guyyyys.. been trying to get through for an hour. can someone call me please? :/',
#  "Hi, Virgin! ' on hold for 40-50 minutes -- are there any earlier flights from LA to NYC tonight; earlier than 11:50pm?",
#  'Congrats on winning the award for Best Deals from an Airline (US)',
#  'everything was fine until you lost my bag',
#  'Need to change reservation. Have Virgin credit card. Do  need to modify on phone to waive change fee? Or can  do online?',
#  ' emailed your customer service team. Let me know if you need the tracking number.',
#  'hi  just booked  flight but need to add baggage, how can  do this?',
#  'your airline is awesome but your lax loft needs to step up its game. $40 for dirty tables and floors?',
#  "not worried, it' been  great ride in  new plane with great crew. All airlines should be like this.",
#  'awesome.  flew yall Sat morning. Any way we can correct my bill ?',
#  'Or watch some of the best student films in the country at 35,000 feet!',
#  'first time flying you all. do you have  different rate/policy for media Bags? Thanks',
#  'what is going on with customer service? Is there anyway to speak to  human asap? Thank you.',
#  'what happened to Doom?!',
#  "why can' you supp the biz traveler like and have customer service like",
#  "'ve applied more then once to be  member of the crew team...Im 100% interested. -",
#  "you're the best!! Whenever  (begrudgingly) use any other airline ' delayed and Late Flight :(",
#  ' have no interesting flying with you after this.  will Cancelled Flight my next four flights  planned.',
#  'it was  disappointing experience which will be shared with every business traveler  meet.',
#  '’ having trouble adding this flight my wife booked to my Elevate account. Help?',
#  "Can' bring up my reservation online using Flight Booking Problems code",
#  "Random : what' the distribution of elevate avatars?  bet that kitty has  disproportionate share",
#  ' &lt; Flying VA But Life happens and  am trying to my trip JPERHI Can you help.VA home page will not let me ?',
#  'Why is the site down? When will it be back up?',
#  '"You down with RNP?" "Yeah you know me!"',
#  'hi,  did not get points on my elevate account for my most recent flight, how do  add the flight and points to my account?',
#  ' like the TV and interesting video . Just disappointed in Cancelled Flightled flight when other flights went out to jfk on Saturday .',
#  'just landed in LAX, an hour after  should of been here. Your no Late Flight bag check is not business travel friendly',
#  'why is flight 345 redirected?',
#  "Is it me, or is your website down? BTW, your new website isn'  great user experience. Time for another redesign.",
#  " can' check in or add  bag. Your website isn' working. 've tried both desktop and mobile",
#  '- Let  scanned in passengers leave the plane than told someone to remove their bag from 1st class bin?',
#  "What is your phone number.  can' find who to call about  flight reservation.",
#  'is anyone doing anything there today? Website is useless and no one is answering the phone.',
#  'trying to add my boy Prince to my ressie. SF this Thursday from LAX',
#  'why must  traveler miss  flight to Late Flight check  bag?  missed my morning appointments and you lost my business.',
#  'check out new music',
#  "how'  direct flight FLL-&gt;SFO have unexpected layover in Vegas  fuel yet peeps next to me bought for Vegas flight.",
#  'your no Late Flight bag check just lost you my business.  missed flight and AM apt. Three other people on flight had same exp.',
#  "- amazing customer service, again! :twohearts::twohearts: RaeAnn in SF - she' the best!",
#  'called your service line and was hung up on. This is awesome.',
#  "your site is tripping. ' trying to check in and ' getting the plain text version.  am reluctant to enter any card info.",
#  ' was scheduled for SFO  DAL flight 714 today. Changed to 24th due weather. Looks like flight still on?',
#  'has getaway deals through May, from $59 one-way. Lots of cool cities',
#  'has getaway deals through May, from $59 one-way. Lots of cool cities',
#  'has getaway deals through May, from $59 one-way. Lots of cool cities',
#  'has getaway deals through May, from $59 one-way. Lots of cool cities',
#  'Have  great week :sunwithface::airplane:',
#  'come back to already. We need you to take us out of this horrible cold.',
#  'should  be concerned that  am about to fly on  plane that needs to be delayed due to  "tech stop"?',
#  'is the best airline  have flown on.Easy to change your reservation,helpful representatives &amp;  comfortable flying experience',
#  'and again! Another rep kicked butt! Naelah represents your team so beautifully!! Thank you!!!',
#  'your beautiful front-end design is down right now; but it was cool to still book my ticket / all your back-end was secure.',
#  'Love the team running Gate E9 at LAS tonight. Waited for  delayed flight, and they kept things entertaining',
#  "Use another browser! 2015 &amp;  brand with  reputation built on tech response doesn' have  cross-browser compatible website?",
#  'And now the flight Flight Booking Problems site is totally down. Folks, what is the problem?',
#  ' like the customer service but  40 min delay just for connecting passengers seems too long. VA370',
#  'thanks to your outstanding NYC-JFK crew who moved mountains to get me home to San Francisco tonight!',
#  "you have the absolute best team and customer service ever. Every time  fly with you ' delighted. Thank you!",
#  'Do you provide complimentary upgrades to first class, if there are available seats?',
#  ' need to change my flight thats scheduled in  hours and 120 min wait time on phone. Im calling intern. Help!!',
#  'completely awesome experience last month BOS-LAS nonstop. Thanks for such an awesome flight and depart time.',
#  'How can  watch the on my JFK-&gt;SFO flight?',
#  'is flight 882 Cancelled Flightled and what do  do if it is?',
#  'you are failing your customers because your check in process does not link to TSA pre-check.',
#  'us too! Terrible airline! Just gave us  hotel hotline number and said sorry',
#  'has flight number 276 from SFO to Cabo San Lucas arrived yet?',
#  'your assistance yesterday when  Cancelled Flightled our flight was to give us  hotel hotline Shame on you!',
#  'Another delayed flight?',
#  ' need to register  service dog for  first class ticket from SFO &gt; Dulles. The phone queue is an hour or longer. Pls advise',
#  'you ROCK for making it so  can watch on my flight!!',
#  ', dropped  track on you...',
#  'always!!! Xoxo',
#  "why can' we book seats on your flights when we buy them or even during check in? Creates so much anxiety!",
#  "You' think paying an extra $100 bucks RT for luggage might afford you hiring an extra hand at",
#  'best customer service rep in the world! takes the cake!!!',
#  'Can you find us  flt out of LAX that is sooner than midnight on Monday? That would be great customer service :grinningfacewithbigeyes:',
#  "please provide status for flight 769.  cant imagine it' on time as the Web indicates dude to weather here and/or Dallas",
#  'you have amazing staff &amp; super helpful as  just ran the they have spoiled me with comfort!!!',
#  ' paid the premium to fly you across the country, you Cancelled Flight my flight and offer no check fee or upgrade love? Sad face :(',
#  "question: is it not possible to book  seat for an infant under ? It' not giving me the option but we want  seat for him.",
#  "Always have it together!!! You're welcome! RT : You're so welcome.",
#  "home to in' back to !",
#  ".  don' understand why you need  DM to give me an answer on if you have  damaged luggage policy.",
#  ". does that mean you don' have  policy for destroyed luggage?",
#  'is there special assistance if  travel alone / kids and  infant? Priority boarding?',
#  'thank you for checking in. tickets are purchased and customer is happy ;-)',
#  'is your website ever coming back online?',
#  '- Is Flight 713 from Love Field to SFO definitely Cancelled Flightled for Monday, February 23?',
#  'Is flight 0769 out of LGA to DFW on time?',
#  'my drivers license is expired by  little over  month. Can  fly Friday morning using my expired license?',
#  'having problems Flight Booking Problems on the web site. keeps giving me an error and to contact by phone. phone is 30 minute wait.',
#  'How do  reschedule my Cancelled Flightled flights online? The change button is greyed out!',
#  ' rang, but there is  wait for 35 minutes!!  can book the same ticket through  vendor, fix your site',
#  'got  flight (we were told) for :50 today..,checked my email and its for ;50 TOMORROW. This is unacceptable.',
#  "our flight into lga was Cancelled Flighted. We're stuck in Dallas.  called to reschedule, told  could get  flight for today...(/)",
#  "why don' any of the pairings include red wine?! Only white is offered :(",
#  'is the website down?',
#  '- Your site seems  little wonked right now. May want to have  look. Tried on two browsers. No CSS?',
#  "' disappointed that the agent at the designated silver status check in line closed to assist all pasengers",
#  'Plans to Include Austin to its Dallas Route - TopNews Arab',
#  'Is it normal to receive no reply from Central Baggage',
#  'at Logan airport and waiting to checkin for my 9am flight. Checkin desk not open !!!!! Why?!',
#  'to jump into the Dallas-Austin market -',
#  "Beats EPS Views, Takes On VA LUV - Investor' Business Daily",
#  'Lister to my show my on Monday 1230 130',
#  'to begin Dallas-Austin in April - 88. KETR',
#  'congrats, you just got all my business from EWR to SFO/LAX. Fuck you fl1289 SFO/EWR was the clincher...',
#  " applied over  weeks ago. Haven' heard back and ' flying this week",
#  "' love to know what your policy is for damaged luggage.",
#  'Thank you for the follow',
#  "- too many apologies! You  the worse airlines! Don' even respond to your cudtomers",
#  'shame on VA for making people spend money in stranded cities when other airlines are landing at JFK! Who will reimburse me?',
#  ' DM you',
#  'can you please have flights in SJC ?  have no choice but to fly Southwest to Vegas :wearyface::loudlycryingface:',
#  'too bad you say it takes 10 to 14 days via YOUR confirmation email. When  inquired after  weeks you claim  to  weeks!',
#  'Flight from BOS &gt; LAS tomorrow was Cancelled Flightled. No notification; wait times are + hour. Will you rebook on another airline?',
#  ':smilingfacewithsunglasses: RT : You’ve met your match. Got status on another airline? Upgrade (+restr): .',
#  'Only way to fly!',
#  'If only you guys had flights from CMH.',
#  ' lot of "apologies" being thrown out to customers from what  can see.Very sad. Thanks for nothing. Worst airline ever.',
#  'for all my flight stuff wrong and did nothing about it. Had ever',
#  'Having an issue finding  missing item on  plane. Can you help me find which airport my plane headed to next?',
#  'you will match my status? Cool!',
#  "“:You've met your match.Got status on another airline? Upgrade : ” ? :hear-no-evilmonkey:",
#  "trying to book  flight with you guys and your website won' let me... about to lose my business",
#  'you suck!',
#  'thanks!',
#  "Just DM'. Same issue persisting.",
#  "Because we never rec' Cancelled Flightlation notice we were left  no options to fly out of PS. Driving to LA for  red eye Mon  kids",
#  'trying to book  flight &amp; your site is down :beamingfacewithsmilingeyes:',
#  "You have any flights flying into Boston tomorrow?  need to be home and you Cancelled Flightled my flight and didn' do anything",
#  'you stink. Flight Cancelled Flighted from PSP to JFK and no notification or ability to rebook . better',
#  " love your guy' song! We're dancing to it for our high school dance revue",
#  "Your website is down and ' trying to check in!",
#  'done! Thank you for the quick response, apparently faster than sitting on hold ;)',
#  'nervous about my flight from DC to LAX getting Cancelled Flightled tomorrow! Just sent you  DM to help me!',
#  'cool picture of another VirginAmerica plane off our wing. What  site!',
#  'Keep up the great work :)',
#  'my goodness your people field are amazing under pressure :redheart:from Texas in crisis Please fly me to NY',
#  'Thanks for  great flight from LA to Boston! Pilots did  great job landing in the snow. Can we go back to LA now?',
#  'can you please get me to the new york area before monday afternoon',
#  'Thanks so much for the awesome support, you guys rock!',
#  "seats in Row  don' recline should mention that on your website",
#  'flight 404 delayed  hours in LA due to mechanical problems. Handle like pros but you could have tossed us  free drink.',
#  'why Cancelled Flight flights today? No precipitation to be scared of! :snowflake::snowflake::snowflake:',
#  'twitter team. you guys killed it for rescheduling me asap. thank you!',
#  "You guys charged me $100 to reschedule  flight that was then Cancelled Flighted and are now refusing to refund it. What' the deal?",
#  'can’ access your website from Safari on iPhone . Seems to work on Mac and iPad. Need iPhone to add Passbook.',
#  'on iPad and iPhone, clicking the CHECKIN link in the email  received at 24hrs before flight',
#  'your mobile site is broken, shows "{{header.elevateUser.numOfPointsAvailable || \'\' | number}} Points", won\' let me checkin',
#  ' was really looking forward to my flight. can you let me know when it will be rescheduled?',
#  'why Cancelled Flight flight VX413? One sec its delayed, on my to airport, the next its Cancelled Flightled?Gonna email or call me to reschedule?',
#  ' did it but there was  problem in the link from the email for check-in. thanks',
#  'had to change to another airline to get to DC today ... Why is able to land in DC but not you? Cost me $800 ...ugh',
#  ' was so looking forward to my first flight with you today but it was Cancelled Flightled along with the subsequent one ...',
#  'when are you putting some great deals from PDX to LAS or from LAS to PDX show me your love!',
#  'wish  can afford to fly with you next Friday going back home.. love everything about your airline',
#  'how are you gonna have  deal from Dallas to DC but no deal from DC to Dallas?',
#  'it’ just  bug report, guys',
#  'hold times at call center are  bit much',
#  'Like',
#  'Site down?',
#  'You have the best flight attendant ever!!!',
#  'Awesome! RT : Watch nominated films at 35,000 feet.',
#  'thanks so much!',
#  'Trying to reset my password, email never arrives. Help?',
#  ", the only airline based in Silicon Valley! '",
#  'Very nicely done. :clappinghands:',
#  '’ looking forward to watching the Oscars on my flight home tomorrow.  might even get something bubbly to drink! ;)',
#  'What is the reason for the delay of the departure of VX 413 from JFK this afternoon?',
#  'is todays flight from Palm Springs, Ca to JFK in NY Cancelled Flightled?',
#  'hahaha :facewithtearsofjoy: YOU GUYS ARE AMAZING.  LOVE YOU GUYS!!!:growingheart:',
#  'sounds like fun !',
#  'any updates on flight 413 from Jfk &gt; Lax',
#  'spruce moose!',
#  'the CSS on your site is  404 right now, please fix. Site unusable.',
#  "We're on flight 910 Vegas to Boston today, checked in online but our bag count didn' register. Can  fix that somehow?",
#  'classiq, luv Virgin America. Greetingz',
#  "Hi, ' trying to do check-in but the website is not working.  tried  different browsers and the problem continues",
#  'Thanks for your great customer service today &amp; for helping me get all my travel sorted out!',
#  'thanks guys! Sweet route over the Rockies',
#  'love the 90s music blasting at gate in while waiting for flight to . Only if  could get an iced coffee!',
#  "- the passenger in 7D, Flt 338 that assaulted me shouldn' have flown.  trust he' banned. Crew filed report to",
#  'current bug on website shows ‘select departure city’ when selecting destination city',
#  "luggage was severely dented/missing wheel coming off baggage claim in SAN. Luggage agent Miranda ( think) wasn' any help.",
#  'thank you for the easy itinerary shift for impending weather. Quick, painless &amp; free.',
#  "If you' love to see more girls be inspired to become pilots, RT our free WOAW event March - at ABQ.",
#  'Thanks! Good times there and back! the entire flight:cocktailglass:',
#  'beats expectations, shares take off - Santa Cruz Sentinel',
#  'any plans to start flying direct from DAL to LAS?',
#  'BIG Love/gratitude.mpower / weRin VIPswagbags',
#  ", you're doing  great job adding little luxuries/aesthetics that improve the air travel experience. Thank you. Keep it up!",
#  'requested window seat and confirmed window but got stuck in middle seat. Not  good way to treat silver member:unamusedface:',
#  'Grand Budapest Hotel',
#  'This is what you missed . Next trip to the 407.',
#  ' paid for direct flight on purpose not to have to stop for fuel exhausted frequent flier and nothing for inconvenience!',
#  'there is something wrong with you website in Safari iPhone',
#  'thanks for gate checking my baggage on your full flight dfw-lax 883 and giving me early boarding too',
#  'Already checked in so the page expired :',
#  'Boo for  not refunding  seat upgrade fee  did not want to buy in the first place!',
#  'shares rise on Q4 financial results - USA TODAY',
#  'Adds Pillows Instead of Lie-Flat Seats in First Class Arms Race',
#  ' see what you did there ;)',
#  'way to take advantage of :)',
#  "you know ' flying virgin for the fight",
#  'your inflight team makes the experience !',
#  "cutest salt and pepper shaker ever. Just when  think you guys can' get any better you just do!",
#  'moved my seat with no notice. "Better seat" is cabin select not behind the row  selected:thumbsdown:',
#  'shares up on 4Q results -',
#  'fav airline',
#  'we have  hot female pilot! Sweet! DCA to SFO! :-)',
#  ":thumbsup::thumbsup::airplane::airplane::growingheart: When are you guys going to start flying to Paris? : You're welcome.”",
#  'what is your policy on flying after surgery?  am still waiting for answer so  can tell me doctor.',
#  'already contacted Central Baggage &amp; sent DM. is charging me for the dress that was in the lost suitcase',
#  'Thank you!!',
#  "Is there anything going on with the website? 've been getting  lot of errors past 30 minutes.",
#  ' think  left something on the plane yesterday. who do  call...ah!',
#  ' need you to follow back in order to DM.',
#  'Need to start flying to . :smilingfacewithsmilingeyes::grinningface::grinningfacewithbigeyes::grinningfacewithsmilingeyes:',
#  'they told to check with the airline regulation first so that is why  contacted you.',
#  ' have just checked in flight to SFO from LAX &amp; been told as Atlantic Flying Club Gold  get no benefits?!',
#  'husband and  ordered three drinks via my screen and they never came. Awesome!',
#  'soooo are you guys going to leave the seatbelt light on all flight? You can barely call this turbulence :-)',
#  'what is your policy on flying after surgery?',
#  'posts second consecutive full-year net profit -',
#  'Funny story, your website is broken, you have missing javascript and stylesheets on the checkin process.  dislike this!',
#  'would love to do more for virgin just like  do for',
#  'Results Handily Exceed Forecasts -',
#  ' applied for  position in ,and  was wondering if you guys received my application.',
#  'achieves  second year of profitability despite revenue pressure ... -',
#  'gives positive outlook, but sees increased competition -',
#  "' trying to check into my 10:50AM CT flight tmm on the desktop website and it' not working (some sort of caching bug) SOS",
#  'weather delays &gt; next few weeks ;)',
#  'check the website before you go to the airport!',
#  'Do you guys know your check-in links from emails are broken?',
#  'pilot says we expect  choppy landing in NYC due to some gusty winds / temperature of about  degrees &amp; /the windchill -',
#  "loved it. Can' wait for Monday' return flight... Mostly just to watch the inflight safety video again.",
#  "lost my luggage  days ago on flight VX 112 from LAX to IAD &amp; ' calling every day, no response.Please give me back my stuff",
#  'The Flight Booking Problems section of your website seems to be broken on Chrome. Might wanna look into that.',
#  'Hi! Just wanted to see if you have any new routes planned this year for Newark. Love flying you guys and hope to do so more!',
#  " mean. Probably inappropriate while on board.. But, it' on!",
#  "happy to spend the day together. Let' do this!",
#  'is saving my sanity right now:',
#  'missed my flight. How does standby work?',
#  '. They were very understanding and helped me out. Thx!',
#  'brought it all the way across the country today  see',
#  'thank you!  absolutely will :smilingfacewithsunglasses:',
#  'Looks like  broken link for your assets',
#  "are you ready!? Let' say it together.. 'Noooo turbulence today!' :faceblowingakiss:",
#  'the manage itinerary section of your website seems to be broken for me',
#  "can' check in, your site looks like this every time it loads",
#  'can  help this :princess: needs urgent treatment in:UnitedStates:2y old battling cancer could  help with flights :growingheart:',
#  'may start service to Hawaii from this year',
#  'Other carriers are less than half price for  round trip fare.  am stunned.',
#  'WTF is happening in PDX Late Flight March such that one way from SFO is ~$550?',
#  "add DTW and ' sold!",
#  'How about some free drinks on the flight back for the free promo?',
#  'thanks!',
#  'momma  made it! :beamingfacewithsmilingeyes::beamingfacewithsmilingeyes::beamingfacewithsmilingeyes:',
#  'please contact me about portfolio left on flight VX 27 from JFK to SFO tonite seat 7AM. Need it returned. Call 914-329-0185.',
#  'help.  was On Flight 27 from JKF tonight. seat 7C left portfolio. Need it back!!',
#  "Seattle bound. Wifey got me the duffle for vday. She'  keeper!!! Holla!!!",
#  "my luggage is gone. 've filed my paperwork, promised  call/email. Still no resolution or response from central luggage.",
#  'Debbie Baldwin gave  performance of the safety demo this evening on VX919',
#  'Thanks!',
#  'thanks for taking care of on her flight!!',
#  'Thanks for the lovely soft views! to',
#  " requested  mileage challenge for status several weeks ago online but haven' heard back. How do  get help with this?",
#  "Just trying to book tickets to NYC and facing super fun broken styling. Don' worry, 'll keep trying :)",
#  'Many Thanks for the Follow. Looking for Any Help:smilingfacewithheart-eyes: :growingheart::UnitedKingdom::growingheart::UnitedStates::growingheart: :ribbon::globeshowingAsia-Australia::ribbon:',
#  'Nice, Lofty View .',
#  'Applied for Status Match on Feb . Got confirmation email same day. Still no news though. You guys have dropped ball Late Flightly :sadbutrelievedface:',
#  'is my new go to airline',
#  'Can You Help in need of some help in :ribbon::UnitedKingdom::ribbon::UnitedStates::ribbon:',
#  ' adore you, and am so looking forward to my flight to Austin in two weeks.',
#  ' was so glad it was mentioned.  took my first virgin flight  few years back and it was  transformative experience.',
#  'Flight Booking Problems flight to uphold my status match. Do taxes on ticket count as earned status points?',
#  'trying to check-in...but looks like your site is down?',
#  'spending my birthday night with you, DAL-DCA. Get me home!',
#  'Sent  couple messages to the email you provided but to no avail. Will try again next year. Cheers.',
#  'first time flying Virgin, went to .Thanks for the smooth ride. Easily my new fav airline!',
#  'seriously, though. will there not be direct flights from SFO-FLL in may???',
#  "It' fine. Already done with my purchase. But you should try it. Just go most of the way through then go back ",
#  'not really the experience  was hoping ,  ws forced  check in  small carry on, / nothing but empty cabin space on board',
#  'wjere is our luggage slow at lax',
#  'to jump into the market',
#  ' spoke with  representative that offered no solution,  am  loyal customer who flies on as well',
#  ' am deeply disappointed that your birthday promo was not applied to  trip  booked mere days before  received the email',
#  'what happened to direct flights from SFO-FLL? Looking in May, only see connecting',
#  '.. Can you help? Left my blazer in. Kooples jacket bag at 3rd row second seat from right gate 36 T3 lax.. Flight to sfo',
#  'partners with Checkout as mobile payment method to help boost mobile conversion rates',
#  'just promoting the product is all, had  problem with southwest and recommend noneother than the best!',
#  'love you guys, but pls get some direct routes LAS to AUS!',
#  ' would like help with some flights please.',
#  'Bruh “: Turn down for what. ”',
#  "of course!  work for and ' obsessed with the entire Virgin family!!",
#  'ok! first time flying with you tonight :)',
#  'Digging the swanky pink mood lighting during the flight from NYC to SFO. Just needs  cabaret singer. Think about it!',
#  'Done, but  need the receipt ASAP. Could you please help? -000114',
#  ' have 2d and 3d embossed badges and patches superior to the ones you are currently using.',
#  'on VX399 from JFK to LA - dirty plane - not up to your standards.',
#  'on flight VX399 headed to LA from JFK - dirtiest VA plane  have ever been on. Sad for  great airline.',
#  'got it squared away. Someone picked up as soon as  tweeted. Should have tweeted sooner. :winkingface:',
#  "your Avis rental continue button doesn' work on your website to book car. Tried  times on phone. This sucks!",
#  'delayed to10.30!!',
#  'currently in minute 10 of being on hold with cust. service. Do  need to do anything to add  lap child to my reservation?',
#  'Adds Pillows Instead of Lie-Flat Seats in First Class Arms Race by',
#  '“: Of course. Have fun celebrating!” Thanks! Happy Chinese New Year!',
#  'Flight Booking Problems last second flight for next week from SFO- to SAN any chance you want to gift me  promo code since  love you guys',
#  'Comenity Bank is  joke! Please change. Nothing but constant problems with this bank',
#  ' just did, how can  DM? Do  have to also add me?',
#  "For my Grandma Ella' 80th, she would &lt;  bday greeting from your flight crew! She was  stewardess for Eastern Airlines.",
#  'Just bought tix for ATX - Dallas route - thanks for adding that! Love yr airline &amp; yr website is BEST transactional site EVER',
#  'Anytime, sugafly.',
#  "gave  credit for my Late Flight flight yesterday. Great service !!!! That'  Wow moment! Unexpected gesture!",
#  ' need  receipt for  flight change. Can you send one?',
#  ',  submitted  status match request  while back and still haven’ heard! ’ flying on Monday. Can you look / accelerate?',
#  'had me at their safety video . . . LOVED my first cross country flight.',
#  "that doesn' look to fat to me! It looks yummy!",
#  'CEO says &amp; have strayed from low cost model.',
#  ' brilliant brisk am in Boston in cue for vx363',
#  'Atlantic ploughs  lone furrow in the',
#  'Atlantic ploughs  lone furrow in the',
#  'Atlantic ploughs  lone furrow in the',
#  'omg omg:smilingfacewithheart-eyes::smilingfacewithheart-eyes: nonstop Dallas to Austin on virgin:sparkles::facescreaminginfear::airplane:',
#  'Your planes are really pretty. Just thought  should know that. :)',
#  'when are you flying to hawaii',
#  "' pulling my hair out trying to book  flight with . Your site doesn' work on iPhone or iPad.don' have  computer",
#  'thank you',
#  "Can  get some help with  support ticket? It' been 15 days.... Incident: 150202-000419 Thank you!",
#  'good to be home',
#  ' cannot even open my laptop in seat 4C and  paid  premium for this?!! Let me out of here!',
#  ' am in seat 4C and  cannot even open my laptop; and  paid extra for this seat!!',
#  '. If only you guys were starting those flights at the end of the month! Guess ’ still road tripping on Feb 27…',
#  "thanks for that. Been needing  way to make those Austin trips from DCA, and now you've come through!",
#  'announced New Route to Austin /fares from $39/way.',
#  "Really? Sprint?  thought you guys were 'kewl'! 00",
#  'this is too cool! Never been on ur planes but now  will!!',
#  'you should have 39 dollar LAX-Las fares!!!',
#  'great. Well deserved.',
#  "FYI the info.com email address you say to contact in password reset emails doesn' exist. Emails bounce.",
#  'Status match -  weeks have gone by and no news.Flt next week - hope flt will count towards requirement. Cust Svc no help!!!',
#  'your website sucks donkey dicks. Just thought you should know. All best.',
#  'You should still develop an app - then you will be my favorite airline.',
#  'all crap channels which is why  pay to watch UK tv',
#  'got it. All set - Thanks!',
#  "no ' channel this year?",
#  'Only thing  see on passbook is Virgin Mobile Mexico. How do  integrate?',
#  'Giants and Virgin America.  match made in heaven.',
#  'thank goodness!! Also, see you friday, nwk&gt;sf.. BOOM!',
#  "how come you don' have an iPhone app? Still using and making me waste paper.",
#  'Your back of seat entertainment system does not accept credit cards that have an apostrophe in the surname.',
#  'When will VX use all  LGA slots instead of  today? Adding AUS makes this less likely :(',
#  'is helping me step up my game!',
#  " luv ur people and product!  thing is  do  charge for herbal tea but not black tea? ' not  caffeine drinker",
#  "thank you! See 'all soon! ' excited to see the expansion of destinations. Spread those wings!",
#  'announces new nonstop connecting &amp; , $39 intro:',
#  'adds Austin-Dallas Love Field route.',
#  'sad to learn you no longer fly SFO &gt; PHL. Hope it returns!',
#  '- can you tweet me the Cancelled Flight/chng fee for  flight? or can  rebook under one of your affiliates? If so, who are afiliates?',
#  "has the most INCREDIBLE customer service 've ever experienced! So refreshing!",
#  'Now, when will we see VirginAmerica come to Philadelphia (PHL).',
#  ', am  dreaming? Did you really just open up  route between Dallas and Austin?! And does this mean Houston might be next?',
#  'OMG FINALLY',
#  'to start 5xweekly flights from to on 28APR',
#  "Nice to see you expanding in Texas but don' forget about us here in .  would love to see more flights out of here!",
#  "kinda sucked my earphone jack didn' work on my flight. They may want to look into that for future passengers",
#  'Very poor experience. First computer problem now seat malfunction. Stuck. Missing meeting in San Diego.',
#  'to battle on - route via',
#  'the DAL-AUS route makes my day!!!!',
#  'awesome deals DAL-AUS for only $39 each way!',
#  ' miss the in San Jose',
#  'love it, taking on in their backyard! Consumers win when biz competes.',
#  '\u200b is flying from Love to Austin now. That is most excellent news.',
#  'can we make every VX plane with ? Why should Austin be the only one getting nerd love?',
#  'please add more frequency to PDX Portland',
#  'Congrats VX on the new route! :airplane::partypopper:',
#  ' tried that. You offered to charge me an additional $1k for  new ticket or be stranded until Thurs. 1st time, last time.',
#  'can  help with flights to get  2y old battling cancer who needs treatment in :UnitedStates: :growingheart: :ribbon: :growingheart:',
#  'Never had  bad experience before, but this one took the cake. Now extortion for carry on items as well?',
#  "Had to spend  hours worrying that items in carryon would be broken/stolen since  couldn' carry them on plane or lock bag.",
#  'All of group  was told there was no more room in the bins. when  got on the plane, was room for at least  bags in my row!',
#  'Thanks for making my flight from LAX to JFK  nightmare by forcing me to check my carry on bag at the gate. ()',
#  " have lots of flights to book and your site it not working!!!! 've been on the phone waiting for over 10 minutes..........",
#  ' am all about the in flight artisanal cheese and wine pairing.',
#  'does Virgin America fly direct from Seattle to NYC or Boston?',
#  "That' classy.",
#  "' sure  lot of your 747 and 777 JFK-LHR flights go  lot faster than 513mph with  strong tailwind.",
#  "now it' just -minus 32 minutes until my Elevate  Silver upgrade window opens . :grinningfacewithbigeyes::thumbsup:",
#  'save some for 871 tomorrow AM!',
#  'Why is it taking 12 years to fly home to Dallas? Get your shit together.',
#  'club Virgin is bumping in New York',
#  'would have been  rough trip but LUCKILY we were on  flight.',
#  'is that ??:beamingfacewithsmilingeyes:',
#  '...Please come to Minneapolis St. Paul!',
#  'YES FYI MY BFF',
#  'another perfect flight. How come on your planes, the sun visors can stay down? Other carriers make you raise them?',
#  'Nice RT : The man of steel might be faster, but we have WiFi – just saying.',
#  ' love the dancing little richard. cool beans.',
#  ' don’ use Passbook =/  still love you though &lt; :) ’ll just use my email in the future.',
#  "thanks for the free birthday points! 'all are ALL RIGHT with me!",
#  'do you have an application for iOS? Was looking and only saw Virgin Mexico :( &lt;/',
#  'Man of steel flies to more cities though...and with more frequency too.',
#  'thanks so much for sharing. Just added it to my site',
#  'Good point!',
#  '.  heard he has  virgin mobile hotspot ;)',
#  'you got cheese pLate Flights too.',
#  'On all your flights?',
#  'Dad on Segway is the best part of this whole infographic!',
#  'Are there any plans for  short haul airline in Europe? Would defiantly fly with you guys :)',
#  'wifi AND better seating.',
#  "how come ABC is the only one of the network channels you don' have?",
#  'started my flight with  scolding for using an overhead bin that was then offered to the person seated next to me.',
#  ". not only was it great, but you return my calls the day after. Couldn' ask for more.",
#  "While other airlines weren' Cancelled Flighting flights into BOS, and helping their customers get home, Virgin was saying Good luck!",
#  "Dear Virgin customer, while you're stranded in SF for  days &amp; $1000cost- we'll do the very least we can to accommodate you!",
#  'should use this in their next airline commercial lol ::',
#  'Grouping Virgin in with the others now. BOS weather has exposed their actual Cus Serv model. Never Flight Booking Problems with Virgin again!',
#  "As one of the travelers affected by the Boston storm, ' shocked at Virgin' complete apathy toward their customers.",
#  'Umm so no reason as to why this is? Is there someone different  should contact (or contact me) to get  definitive answer?',
#  'Trying to make the change in advance (not just 24 hours prior)…tried it online earlier and it wanted $300 in change fees.',
#  "so loyal that ' driving to from , to fly Virgin, since you cut flights ;)",
#  'Any way to change from Main Cabin to Main Cabin Select (on same flight) without paying  change fee penalty?',
#  'you guys are perfect as always! &lt;',
#  "thanks! 'all have some of the best customer service left in the industry.",
#  'Can you give me Silver Status for 12 months?',
#  "really wish you' fly out of those fares are amazings",
#  'mood lighting on point:raisinghands: Reclining my seat, kickin up my feet:zzz:',
#  'my flight (6000) scheduled for 1pm departure still says on time but no plane at gate. Any update on how long of  delay?',
#  "my group got their Cancelled Flightlation fees waived but  can' because my ticket is booked for /18? Your reps were no help either :poutingface:",
#  'Are there any sign up bonuses to enroll in Elevate?',
#  'just got on the 1pm in Newark home to LA. Your folks at EWR are incredible',
#  'morning. If  have  question regarding elevate points &amp; flights can  DM you?',
#  'still waiting to see :disappointedface:',
#  "was wondering if you guys recieved my dm and we're able to potentially respond asap",
#  'Flying LAX to SFO and after looking at the awesome movie lineup  actually wish  was on  long haul.',
#  '“: Book out of town with fares from $59/way (+restr). ”',
#  'thanks',
#  'Thanks for taking care of that MR!! Happy customer.',
#  "still no refund or word via DM. Please resolve this issue as your Cancelled Flightled flight was useless to my assistant' trip.",
#  "Delayed due to lack of crew and now delayed again because there'  long line for deicing... Still need to improve service",
#  "thanks -- we filled it out. How' our luck with this? Is it common?",
#  'Your ERI-ORD express connections are hugely popular .. now if only we could have an ERI-EWR hop! :)',
#  'even on international flight Glasgow to the ..? Then what about orlando to Newark? All 90 mins?',
#  'you think you boarded flight AU1066 too early?  think so.',
#  " understand, but it' tough when there is no way to get to the airport / serious risk of an accident. It'  steep price.",
#  'Gate agent hooked me up with alternate flights. If you have  way to PREVENT the constant issues, that would rock.',
#  'flying gla-mco in  few weeks. How long do we have to be at airport for before departure for both international and domestic? Ta',
#  'thanks',
#  'Thanks. It is on the same ticket.',
#  'why not? Is it  law or  policy?',
#  'is the worst. Nonrefundable First class tickets? Oh because when you select Global/FC their system auto selects economy /upgrade.',
#  "So  can buy tix  days before flight but can' transfer the tix. Flawed security logic. Flawed customer service",
#  ' did start  claim but -10 weeks is unrealistic, am  really supposed to go that long with out  car seat for my child.Ridiculous!',
#  'follow me please this airline is beautifull :heartsuit:',
#  "no  don', but ' sure United have my info on its system.",
#  "if the car seat is lost should just reimburse me for  new one, this is not  pair of shoes, it'  necessity for my child",
#  'Just submitted my response on the link you sent.',
#  'yes, David Allan send an email with this number (KMM24999563V99860L0KM) and case',
#  'that totally sucks my cousin worked at PHL said',
#  'just wanted to let you know how wonderful Rosetta the gate agent was working flight 6457 Dan to Ase. Let her know she wasappreciated',
#  'yes,  paper voucher that  got on January 26th 2015',
#  'beginning of Feb  called United they said they would send another voucher by mail. Never got anything.',
#  'the internet is  great thing.  am emailing executives in your company, maybe they will respond to me in  timely manner.',
#  'Do  need to use  Chase United Club pass for my 8yr old son, or can he come in with me on my pass?',
#  'and what am  suppose to do with that number?',
#  'thats weak. See ya :wavinghand: Hey !!',
#  ' flew back  other company since United didnt have an earlier flight',
#  ' lost  voucher that  was given in Miami aeroport on jan 26.  did not use it.',
#  ' am trying to book awards for September and need flights on but they will not show even / many award seats availab',
#  " sure did.  had to drive  total of  hours to get my own bag. ' like to explain that debacle but no one wants to talk to me.",
#  "Gee that' like almost caring about ppl more than $$. Think ' more int in having  trusted adult / daughter .",
#  'See? We were told repeatedly that the pilot was Late Flight and kept getting Late Flightr. After we boarded, there was  defibrillator issue.',
#  "why no preferred security line anymore. My TSA pre-check didn' pull on my partner flight!",
#  "Airport need to indicate different gate' for terminals &amp;.",
#  'yes please!  am newly married and trying to update my last name on  preexisting international flight! It seems so easy, but...',
#  "How does United refuse to reissue  $400 lost voucher when their plane didn' take off due to mechanics?",
#  'also during the run  was instructed to do,  shattered my computer.',
#  "yes, we've been with the agents for the last 50 minutes. One of the agents have been very rude, but thankfully Ladan has been nice.",
#  "that' right- with an overnight Miami.",
#  'Have clients with an 11 hr layover at IAH (during the day). Will they have to claim &amp; recheck luggage. Or will it be taken care of?',
#  ' am trying to find out if the loaner seat is new or used,  used car seat is illegal according to safety regulations',
#  ' DMed you the details',
#  'iah to charlotte. Baggage claim rep latrice . non existent, Ignored customer then inappropriately touched customer',
#  'Kewl. Will also let them know the overhead bin over my row was "Inop".  love  good abbreve.',
#  '- thanks for your help...got me what  need, but its an issue with .  guess  sit awhile longer.',
#  '-  would have loved to respond to your website until  saw the really long form. In business the new seats are bad',
#  ' refund and flight vouchers or another flight on  different airline at your expense for today.  hour drive is very inconvenient',
#  "then why have  not received my call back its been  days...it' an infant car seat how am  supposed to go anywhere with my child",
#  'thanks again for your concern.  will contact customer care upon our return from Australia.',
#  "well sitting on the ground 'on time' but waiting for  gate....again",
#  '"Airport snow removal method ..." Keep up the good work folks, this is where Cessna\' become 747\'!',
#  "No,  need you guys to not over book planes. It' not  concern, 'll just travel with someone else moving forward.",
#  ' measly $50 -certificate is not how you appreciate loyal customers after they wait 3hrs on the tarmac during UA1116.',
#  "When will email address/username sign-on be available? It' been  while.",
#  'Thank you for that. Am  able to claim any interim expenses or is the cost of the stuff up on me?',
#  'rude rude',
#  "- Why can'  get  boarding pass for my Austrian Airlines codeshare flight. Rebook incls   hour layover &amp;  am stuck outside sec",
#  '. .. received on other flights. truly breaks guitars.',
#  "just flew to paid $100 from  third suitcase which didn' even make it on the plane! Besides for the impolite service...",
#  'My bag is still in Colo Springs.  am disabled and have to search an unfamiliar airport and look for my bag. Not  good outcome',
#  "Shame that there' no flex to tickets transfer rules. Even calling from Neurosurgery ICU isn' enough!",
#  "No. Denver said they don' handle baggage that made it to Colo. Springs. They gave me an 800 number to call. No help there either.",
#  'you guys need some serious training in customer service. Too many better options to put up with the way you guys handle ur mistakes',
#  '6533 ORD to DCA',
#  'once he found out we had  problem he avoided me like the plague. Was told "we can\' find  supervisor."',
#  "ZCC82U Cancelled Flight flight 16h in advance??? Need connect flight reschedule so the link isn' helping. Help!? Gf waited months to see me.",
#  ' will not be flying you again',
#  "in addition, my first flight was delayed an hour and ' arriving at my destination  hrs Late Flight.",
#  "Cancelled Flighted our flight, didn' rebook us on added flight, now have to drive from  Denver to KC....thanks!",
#  'your announcement for pre boarding only addresses mobility. My disability requires me to travel with  lot of stuff. Do  preboard?',
#  ' flew United last month and the experience was AWESOME!',
#  'our travel booked thru United group dept. Okc ticket agent less than willing to help with our connection in LAX.',
#  ' upset with your disability "services". When  told one of your employees  was carrying medical equipment she was very rude.',
#  "thnx for quick reply but don' think you can assist. Our intl grp will be put to considerable inconvenience today.",
#  "wont transfer flight ticket to accompany an 11 yr old who' active military mom had to have emergency brain surgery? WOW!!",
#  ' WEEKS Late FlightR AND  STILL HAVE NOT RECEIVED MY MILES FROM THE MileagePlus Gift Card $150 STARBUCKS CARD  HANDED OVER!!!',
#  "as  1k, ' always hoping for improvement.",
# ...
#  'Made the upgrade list. Will fly 1st tomorrow (for 40 min) for the first time ever! :raisinghands:',
#  'not just refunded, but for those of us who are on vacation to get  free room night to make up for making us sleep in DIA',
#  "Thanks for the reminder. It' been  fun ride.",
#  " received my luggage that also looked to be left in the snow when  arrived. ' asking for all 50 people to be refunded.",
#  "updated A320 aircraft has wifi and device entertainment but no outlets.  don' get it. How can  charge devices?",
#  'was no one between the scan and inside the plane.  just asked the people in line around me where the plane was going',
#  ' gate changes, two delays. Even the crew thinks the airline sucks',
#  "' very frustrated and have wasted  days now due to your equipment failures.",
#  "computers are down but you stopped giving updates and took my flight info off the app. That' just ridiculous keep people updated!",
#  "Soooo, it' been 15 days and you've offered no response. So  assume poor treatment by gate agents is the norm now?",
#  'Terrific. Many thanks. Looking forward to being back on UA tomorrow. Had  great flight up to Vancouver.',
#  'Calls to 800 resulted in 2hrs of hold time &amp; 2day wait to check suspect code share fare. Nothing investigated—my time wasted (/)',
#  "It' taken ~ weeks for Cust Care to respond to Case , requesting  refund for wi-fi not working. Where can  get an update?",
#  ' appreciate your efforts getting me home!',
#  "That' correct—'ve spent hours trying to book online only to receive an error when clicking final purchase button. (/)",
#  'Today was not your finest. All could have been prevented by one gate agent advising 200 passengers.',
#  'what is the real deal with the delay on flight UA 1032 from Denver to Vegas?',
#  'UA63 from Madrid arrived no agent mass confusion we sent to and fro by  UA employees. MaryJo was rude and unhelpful.',
#  "system failure again = bad trend. Software projects are like flying an airplane; there' no such thing as an emergency takeoff.",
#  'lots of reports of system failures delaying flights over the last week. Currently sitting on the tarmac at OGG for over an hour.',
#  "rebooting Chicago dispatch system, need as ' tired of sitting on planes",
#  "despite shaky connections, looks like 'll get home tonight. Great job, - was touch and go for  while..",
#  ', however, is completely under your control—the price was and still is displayed on .',
#  'the aircraft closest to gate was for the other flight and the one closest to our gate was going to Chicago.',
#  'can you tell me how to file  claim for clothing that had to be purchased?',
#  'comically on the return flight from ASE there were two United flights boarding at adjacent gates and not clear which plane to board',
#  'GRK13575M is the file reference',
#  'we would...how do  contact you to discuss?  few poor experiences with customer service but would give it  shot!',
#  'UA 746. Pacific Rim and Date Night cut out. Not constantly or randomly, but one spot, repeatably.',
#  'Been trying since 1230 to file  report.',
#  " send an email about my bad experience and you send back  generic response. Yet another reason why 'll never fly with you again.",
#  'My mom left her Kindle on flight 1544 today. Burgundy case with  light. Seat 27D. Did anyone find it?',
#  'here is the ticket 0162424965446 please refund my unnecessary upgrade fee',
#  "is horrible!! They lost our carseat and expect us to use  loner carseat, safety regulations say it' illegal to use  used car seat",
#  'thank you.',
#  "Decisions Decisions : We' love for you to try our service. We offer status match too. ^KP”",
#  "Need more info on that! : We have great amenity kits. PJ' not included. We status match AA. ^KP”",
#  ':  don\' care that  link showed me  "wrong" price on your site—it\' your site &amp; responsibility to ensure correctness.',
#  'Do you have any flights with lie flat seating from STL to PDX around the date of March ?',
#  "He needs to get to home the 24th, they're telling him it'll be the 25th night. Is there compensation or anything that can be done?",
#  "“: The baggage fee is waived for Premier members. Please see . ^JP” what' the point of membership?",
#  'wonderful bag claim people - finally have my bag. But why did  catch earlier flight? Original flight just landed.',
#  'Dmed you. Thank you',
#  "thanks we'll be in touch!",
#  "Thanks to Karen Salisbury at IAH for amazing customer service! Found my daughter' bag lost on UA1516. Made her day!",
#  ' days Late Flightr and my bag has not left IAD, United is not helping at all. Everyone tells me  different story',
#  "hi, when do direct flights from Houston to Reno begin? Don' see any days in March?",
#  "like continental' chicken feat fairs",
#  'can you assist with current flight status for flt 1016 out of DFW tomorrow at :55am?',
#  ' left my comment with customer care. Thanks for contacting me.',
#  'how do you lose  gate checked bag DEN to ORD? Direct flight. Ugh.',
#  "caught earlier flight to ORD. Gate checked bag, and you've lost it at 'Hare. original flight lands in 20minutes. !",
#  "Yes!! Thanks so much!!! :purpleheart:“: We see you spoke with our Reservations team and they've reinstated the flight. Thanks. ^EY”",
#  'captain "on behalf of the front office, welcome on board.".... Never heard that before.  laughed...hard.',
#  'Can you please follow for  Dm on  missing bag?',
#  'to be clear on my luggage comment,  am referencing the photo attached. Flight 6232 to JAC',
#  'These are great fares!!!!!',
#  ' left an item on the plane and have been calling non stop and no one has been answering can you please help',
#  "awesome 'll book my next Christmas vacatinn this December any other ways you want to devalue mileage plus.",
#  "what'  good number to call to speak with someone about how you can fix what you did to 50 people and their luggage on Saturday?",
#  'THANK ! Secured room for the night Thx to VERY helpful customer service rep . Dorns..  thanked her.. Can  ?',
#  "where' my damn bag??",
#  'well someone should tell that to the employees at the Denver baggage claim. Still no bag!!!!',
#  'Greetings. UA Club member here. Any idea if  can use the Air Canada Lounge at YVR. Flying UA tomorrow.',
#  'how is Mexico not international from the us?',
#  "diverted and missed our connecting flight. Was just told that my bag is on it' way to MSY. If you only had people that cared",
#  "Male agnt in LAS threatens Canadian cust when cust takes pic of him at gate after agents announce can' help rebook. ?",
#  'we just want to go home tonight - why did you Cancelled Flight the last leg of our reserv. /out our permission??!',
#  'Stressed and rude agents. Overwhelmed by delyd flight LAS-DEN 1657. Yelling at several people. Not pretty. This is ??',
#  'landed in Boston at  last night. The 15 hours of traveling was rough tho.',
#  'FAIL You Cancelled Flightled our flight frm GJT and then used our reserv home to IAH (from SEA) for reFlight Booking Problems /out OUR PERMISSION!!',
#  'Just sent thank  RT : Please DM your confirmation number if reFlight Booking Problems is needed. Thank you. ^EY',
#  'has made my no fly list. Other airlines wait when connector Late Flight. Stuck in IAH.',
#  'so what’ the deal? Do  provide voucher for overnight or am  cozy on the floor at ?',
#  'also, the mere fact that  have to go online to issue  statement vice calling and talking to some directly is one good example.',
#  'thank you.  flew into Newark from Vail/Eagle.',
#  ' have  weekend of dealing with your company that would say otherwise.',
#  'now what?!? flight was gone when  got off plane!',
#  "the proper response: sorry for your wait, what flight were you on so we can look into the issue. That' how would handle.",
#  'your customer service is terrible! Stood inline  hours no flights and  hours Late Flightr still no bag',
#  'please upload the March on-demand entertainment listing on your website! :airplane:',
#  'So you are inadequate by accident?',
#  'Denver International Airport',
#  'Thank you for responding so quickly with  helpful tool!',
#  'boarding time shows 35 min and your gate agent started at 45. showed up at :00 and they had to check bag.',
#  "Agent in LAS letting 20 customers know they can' help them rebook delayed flight to DEN",
#  'empathizes / my disappointment that 1stClass flight /nonworking entertainmnt is worth $50.',
#  "...and when that doesn' work...",
#  'did you have seen my message today?? About  mcdonnell Douglas dc 10 model??  will hear it if you read it, Goodnight now',
#  "searched for mileage tickets to BOM couldn' find  single one is saver awards -  see how you play. Earn miles but can' use them.",
#  'flight arrives 30 minutes early, but then have we to wait for an hour for our bags.',
#  "That' not the issue. The fact that no one even called (despite promises) to confirm the bag' location is.",
#  "what'  girl gotta do to get  flight name change when SHE bought one for  mean ex boyfriend and needs  girl' trip stat?!",
#  'thank you. We are signed up for notifications. We shall watch and wait! :snowflake::snowflake:',
#  'still waiting to hear back. My wallet was stolen from one of your planes so would appreciate  resolution here',
#  ' would love if someone could get me back to Austin tonight and  do not wish to wait til tomorrow morning.',
#  'or has lost my baggage… heard different things from different employees of . has said nothing.',
#  'cs thinks that miles can repair the damage done, it will be interesting if they travel in and exp the worst flight ever!',
#  ' have  0530 flight out of DFW on Tuesday. How far in advance will you give notice if Cancelled Flightled?',
#  ' am signed up for notifications. This is the first trip  was not updated on. Not sure why this happened.',
#  "Thank you. Took care of everything and made it right. That' the experience ' used to. Opened the app to find flight changed.",
#  "that is not in line with your responses here. And now ' waiting until tomorrow morning because all the flights are overbooked.",
#  ' took the exact same aircraft in to LAX  days ago. It fit, no problem. The agent today told some nonsense about  policy change',
#  'your helpful agents in Club helped.  am just out baggage fees and  night of my life.stop doing business with',
#  'never heard of this?',
#  'doesn\' charge ticket change fees. Do they not incur the same mysterious "costs" that you incur, ?',
#  'Exhausted &amp; frustrated! Link to  FB post abt my travel issue',
#  " was denied getting on the plane / getting the chance to prove it fits. ' not  rookie. Read my bio.",
#  "that' exactly the point. It fits. ' premier access. Boarding group . This was  return ticket. 've been doing this for 15 yrs",
#  "'ve never experienced worst customer service. Placing blame on codeshare partners and not assuming responsibility is unacceptable",
#  'currently on board so not now. Check in was terrible. Staff rude. Expensive luggage thrown around etc.',
#  'fucked up, then voided my ticket, and KEPT MY MONEY. Not even an apology.  will never fly with your airline again.',
#  "has the WORST customer svcs! This Kevin rep at call center must be investigated. My baggage' lost and there' no help but argument!",
#  'should NOT sell tickets for on . has terrible service and UA staff cannot reach Silver',
#  'Just got demoted from Gold cuz my hubby got 100% of the PQD, tho there were enuf $ spent for  Golds..discrimination/angry.',
#  'Thank you!',
#  'When will direct flights from Belfast Intl to Newark resume from their winter break? Thanks.',
#  'My favorite way to travel! Thank you!',
#  'yes, after this awful weather it appears  can get home',
#  'yes lots. You have terrible customer service at Newark and despite raising  complaint there we were ignored hence the tweet',
#  'Lovely new plane from LGA to ORD but no power outlets?',
#  "but if  tweet the ID number, won' that reveal my home address to anyone on the web?",
#  ' filed  delayed bag report on Saturday! my flight was Cancelled Flightled and  never went anywhere!',
#  'the person is currently bettween gates 71A and 73 in LAX',
#  ' need it there before she lands so she can have the EWR baggage claim file to have it sent but the employee has not droppeditoffyet',
#  'rarely ceases to amaze...for the worse.  hope this is the last time  "have" to fly with you.',
#  'thank you for the quick response but  cannot dm you until you follow me as well',
#  'iCloud it is not there yet -- PLEASE HELP 917 703 1472',
#  ' need the phone number to baggage claim in LAX, my mom left her phone and someone called saying they would put it there but on',
#  ' did... no response back',
#  'this is atrocious customer service.',
#  'will not have to honor absurdly low mistake fares. vía',
#  'delayed departure to check bags at gate claiming space filled and walk on to open spaces  delay',
#  'you Cancelled Flighted our flights for no reason &amp; now we have been on the phone for AN HOUR on our vacation. Why?',
#  "THAT' your response? Shaking my head back and forth with  tsk. You can do better-from customer service to your apology",
#  "thanks! It' 35K miles from RTB to Europe, to do  multiple destination so we could stop over in US on way/way back- mileage diff?",
#  'of course  did. The bag should be here by now :(',
#  'you are the worst.  will avoid you like the plague.',
#  'is the worst airline in the world.',
#  'someone needs to DM me and resolve this correctly. Extremely disappointed with the service  received. Terrible management.',
#  'Premier Gold desk changes flight. Waives fees. Gives me wrong flight. Now Jana Acosta in Salt Lake refuses the same service. Angry.',
#  ' will give you one thing, you are consistent but unfortunately you are consistent at not doing your job well',
#  " will but right now ' to angry",
#  'first time flying with United. Also last time. back to for me.',
#  ' used to be  committed flyer until merger.  remember now why  switched to',
#  'the least you could do is offer me  ticket in coach instead of just Cancelled Flighting my reservation because of your glitch!!!',
#  "' saying  made the flight but with poor/non-communication, unaccounted for lost time &amp; lots of frustrated flyers standing around",
#  ' think DM would be better',
#  'gate announcement states delay due to maintenance yet app says Late Flight arriving aircraft tell the truth!',
#  "you are easily the worst company  have ever experienced. You have lost someone' personal possessions &amp; you couldn' care less!....",
#  'how can your app show arriving aircraft is early but departing flight is delayed due to Late Flight arriving aircraft?',
#  'already did that at the airport and 12 hrs Late Flightr its still not here! you guys are really killing me today. trying to stay positive..',
#  "once united' service levels reaches those of Etihad or lets be more realistically Lufthansa then ill consider it again",
#  'really? Someone called in sick and then someone FORGOT to call  replacement?! Now an hour Late Flight to take off.',
#  'Asked Flight attendant what typical compensation would be &amp; says we might get free TV.',
#  'done',
#  'Thank you, ^JH, appreciate the prompt responses--me and other passengers will be doing so.',
#  'has been such  disappointment today. Simply put. Rather unpleased with things currently. Flight delayed; cant wait to just get home',
#  'During the same round trip, my NON-English speaking friend was stranded TWICE for 12+ hours each time! Most staff members were rude.',
#  'found  group of people who actually hates people more than ISIS, thats right United Airlines.',
#  'Nope. Walked up &amp; down the ORF terminal, &amp; not  United agent to be found. Showed up last minute to board us. Many panicked people',
#  'thank you',
#  'by the time  finally get to Dallas  could have driven with less frustration and cheaper.',
#  "' trying to get to my final destination, we need compensation. Just about 2hrs of personal time wasted.",
#  'that guy really has no customer service clue.Could have spent effort clearing bins for rollerboards instead of art projects in mine!',
#  'he has no priority and Iove it',
#  'Pleased to be  Premier Platinum',
#  ...]

# %%
# Penultimate stage of preprocessing tweets: treatment of contractions, most common emoticons, digits, 
# capital letters, double space, token constituted by only one character, punctuation marks, etc.
# The preprocessed tweets are saved in the 'tweets_cleaned_1' list.

tweets_cleaned_1=[]
for s in range(len(tweets_cleaned_0)):
    tweet = re.sub(r"that's","that is", str(tweets_cleaned_0[s]))
    tweet = re.sub(r"there's","there is",tweet)
    tweet = re.sub(r"you've","you have",tweet)
    tweet = re.sub(r"I've","I have",tweet)
    tweet = re.sub(r"they've","they have",tweet)
    tweet = re.sub(r"we've","we have",tweet)
    tweet = re.sub(r"there're","there are",tweet)
    tweet = re.sub(r"what's","what is",tweet)
    tweet = re.sub(r"what've", "what have", tweet)
    tweet = re.sub(r"where's","where is",tweet)
    tweet = re.sub(r"it's","it is",tweet)
    tweet = re.sub(r"who's","who is",tweet)
    tweet = re.sub(r"i'm","i am",tweet)
    tweet = re.sub(r"they're","they are",tweet)
    tweet = re.sub(r"she's","she is",tweet)
    tweet = re.sub(r"he's","he is",tweet)
    tweet = re.sub(r"it's","it is",tweet)
    tweet = re.sub(r"there're","there are",tweet)
    tweet = re.sub(r"who're","who are",tweet)
    tweet = re.sub(r"ain't","am not",tweet)
    tweet = re.sub(r"wouldn't","would not",tweet)
    tweet = re.sub(r"shouldn't","should not",tweet)
    tweet = re.sub(r"can't","can not",tweet)
    tweet = re.sub(r"couldn't","could not",tweet)
    tweet = re.sub(r"we'll","we will",tweet)
    tweet = re.sub(r"I'll","I will",tweet)
    tweet = re.sub(r"you'll","you will",tweet)
    tweet = re.sub(r"she'll","she will",tweet)
    tweet = re.sub(r"he'll","he will",tweet)
    tweet = re.sub(r"it'll","it will",tweet)
    tweet = re.sub(r"won't","will not",tweet)
    tweet = re.sub(r"could've","could have",tweet)
    tweet = re.sub(r"couldn't've","could not have",tweet)
    tweet = re.sub(r"didn't","did not",tweet)
    tweet = re.sub(r"don't","do not",tweet)
    tweet = re.sub(r"doesn't","does not",tweet)
    tweet = re.sub(r"everyone's","everyone is",tweet)
    tweet = re.sub(r"giv’n","given",tweet)
    tweet = re.sub(r"hasn't","has not",tweet)
    tweet = re.sub(r"haven't","have not",tweet)
    tweet = re.sub(r"hadn't","had not",tweet)
    tweet = re.sub(r"who're","who are",tweet)
    tweet = re.sub(r"aren't", "are not", tweet)
    tweet = re.sub(r"isn't", "is not", tweet)
    tweet = re.sub(r"let's", "let us", tweet)
    tweet = re.sub(r"mustn't", "must not", tweet)
    tweet = re.sub(r":D", "smiley", tweet)
    tweet = re.sub(r":-D", "smiley", tweet)
    tweet = re.sub(r":\)", "simple_smile", tweet)
    tweet = re.sub(r";D", "wink", tweet)
    tweet = re.sub(r";D", "wink", tweet)
    tweet = re.sub(r":-\)", "simple_smile", tweet)
    tweet = re.sub(r";\)", "wink", tweet)
    tweet = re.sub(r";-\)", "wink", tweet)
    tweet = re.sub(r":P", "stuck_out_tongue", tweet)
    tweet = re.sub(r":-P", "stuck_out_tongue", tweet)
    tweet = re.sub(r";P", "stuck_out_tongue_closed_eyes", tweet)
    tweet = re.sub(r";-P", "stuck_out_tongue_closed_eyes", tweet)
    tweet = re.sub(r":\(", "worried", tweet)
    tweet = re.sub(r":-\(", "worried", tweet)
    tweet = re.sub(r":'\('", "cry", tweet)
    tweet = re.sub(r'\W', ' ', tweet)  
    tweet = re.sub(r'\d', ' ', tweet)
    tweet = tweet.lower()
    tweet = re.sub(r'^br$', ' ', tweet)
    tweet = re.sub(r'^[a-zA-Z]\s', ' ', tweet)
    tweet = re.sub(r'\s+br\s+',' ',tweet)
    tweet = re.sub(r'\s+[a-z]\s+', ' ',tweet)
    tweet = re.sub(r'^b\s+', '', tweet)
    tweet = re.sub(r'\s+', ' ', tweet)
    tweet = tweet.split()
    tweet = ' '.join(tweet)
    tweets_cleaned_1.append(tweet)

# %%
# The list containing each of the pre-processed tweets is printed to verify that the previous process has been
# performed correctly.

tweets_cleaned_1
# Out:
# ['what said',
#  'plus you have added commercials to the experience tacky',
#  'didn today must mean need to take another trip',
#  'it really aggressive to blast obnoxious entertainment in your guests faces amp they have little recourse',
#  'and it really big bad thing about it',
#  'seriously would pay flight for seats that didn have this playing it really the only bad thing about flying va',
#  'yes nearly every time fly vx this ear worm won go away simple_smile',
#  'really missed prime opportunity for men without hats parody there',
#  'well didn but now do',
#  'it was amazing and arrived an hour early you re too good to me',
#  'did you know that suicide is the second leading cause of death among teens',
#  'lt pretty graphics so much better than minimal iconography',
#  'this is such great deal already thinking about my nd trip to amp haven even gone on my st trip yet',
#  'flying your skies again take all the away from travel',
#  'thanks',
#  'sfo pdx schedule is still mia',
#  'so excited for my first cross country flight lax to mco ve heard nothing but great things about virgin america',
#  'flew from nyc to sfo last week and couldn fully sit in my seat due to two large gentleman on either side of me help',
#  'redheart flying smilingface thumbsup',
#  'you know what would be amazingly awesome bos fll please want to fly with only you',
#  'why are your first fares in may over three times more than other carriers when all seats are available to select',
#  'love this graphic',
#  'love the hipster innovation you are feel good brand',
#  'will you be making bos gt las non stop permanently anytime soon',
#  'you guys messed up my seating reserved seating with my friends and you guys gave my seat away poutingface want free internet',
#  'status match program applied and it been three weeks called and emailed with no response',
#  'what happened ur vegan food options at least say on ur site so know won be able eat anything for next hrs',
#  'do you miss me don worry we will be together very soon',
#  'amazing to me that we can get any cold air from the vents',
#  'lax to ewr middle seat on red eye such noob maneuver',
#  'hi just bked cool birthday trip with you but can add my elevate no cause entered my middle name during flight booking problems cryingface',
#  'are the hours of operation for the club at sfo that are posted online current',
#  'help left expensive headphones on flight iad to lax today seat no one answering amp number at lax',
#  'awaiting my return phone call just would prefer to use your online self service option worried',
#  'this is great news america could start flights to hawaii by end of year via',
#  'nice rt vibe with the moodlight from takeoff to touchdown',
#  'moodlighting is the only way to fly best experience ever cool and calming purpleheart airplane',
#  'done and done best airline around hands down',
#  'when can book my flight to hawaii',
#  'your chat support is not working on your site',
#  'view of downtown los angeles the hollywood sign and beyond that rain in the mountains',
#  'hey first time flyer next week excited but having hard time getting my flights added to my elevate account help',
#  'plz help me win my bid upgrade for my flight lax gt sea wineglass thumbsup seat airplane',
#  'have an unused ticket but moved to new city where you don fly how can fly with you before it expires',
#  'are flights leaving dallas for seattle on time feb',
#  'for good reason you rock',
#  'dream',
#  'wow this just blew my mind',
#  'after last night think agree',
#  'all were entertaining',
#  'is flight on it way was supposed to take off minutes ago website still shows on time not in flight thanks',
#  'julie andrews all the way though was very impressive no to',
#  'wish you flew out of atlanta soon',
#  'julie andrews hands down',
#  'will flights be leaving dallas for la on february th',
#  'hi so excited about your lga gtwinkal deal but ve been trying book since last week amp the page never loads thx',
#  'you know it need it on my spotify stat',
#  'lady gaga she is amazing smilingfacewithsmilingeyes',
#  'carrie',
#  'new marketing song let us know what you think',
#  'julie andrews first but lady gaga wow me last night carrie meh',
#  'called weeks ago about adding flights from to my elevate they still haven shown up help',
#  'all are great but have to go with smilingfacewithheart eyes okhand',
#  'sorry mary martin had it first',
#  'love all three but you really can beat the classics',
#  'flight dal to dca pm tried to check in could not status please',
#  'heyyyy guyyyys been trying to get through for an hour can someone call me please',
#  'hi virgin on hold for minutes are there any earlier flights from la to nyc tonight earlier than pm',
#  'congrats on winning the award for best deals from an airline us',
#  'everything was fine until you lost my bag',
#  'need to change reservation have virgin credit card do need to modify on phone to waive change fee or can do online',
#  'emailed your customer service team let me know if you need the tracking number',
#  'hi just booked flight but need to add baggage how can do this',
#  'your airline is awesome but your lax loft needs to step up its game for dirty tables and floors',
#  'not worried it been great ride in new plane with great crew all airlines should be like this',
#  'awesome flew yall sat morning any way we can correct my bill',
#  'or watch some of the best student films in the country at feet',
#  'first time flying you all do you have different rate policy for media bags thanks',
#  'what is going on with customer service is there anyway to speak to human asap thank you',
#  'what happened to doom',
#  'why can you supp the biz traveler like and have customer service like',
#  've applied more then once to be member of the crew team im interested',
#  'you re the best whenever begrudgingly use any other airline delayed and late flight worried',
#  'have no interesting flying with you after this will cancelled flight my next four flights planned',
#  'it was disappointing experience which will be shared with every business traveler meet',
#  'having trouble adding this flight my wife booked to my elevate account help',
#  'can bring up my reservation online using flight booking problems code',
#  'random what the distribution of elevate avatars bet that kitty has disproportionate share',
#  'lt flying va but life happens and am trying to my trip jperhi can you help va home page will not let me',
#  'why is the site down when will it be back up',
#  'you down with rnp yeah you know me',
#  'hi did not get points on my elevate account for my most recent flight how do add the flight and points to my account',
#  'like the tv and interesting video just disappointed in cancelled flightled flight when other flights went out to jfk on saturday',
#  'just landed in lax an hour after should of been here your no late flight bag check is not business travel friendly',
#  'why is flight redirected',
#  'is it me or is your website down btw your new website isn great user experience time for another redesign',
#  'can check in or add bag your website isn working ve tried both desktop and mobile',
#  'let scanned in passengers leave the plane than told someone to remove their bag from st class bin',
#  'what is your phone number can find who to call about flight reservation',
#  'is anyone doing anything there today website is useless and no one is answering the phone',
#  'trying to add my boy prince to my ressie sf this thursday from lax',
#  'why must traveler miss flight to late flight check bag missed my morning appointments and you lost my business',
#  'check out new music',
#  'how direct flight fll gt sfo have unexpected layover in vegas fuel yet peeps next to me bought for vegas flight',
#  'your no late flight bag check just lost you my business missed flight and am apt three other people on flight had same exp',
#  'amazing customer service again twohearts twohearts raeann in sf she the best',
#  'called your service line and was hung up on this is awesome',
#  'your site is tripping trying to check in and getting the plain text version am reluctant to enter any card info',
#  'was scheduled for sfo dal flight today changed to th due weather looks like flight still on',
#  'has getaway deals through may from one way lots of cool cities',
#  'has getaway deals through may from one way lots of cool cities',
#  'has getaway deals through may from one way lots of cool cities',
#  'has getaway deals through may from one way lots of cool cities',
#  'have great week sunwithface airplane',
#  'come back to already we need you to take us out of this horrible cold',
#  'should be concerned that am about to fly on plane that needs to be delayed due to tech stop',
#  'is the best airline have flown on easy to change your reservation helpful representatives amp comfortable flying experience',
#  'and again another rep kicked butt naelah represents your team so beautifully thank you',
#  'your beautiful front end design is down right now but it was cool to still book my ticket all your back end was secure',
#  'love the team running gate at las tonight waited for delayed flight and they kept things entertaining',
#  'use another browser amp brand with reputation built on tech response doesn have cross browser compatible website',
#  'and now the flight flight booking problems site is totally down folks what is the problem',
#  'like the customer service but min delay just for connecting passengers seems too long va',
#  'thanks to your outstanding nyc jfk crew who moved mountains to get me home to san francisco tonight',
#  'you have the absolute best team and customer service ever every time fly with you delighted thank you',
#  'do you provide complimentary upgrades to first class if there are available seats',
#  'need to change my flight thats scheduled in hours and min wait time on phone im calling intern help',
#  'completely awesome experience last month bos las nonstop thanks for such an awesome flight and depart time',
#  'how can watch the on my jfk gt sfo flight',
#  'is flight cancelled flightled and what do do if it is',
#  'you are failing your customers because your check in process does not link to tsa pre check',
#  'us too terrible airline just gave us hotel hotline number and said sorry',
#  'has flight number from sfo to cabo san lucas arrived yet',
#  'your assistance yesterday when cancelled flightled our flight was to give us hotel hotline shame on you',
#  'another delayed flight',
#  'need to register service dog for first class ticket from sfo gt dulles the phone queue is an hour or longer pls advise',
#  'you rock for making it so can watch on my flight',
#  'dropped track on you',
#  'always xoxo',
#  'why can we book seats on your flights when we buy them or even during check in creates so much anxiety',
#  'you think paying an extra bucks rt for luggage might afford you hiring an extra hand at',
#  'best customer service rep in the world takes the cake',
#  'can you find us flt out of lax that is sooner than midnight on monday that would be great customer service grinningfacewithbigeyes',
#  'please provide status for flight cant imagine it on time as the web indicates dude to weather here and or dallas',
#  'you have amazing staff amp super helpful as just ran the they have spoiled me with comfort',
#  'paid the premium to fly you across the country you cancelled flight my flight and offer no check fee or upgrade love sad face worried',
#  'question is it not possible to book seat for an infant under it not giving me the option but we want seat for him',
#  'always have it together you re welcome rt you re so welcome',
#  'home to in back to',
#  'don understand why you need dm to give me an answer on if you have damaged luggage policy',
#  'does that mean you don have policy for destroyed luggage',
#  'is there special assistance if travel alone kids and infant priority boarding',
#  'thank you for checking in tickets are purchased and customer is happy wink',
#  'is your website ever coming back online',
#  'is flight from love field to sfo definitely cancelled flightled for monday february',
#  'is flight out of lga to dfw on time',
#  'my drivers license is expired by little over month can fly friday morning using my expired license',
#  'having problems flight booking problems on the web site keeps giving me an error and to contact by phone phone is minute wait',
#  'how do reschedule my cancelled flightled flights online the change button is greyed out',
#  'rang but there is wait for minutes can book the same ticket through vendor fix your site',
#  'got flight we were told for today checked my email and its for tomorrow this is unacceptable',
#  'our flight into lga was cancelled flighted we re stuck in dallas called to reschedule told could get flight for today',
#  'why don any of the pairings include red wine only white is offered worried',
#  'is the website down',
#  'your site seems little wonked right now may want to have look tried on two browsers no css',
#  'disappointed that the agent at the designated silver status check in line closed to assist all pasengers',
#  'plans to include austin to its dallas route topnews arab',
#  'is it normal to receive no reply from central baggage',
#  'at logan airport and waiting to checkin for my am flight checkin desk not open why',
#  'to jump into the dallas austin market',
#  'beats eps views takes on va luv investor business daily',
#  'lister to my show my on monday',
#  'to begin dallas austin in april ketr',
#  'congrats you just got all my business from ewr to sfo lax fuck you fl sfo ewr was the clincher',
#  'applied over weeks ago haven heard back and flying this week',
#  'love to know what your policy is for damaged luggage',
#  'thank you for the follow',
#  'too many apologies you the worse airlines don even respond to your cudtomers',
#  'shame on va for making people spend money in stranded cities when other airlines are landing at jfk who will reimburse me',
#  'dm you',
#  'can you please have flights in sjc have no choice but to fly southwest to vegas wearyface loudlycryingface',
#  'too bad you say it takes to days via your confirmation email when inquired after weeks you claim to weeks',
#  'flight from bos gt las tomorrow was cancelled flightled no notification wait times are hour will you rebook on another airline',
#  'smilingfacewithsunglasses rt you ve met your match got status on another airline upgrade restr',
#  'only way to fly',
#  'if only you guys had flights from cmh',
#  'lot of apologies being thrown out to customers from what can see very sad thanks for nothing worst airline ever',
#  'for all my flight stuff wrong and did nothing about it had ever',
#  'having an issue finding missing item on plane can you help me find which airport my plane headed to next',
#  'you will match my status cool',
#  'you ve met your match got status on another airline upgrade hear no evilmonkey',
#  'trying to book flight with you guys and your website won let me about to lose my business',
#  'you suck',
#  'thanks',
#  'just dm same issue persisting',
#  'because we never rec cancelled flightlation notice we were left no options to fly out of ps driving to la for red eye mon kids',
#  'trying to book flight amp your site is down beamingfacewithsmilingeyes',
#  'you have any flights flying into boston tomorrow need to be home and you cancelled flightled my flight and didn do anything',
#  'you stink flight cancelled flighted from psp to jfk and no notification or ability to rebook better',
#  'love your guy song we re dancing to it for our high school dance revue',
#  'your website is down and trying to check in',
#  'done thank you for the quick response apparently faster than sitting on hold wink',
#  'nervous about my flight from dc to lax getting cancelled flightled tomorrow just sent you dm to help me',
#  'cool picture of another virginamerica plane off our wing what site',
#  'keep up the great work simple_smile',
#  'my goodness your people field are amazing under pressure redheart from texas in crisis please fly me to ny',
#  'thanks for great flight from la to boston pilots did great job landing in the snow can we go back to la now',
#  'can you please get me to the new york area before monday afternoon',
#  'thanks so much for the awesome support you guys rock',
#  'seats in row don recline should mention that on your website',
#  'flight delayed hours in la due to mechanical problems handle like pros but you could have tossed us free drink',
#  'why cancelled flight flights today no precipitation to be scared of snowflake snowflake snowflake',
#  'twitter team you guys killed it for rescheduling me asap thank you',
#  'you guys charged me to reschedule flight that was then cancelled flighted and are now refusing to refund it what the deal',
#  'can access your website from safari on iphone seems to work on mac and ipad need iphone to add passbook',
#  'on ipad and iphone clicking the checkin link in the email received at hrs before flight',
#  'your mobile site is broken shows header elevateuser numofpointsavailable number points won let me checkin',
#  'was really looking forward to my flight can you let me know when it will be rescheduled',
#  'why cancelled flight flight vx one sec its delayed on my to airport the next its cancelled flightled gonna email or call me to reschedule',
#  'did it but there was problem in the link from the email for check in thanks',
#  'had to change to another airline to get to dc today why is able to land in dc but not you cost me ugh',
#  'was so looking forward to my first flight with you today but it was cancelled flightled along with the subsequent one',
#  'when are you putting some great deals from pdx to las or from las to pdx show me your love',
#  'wish can afford to fly with you next friday going back home love everything about your airline',
#  'how are you gonna have deal from dallas to dc but no deal from dc to dallas',
#  'it just bug report guys',
#  'hold times at call center are bit much',
#  'like',
#  'site down',
#  'you have the best flight attendant ever',
#  'awesome rt watch nominated films at feet',
#  'thanks so much',
#  'trying to reset my password email never arrives help',
#  'the only airline based in silicon valley',
#  'very nicely done clappinghands',
#  'looking forward to watching the oscars on my flight home tomorrow might even get something bubbly to drink wink',
#  'what is the reason for the delay of the departure of vx from jfk this afternoon',
#  'is todays flight from palm springs ca to jfk in ny cancelled flightled',
#  'hahaha facewithtearsofjoy you guys are amazing love you guys growingheart',
#  'sounds like fun',
#  'any updates on flight from jfk gt lax',
#  'spruce moose',
#  'the css on your site is right now please fix site unusable',
#  'we re on flight vegas to boston today checked in online but our bag count didn register can fix that somehow',
#  'classiq luv virgin america greetingz',
#  'hi trying to do check in but the website is not working tried different browsers and the problem continues',
#  'thanks for your great customer service today amp for helping me get all my travel sorted out',
#  'thanks guys sweet route over the rockies',
#  'love the music blasting at gate in while waiting for flight to only if could get an iced coffee',
#  'the passenger in flt that assaulted me shouldn have flown trust he banned crew filed report to',
#  'current bug on website shows select departure city when selecting destination city',
#  'luggage was severely dented missing wheel coming off baggage claim in san luggage agent miranda think wasn any help',
#  'thank you for the easy itinerary shift for impending weather quick painless amp free',
#  'if you love to see more girls be inspired to become pilots rt our free woaw event march at abq',
#  'thanks good times there and back the entire flight cocktailglass',
#  'beats expectations shares take off santa cruz sentinel',
#  'any plans to start flying direct from dal to las',
#  'big love gratitude mpower werin vipswagbags',
#  'you re doing great job adding little luxuries aesthetics that improve the air travel experience thank you keep it up',
#  'requested window seat and confirmed window but got stuck in middle seat not good way to treat silver member unamusedface',
#  'grand budapest hotel',
#  'this is what you missed next trip to the',
#  'paid for direct flight on purpose not to have to stop for fuel exhausted frequent flier and nothing for inconvenience',
#  'there is something wrong with you website in safari iphone',
#  'thanks for gate checking my baggage on your full flight dfw lax and giving me early boarding too',
#  'already checked in so the page expired',
#  'boo for not refunding seat upgrade fee did not want to buy in the first place',
#  'shares rise on financial results usa today',
#  'adds pillows instead of lie flat seats in first class arms race',
#  'see what you did there wink',
#  'way to take advantage of simple_smile',
#  'you know flying virgin for the fight',
#  'your inflight team makes the experience',
#  'cutest salt and pepper shaker ever just when think you guys can get any better you just do',
#  'moved my seat with no notice better seat is cabin select not behind the row selected thumbsdown',
#  'shares up on results',
#  'fav airline',
#  'we have hot female pilot sweet dca to sfo simple_smile',
#  'thumbsup thumbsup airplane airplane growingheart when are you guys going to start flying to paris you re welcome',
#  'what is your policy on flying after surgery am still waiting for answer so can tell me doctor',
#  'already contacted central baggage amp sent dm is charging me for the dress that was in the lost suitcase',
#  'thank you',
#  'is there anything going on with the website ve been getting lot of errors past minutes',
#  'think left something on the plane yesterday who do call ah',
#  'need you to follow back in order to dm',
#  'need to start flying to smilingfacewithsmilingeyes grinningface grinningfacewithbigeyes grinningfacewithsmilingeyes',
#  'they told to check with the airline regulation first so that is why contacted you',
#  'have just checked in flight to sfo from lax amp been told as atlantic flying club gold get no benefits',
#  'husband and ordered three drinks via my screen and they never came awesome',
#  'soooo are you guys going to leave the seatbelt light on all flight you can barely call this turbulence simple_smile',
#  'what is your policy on flying after surgery',
#  'posts second consecutive full year net profit',
#  'funny story your website is broken you have missing javascript and stylesheets on the checkin process dislike this',
#  'would love to do more for virgin just like do for',
#  'results handily exceed forecasts',
#  'applied for position in and was wondering if you guys received my application',
#  'achieves second year of profitability despite revenue pressure',
#  'gives positive outlook but sees increased competition',
#  'trying to check into my am ct flight tmm on the desktop website and it not working some sort of caching bug sos',
#  'weather delays gt next few weeks wink',
#  'check the website before you go to the airport',
#  'do you guys know your check in links from emails are broken',
#  'pilot says we expect choppy landing in nyc due to some gusty winds temperature of about degrees amp the windchill',
#  'loved it can wait for monday return flight mostly just to watch the inflight safety video again',
#  'lost my luggage days ago on flight vx from lax to iad amp calling every day no response please give me back my stuff',
#  'the flight booking problems section of your website seems to be broken on chrome might wanna look into that',
#  'hi just wanted to see if you have any new routes planned this year for newark love flying you guys and hope to do so more',
#  'mean probably inappropriate while on board but it on',
#  'happy to spend the day together let do this',
#  'is saving my sanity right now',
#  'missed my flight how does standby work',
#  'they were very understanding and helped me out thx',
#  'brought it all the way across the country today see',
#  'thank you absolutely will smilingfacewithsunglasses',
#  'looks like broken link for your assets',
#  'are you ready let say it together noooo turbulence today faceblowingakiss',
#  'the manage itinerary section of your website seems to be broken for me',
#  'can check in your site looks like this every time it loads',
#  'can help this princess needs urgent treatment in unitedstates old battling cancer could help with flights growingheart',
#  'may start service to hawaii from this year',
#  'other carriers are less than half price for round trip fare am stunned',
#  'wtf is happening in pdx late flight march such that one way from sfo is',
#  'add dtw and sold',
#  'how about some free drinks on the flight back for the free promo',
#  'thanks',
#  'momma made it beamingfacewithsmilingeyes beamingfacewithsmilingeyes beamingfacewithsmilingeyes',
#  'please contact me about portfolio left on flight vx from jfk to sfo tonite seat am need it returned call',
#  'help was on flight from jkf tonight seat left portfolio need it back',
#  'seattle bound wifey got me the duffle for vday she keeper holla',
#  'my luggage is gone ve filed my paperwork promised call email still no resolution or response from central luggage',
#  'debbie baldwin gave performance of the safety demo this evening on vx',
#  'thanks',
#  'thanks for taking care of on her flight',
#  'thanks for the lovely soft views to',
#  'requested mileage challenge for status several weeks ago online but haven heard back how do get help with this',
#  'just trying to book tickets to nyc and facing super fun broken styling don worry ll keep trying simple_smile',
#  'many thanks for the follow looking for any help smilingfacewithheart eyes growingheart unitedkingdom growingheart unitedstates growingheart ribbon globeshowingasia australia ribbon',
#  'nice lofty view',
#  'applied for status match on feb got confirmation email same day still no news though you guys have dropped ball late flightly sadbutrelievedface',
#  'is my new go to airline',
#  'can you help in need of some help in ribbon unitedkingdom ribbon unitedstates ribbon',
#  'adore you and am so looking forward to my flight to austin in two weeks',
#  'was so glad it was mentioned took my first virgin flight few years back and it was transformative experience',
#  'flight booking problems flight to uphold my status match do taxes on ticket count as earned status points',
#  'trying to check in but looks like your site is down',
#  'spending my birthday night with you dal dca get me home',
#  'sent couple messages to the email you provided but to no avail will try again next year cheers',
#  'first time flying virgin went to thanks for the smooth ride easily my new fav airline',
#  'seriously though will there not be direct flights from sfo fll in may',
#  'it fine already done with my purchase but you should try it just go most of the way through then go back',
#  'not really the experience was hoping ws forced check in small carry on nothing but empty cabin space on board',
#  'wjere is our luggage slow at lax',
#  'to jump into the market',
#  'spoke with representative that offered no solution am loyal customer who flies on as well',
#  'am deeply disappointed that your birthday promo was not applied to trip booked mere days before received the email',
#  'what happened to direct flights from sfo fll looking in may only see connecting',
#  'can you help left my blazer in kooples jacket bag at rd row second seat from right gate lax flight to sfo',
#  'partners with checkout as mobile payment method to help boost mobile conversion rates',
#  'just promoting the product is all had problem with southwest and recommend noneother than the best',
#  'love you guys but pls get some direct routes las to aus',
#  'would like help with some flights please',
#  'bruh turn down for what',
#  'of course work for and obsessed with the entire virgin family',
#  'ok first time flying with you tonight simple_smile',
#  'digging the swanky pink mood lighting during the flight from nyc to sfo just needs cabaret singer think about it',
#  'done but need the receipt asap could you please help',
#  'have and embossed badges and patches superior to the ones you are currently using',
#  'on vx from jfk to la dirty plane not up to your standards',
#  'on flight vx headed to la from jfk dirtiest va plane have ever been on sad for great airline',
#  'got it squared away someone picked up as soon as tweeted should have tweeted sooner winkingface',
#  'your avis rental continue button doesn work on your website to book car tried times on phone this sucks',
#  'delayed to',
#  'currently in minute of being on hold with cust service do need to do anything to add lap child to my reservation',
#  'adds pillows instead of lie flat seats in first class arms race by',
#  'of course have fun celebrating thanks happy chinese new year',
#  'flight booking problems last second flight for next week from sfo to san any chance you want to gift me promo code since love you guys',
#  'comenity bank is joke please change nothing but constant problems with this bank',
#  'just did how can dm do have to also add me',
#  'for my grandma ella th she would lt bday greeting from your flight crew she was stewardess for eastern airlines',
#  'just bought tix for atx dallas route thanks for adding that love yr airline amp yr website is best transactional site ever',
#  'anytime sugafly',
#  'gave credit for my late flight flight yesterday great service that wow moment unexpected gesture',
#  'need receipt for flight change can you send one',
#  'submitted status match request while back and still haven heard flying on monday can you look accelerate',
#  'had me at their safety video loved my first cross country flight',
#  'that doesn look to fat to me it looks yummy',
#  'ceo says amp have strayed from low cost model',
#  'brilliant brisk am in boston in cue for vx',
#  'atlantic ploughs lone furrow in the',
#  'atlantic ploughs lone furrow in the',
#  'atlantic ploughs lone furrow in the',
#  'omg omg smilingfacewithheart eyes smilingfacewithheart eyes nonstop dallas to austin on virgin sparkles facescreaminginfear airplane',
#  'your planes are really pretty just thought should know that simple_smile',
#  'when are you flying to hawaii',
#  'pulling my hair out trying to book flight with your site doesn work on iphone or ipad don have computer',
#  'thank you',
#  'can get some help with support ticket it been days incident thank you',
#  'good to be home',
#  'cannot even open my laptop in seat and paid premium for this let me out of here',
#  'am in seat and cannot even open my laptop and paid extra for this seat',
#  'if only you guys were starting those flights at the end of the month guess still road tripping on feb',
#  'thanks for that been needing way to make those austin trips from dca and now you have come through',
#  'announced new route to austin fares from way',
#  'really sprint thought you guys were kewl',
#  'this is too cool never been on ur planes but now will',
#  'you should have dollar lax las fares',
#  'great well deserved',
#  'fyi the info com email address you say to contact in password reset emails doesn exist emails bounce',
#  'status match weeks have gone by and no news flt next week hope flt will count towards requirement cust svc no help',
#  'your website sucks donkey dicks just thought you should know all best',
#  'you should still develop an app then you will be my favorite airline',
#  'all crap channels which is why pay to watch uk tv',
#  'got it all set thanks',
#  'no channel this year',
#  'only thing see on passbook is virgin mobile mexico how do integrate',
#  'giants and virgin america match made in heaven',
#  'thank goodness also see you friday nwk gt sf boom',
#  'how come you don have an iphone app still using and making me waste paper',
#  'your back of seat entertainment system does not accept credit cards that have an apostrophe in the surname',
#  'when will vx use all lga slots instead of today adding aus makes this less likely worried',
#  'is helping me step up my game',
#  'luv ur people and product thing is do charge for herbal tea but not black tea not caffeine drinker',
#  'thank you see all soon excited to see the expansion of destinations spread those wings',
#  'announces new nonstop connecting amp intro',
#  'adds austin dallas love field route',
#  'sad to learn you no longer fly sfo gt phl hope it returns',
#  'can you tweet me the cancelled flight chng fee for flight or can rebook under one of your affiliates if so who are afiliates',
#  'has the most incredible customer service ve ever experienced so refreshing',
#  'now when will we see virginamerica come to philadelphia phl',
#  'am dreaming did you really just open up route between dallas and austin and does this mean houston might be next',
#  'omg finally',
#  'to start xweekly flights from to on apr',
#  'nice to see you expanding in texas but don forget about us here in would love to see more flights out of here',
#  'kinda sucked my earphone jack didn work on my flight they may want to look into that for future passengers',
#  'very poor experience first computer problem now seat malfunction stuck missing meeting in san diego',
#  'to battle on route via',
#  'the dal aus route makes my day',
#  'awesome deals dal aus for only each way',
#  'miss the in san jose',
#  'love it taking on in their backyard consumers win when biz competes',
#  'is flying from love to austin now that is most excellent news',
#  'can we make every vx plane with why should austin be the only one getting nerd love',
#  'please add more frequency to pdx portland',
#  'congrats vx on the new route airplane partypopper',
#  'tried that you offered to charge me an additional for new ticket or be stranded until thurs st time last time',
#  'can help with flights to get old battling cancer who needs treatment in unitedstates growingheart ribbon growingheart',
#  'never had bad experience before but this one took the cake now extortion for carry on items as well',
#  'had to spend hours worrying that items in carryon would be broken stolen since couldn carry them on plane or lock bag',
#  'all of group was told there was no more room in the bins when got on the plane was room for at least bags in my row',
#  'thanks for making my flight from lax to jfk nightmare by forcing me to check my carry on bag at the gate',
#  'have lots of flights to book and your site it not working ve been on the phone waiting for over minutes',
#  'am all about the in flight artisanal cheese and wine pairing',
#  'does virgin america fly direct from seattle to nyc or boston',
#  'that classy',
#  'sure lot of your and jfk lhr flights go lot faster than mph with strong tailwind',
#  'now it just minus minutes until my elevate silver upgrade window opens grinningfacewithbigeyes thumbsup',
#  'save some for tomorrow am',
#  'why is it taking years to fly home to dallas get your shit together',
#  'club virgin is bumping in new york',
#  'would have been rough trip but luckily we were on flight',
#  'is that beamingfacewithsmilingeyes',
#  'please come to minneapolis st paul',
#  'yes fyi my bff',
#  'another perfect flight how come on your planes the sun visors can stay down other carriers make you raise them',
#  'nice rt the man of steel might be faster but we have wifi just saying',
#  'love the dancing little richard cool beans',
#  'don use passbook still love you though lt simple_smile ll just use my email in the future',
#  'thanks for the free birthday points all are all right with me',
#  'do you have an application for ios was looking and only saw virgin mexico worried lt',
#  'man of steel flies to more cities though and with more frequency too',
#  'thanks so much for sharing just added it to my site',
#  'good point',
#  'heard he has virgin mobile hotspot wink',
#  'you got cheese plate flights too',
#  'on all your flights',
#  'dad on segway is the best part of this whole infographic',
#  'are there any plans for short haul airline in europe would defiantly fly with you guys simple_smile',
#  'wifi and better seating',
#  'how come abc is the only one of the network channels you don have',
#  'started my flight with scolding for using an overhead bin that was then offered to the person seated next to me',
#  'not only was it great but you return my calls the day after couldn ask for more',
#  'while other airlines weren cancelled flighting flights into bos and helping their customers get home virgin was saying good luck',
#  'dear virgin customer while you re stranded in sf for days amp cost we will do the very least we can to accommodate you',
#  'should use this in their next airline commercial lol',
#  'grouping virgin in with the others now bos weather has exposed their actual cus serv model never flight booking problems with virgin again',
#  'as one of the travelers affected by the boston storm shocked at virgin complete apathy toward their customers',
#  'umm so no reason as to why this is is there someone different should contact or contact me to get definitive answer',
#  'trying to make the change in advance not just hours prior tried it online earlier and it wanted in change fees',
#  'so loyal that driving to from to fly virgin since you cut flights wink',
#  'any way to change from main cabin to main cabin select on same flight without paying change fee penalty',
#  'you guys are perfect as always lt',
#  'thanks all have some of the best customer service left in the industry',
#  'can you give me silver status for months',
#  'really wish you fly out of those fares are amazings',
#  'mood lighting on point raisinghands reclining my seat kickin up my feet zzz',
#  'my flight scheduled for pm departure still says on time but no plane at gate any update on how long of delay',
#  'my group got their cancelled flightlation fees waived but can because my ticket is booked for your reps were no help either poutingface',
#  'are there any sign up bonuses to enroll in elevate',
#  'just got on the pm in newark home to la your folks at ewr are incredible',
#  'morning if have question regarding elevate points amp flights can dm you',
#  'still waiting to see disappointedface',
#  'was wondering if you guys recieved my dm and we re able to potentially respond asap',
#  'flying lax to sfo and after looking at the awesome movie lineup actually wish was on long haul',
#  'book out of town with fares from way restr',
#  'thanks',
#  'thanks for taking care of that mr happy customer',
#  'still no refund or word via dm please resolve this issue as your cancelled flightled flight was useless to my assistant trip',
#  'delayed due to lack of crew and now delayed again because there long line for deicing still need to improve service',
#  'thanks we filled it out how our luck with this is it common',
#  'your eri ord express connections are hugely popular now if only we could have an eri ewr hop simple_smile',
#  'even on international flight glasgow to the then what about orlando to newark all mins',
#  'you think you boarded flight au too early think so',
#  'understand but it tough when there is no way to get to the airport serious risk of an accident it steep price',
#  'gate agent hooked me up with alternate flights if you have way to prevent the constant issues that would rock',
#  'flying gla mco in few weeks how long do we have to be at airport for before departure for both international and domestic ta',
#  'thanks',
#  'thanks it is on the same ticket',
#  'why not is it law or policy',
#  'is the worst nonrefundable first class tickets oh because when you select global fc their system auto selects economy upgrade',
#  'so can buy tix days before flight but can transfer the tix flawed security logic flawed customer service',
#  'did start claim but weeks is unrealistic am really supposed to go that long with out car seat for my child ridiculous',
#  'follow me please this airline is beautifull heartsuit',
#  'no don but sure united have my info on its system',
#  'if the car seat is lost should just reimburse me for new one this is not pair of shoes it necessity for my child',
#  'just submitted my response on the link you sent',
#  'yes david allan send an email with this number kmm l km and case',
#  'that totally sucks my cousin worked at phl said',
#  'just wanted to let you know how wonderful rosetta the gate agent was working flight dan to ase let her know she wasappreciated',
#  'yes paper voucher that got on january th',
#  'beginning of feb called united they said they would send another voucher by mail never got anything',
#  'the internet is great thing am emailing executives in your company maybe they will respond to me in timely manner',
#  'do need to use chase united club pass for my yr old son or can he come in with me on my pass',
#  'and what am suppose to do with that number',
#  'thats weak see ya wavinghand hey',
#  'flew back other company since united didnt have an earlier flight',
#  'lost voucher that was given in miami aeroport on jan did not use it',
#  'am trying to book awards for september and need flights on but they will not show even many award seats availab',
#  'sure did had to drive total of hours to get my own bag like to explain that debacle but no one wants to talk to me',
#  'gee that like almost caring about ppl more than think more int in having trusted adult daughter',
#  'see we were told repeatedly that the pilot was late flight and kept getting late flightr after we boarded there was defibrillator issue',
#  'why no preferred security line anymore my tsa pre check didn pull on my partner flight',
#  'airport need to indicate different gate for terminals amp',
#  'yes please am newly married and trying to update my last name on preexisting international flight it seems so easy but',
#  'how does united refuse to reissue lost voucher when their plane didn take off due to mechanics',
#  'also during the run was instructed to do shattered my computer',
#  'yes we have been with the agents for the last minutes one of the agents have been very rude but thankfully ladan has been nice',
#  'that right with an overnight miami',
#  'have clients with an hr layover at iah during the day will they have to claim amp recheck luggage or will it be taken care of',
#  'am trying to find out if the loaner seat is new or used used car seat is illegal according to safety regulations',
#  'dmed you the details',
#  'iah to charlotte baggage claim rep latrice non existent ignored customer then inappropriately touched customer',
#  'kewl will also let them know the overhead bin over my row was inop love good abbreve',
#  'thanks for your help got me what need but its an issue with guess sit awhile longer',
#  'would have loved to respond to your website until saw the really long form in business the new seats are bad',
#  'refund and flight vouchers or another flight on different airline at your expense for today hour drive is very inconvenient',
#  'then why have not received my call back its been days it an infant car seat how am supposed to go anywhere with my child',
#  'thanks again for your concern will contact customer care upon our return from australia',
#  'well sitting on the ground on time but waiting for gate again',
#  'airport snow removal method keep up the good work folks this is where cessna become',
#  'no need you guys to not over book planes it not concern ll just travel with someone else moving forward',
#  'measly certificate is not how you appreciate loyal customers after they wait hrs on the tarmac during ua',
#  'when will email address username sign on be available it been while',
#  'thank you for that am able to claim any interim expenses or is the cost of the stuff up on me',
#  'rude rude',
#  'why can get boarding pass for my austrian airlines codeshare flight rebook incls hour layover amp am stuck outside sec',
#  'received on other flights truly breaks guitars',
#  'just flew to paid from third suitcase which didn even make it on the plane besides for the impolite service',
#  'my bag is still in colo springs am disabled and have to search an unfamiliar airport and look for my bag not good outcome',
#  'shame that there no flex to tickets transfer rules even calling from neurosurgery icu isn enough',
#  'no denver said they don handle baggage that made it to colo springs they gave me an number to call no help there either',
#  'you guys need some serious training in customer service too many better options to put up with the way you guys handle ur mistakes',
#  'ord to dca',
#  'once he found out we had problem he avoided me like the plague was told we can find supervisor',
#  'zcc cancelled flight flight in advance need connect flight reschedule so the link isn helping help gf waited months to see me',
#  'will not be flying you again',
#  'in addition my first flight was delayed an hour and arriving at my destination hrs late flight',
#  'cancelled flighted our flight didn rebook us on added flight now have to drive from denver to kc thanks',
#  'your announcement for pre boarding only addresses mobility my disability requires me to travel with lot of stuff do preboard',
#  'flew united last month and the experience was awesome',
#  'our travel booked thru united group dept okc ticket agent less than willing to help with our connection in lax',
#  'upset with your disability services when told one of your employees was carrying medical equipment she was very rude',
#  'thnx for quick reply but don think you can assist our intl grp will be put to considerable inconvenience today',
#  'wont transfer flight ticket to accompany an yr old who active military mom had to have emergency brain surgery wow',
#  'weeks late flightr and still have not received my miles from the mileageplus gift card starbucks card handed over',
#  'as always hoping for improvement',
#  'not yet complained about the guy who checked my luggage in as he was throwing the bags around unfortunate coincidence hope',
#  'okc ticket agent roger mclarren sp less than helpful with our intl group travel problems can find supervisor for help',
#  'mobile apps need construction from the ground up for each os category it expensive to get right',
#  'another fail for the united ticket agents in okc less than helpful and could care less about our problems american here we come',
#  'which also had working wc in coach good thing this bird landed ahead of schedule have to use the wc stat',
#  'the os isn controlled by me but rather app is new',
#  'just sent an email to customer care telling them may have to break up with you cryingface sincerely hope they can help me',
#  'silly flying delta today your united club staff and attendants are surly and unhelpful and always seem bothered by pesky folk',
#  'what is your phone number can find who to call about flight reservation',
#  'well you can fix me missing my buddies th bday because of negligence but you can attempt to make up for it',
#  'why am to believe they will help when customer service couldn like said want number to someone who can fix what you did',
#  'they helped me at the baggage service desk said bc tsa screening was down in fll not all bags made it but bag will be in ewr',
#  'mobile boarding pass disappeared from phone while standing in line to board second time this week hmm',
#  'for the record rozana at newark was lovely and helpful',
#  'it was last night ord lga',
#  'thx for update',
#  'thank you',
#  'dm these nuts',
#  'had to explain to very over eager flight attendant trying to ask about my vision that my was not guide dog',
#  'what the point of asking for details about when you book if your flight crew doesn read them continued',
#  'tried but no one was available in bogota and everyone was rude in houston was stuck for hours because of you guys',
#  'ua las to iad mechanical problems again took off had to land for fix delayed again',
#  'despite my bag not making it to newark good informative email tracking updates help',
#  'what going on with ua outbound flight last thurs was delayed hrs how long will this delay be',
#  'ua iad to las mechanical problems switched aircraft delayed hours',
#  'crashed trying to check in',
#  'wow what deal again plus seats available easy change to make customer happy',
#  'thanks for the info already knew',
#  'airline trouble this winter amp not getting good customer service contact we negotiate resolutions for you',
#  'on to logan boarding gong show due to lax carry on enforcement bins full of coats no room for bags need better system',
#  'thank you',
#  'blackmailed me into paying extra or having my return ticket nullified in san francisco airport terrible service from rep',
# ...
#  'ua ord lhr bags are being loaded min late flight frigid air into cabin plane feels like falling apart upgrade long haul fleet',
#  'flight attendant never served me my beverage tea and not once checked up on me what gives',
#  'load balancing system apparently down major impact on all airlines flights was this',
#  'after our unscheduled refueling stop and missing connecting flights we home looking ward to our bed and big pb amp sandwich',
#  'spent hundreds to rectify the situation and you guys go quiet',
#  'ua sitting at ewr nearly an hour after sked pilot says computers down but no clue when we will leave can you help',
#  'so that it it just ends there come on traveled for literally an extra day and half because of this',
#  'made the upgrade list will fly st tomorrow for min for the first time ever raisinghands',
#  'not just refunded but for those of us who are on vacation to get free room night to make up for making us sleep in dia',
#  'thanks for the reminder it been fun ride',
#  'received my luggage that also looked to be left in the snow when arrived asking for all people to be refunded',
#  'updated aircraft has wifi and device entertainment but no outlets don get it how can charge devices',
#  'was no one between the scan and inside the plane just asked the people in line around me where the plane was going',
#  'gate changes two delays even the crew thinks the airline sucks',
#  'very frustrated and have wasted days now due to your equipment failures',
#  'computers are down but you stopped giving updates and took my flight info off the app that just ridiculous keep people updated',
#  'soooo it been days and you have offered no response so assume poor treatment by gate agents is the norm now',
#  'terrific many thanks looking forward to being back on ua tomorrow had great flight up to vancouver',
#  'calls to resulted in hrs of hold time amp day wait to check suspect code share fare nothing investigated my time wasted',
#  'it taken weeks for cust care to respond to case requesting refund for wi fi not working where can get an update',
#  'appreciate your efforts getting me home',
#  'that correct ve spent hours trying to book online only to receive an error when clicking final purchase button',
#  'today was not your finest all could have been prevented by one gate agent advising passengers',
#  'what is the real deal with the delay on flight ua from denver to vegas',
#  'ua from madrid arrived no agent mass confusion we sent to and fro by ua employees maryjo was rude and unhelpful',
#  'system failure again bad trend software projects are like flying an airplane there no such thing as an emergency takeoff',
#  'lots of reports of system failures delaying flights over the last week currently sitting on the tarmac at ogg for over an hour',
#  'rebooting chicago dispatch system need as tired of sitting on planes',
#  'despite shaky connections looks like ll get home tonight great job was touch and go for while',
#  'however is completely under your control the price was and still is displayed on',
#  'the aircraft closest to gate was for the other flight and the one closest to our gate was going to chicago',
#  'can you tell me how to file claim for clothing that had to be purchased',
#  'comically on the return flight from ase there were two united flights boarding at adjacent gates and not clear which plane to board',
#  'grk is the file reference',
#  'we would how do contact you to discuss few poor experiences with customer service but would give it shot',
#  'ua pacific rim and date night cut out not constantly or randomly but one spot repeatably',
#  'been trying since to file report',
#  'send an email about my bad experience and you send back generic response yet another reason why ll never fly with you again',
#  'my mom left her kindle on flight today burgundy case with light seat did anyone find it',
#  'here is the ticket please refund my unnecessary upgrade fee',
#  'is horrible they lost our carseat and expect us to use loner carseat safety regulations say it illegal to use used car seat',
#  'thank you',
#  'decisions decisions we love for you to try our service we offer status match too kp',
#  'need more info on that we have great amenity kits pj not included we status match aa kp',
#  'don care that link showed me wrong price on your site it your site amp responsibility to ensure correctness',
#  'do you have any flights with lie flat seating from stl to pdx around the date of march',
#  'he needs to get to home the th they are telling him it will be the th night is there compensation or anything that can be done',
#  'the baggage fee is waived for premier members please see jp what the point of membership',
#  'wonderful bag claim people finally have my bag but why did catch earlier flight original flight just landed',
#  'dmed you thank you',
#  'thanks we will be in touch',
#  'thanks to karen salisbury at iah for amazing customer service found my daughter bag lost on ua made her day',
#  'days late flightr and my bag has not left iad united is not helping at all everyone tells me different story',
#  'hi when do direct flights from houston to reno begin don see any days in march',
#  'like continental chicken feat fairs',
#  'can you assist with current flight status for flt out of dfw tomorrow at am',
#  'left my comment with customer care thanks for contacting me',
#  'how do you lose gate checked bag den to ord direct flight ugh',
#  'caught earlier flight to ord gate checked bag and you have lost it at hare original flight lands in minutes',
#  'yes thanks so much purpleheart we see you spoke with our reservations team and they have reinstated the flight thanks ey',
#  'captain on behalf of the front office welcome on board never heard that before laughed hard',
#  'can you please follow for dm on missing bag',
#  'to be clear on my luggage comment am referencing the photo attached flight to jac',
#  'these are great fares',
#  'left an item on the plane and have been calling non stop and no one has been answering can you please help',
#  'awesome ll book my next christmas vacatinn this december any other ways you want to devalue mileage plus',
#  'what good number to call to speak with someone about how you can fix what you did to people and their luggage on saturday',
#  'thank secured room for the night thx to very helpful customer service rep dorns thanked her can',
#  'where my damn bag',
#  'well someone should tell that to the employees at the denver baggage claim still no bag',
#  'greetings ua club member here any idea if can use the air canada lounge at yvr flying ua tomorrow',
#  'how is mexico not international from the us',
#  'diverted and missed our connecting flight was just told that my bag is on it way to msy if you only had people that cared',
#  'male agnt in las threatens canadian cust when cust takes pic of him at gate after agents announce can help rebook',
#  'we just want to go home tonight why did you cancelled flight the last leg of our reserv out our permission',
#  'stressed and rude agents overwhelmed by delyd flight las den yelling at several people not pretty this is',
#  'landed in boston at last night the hours of traveling was rough tho',
#  'fail you cancelled flightled our flight frm gjt and then used our reserv home to iah from sea for reflight booking problems out our permission',
#  'just sent thank rt please dm your confirmation number if reflight booking problems is needed thank you ey',
#  'has made my no fly list other airlines wait when connector late flight stuck in iah',
#  'so what the deal do provide voucher for overnight or am cozy on the floor at',
#  'also the mere fact that have to go online to issue statement vice calling and talking to some directly is one good example',
#  'thank you flew into newark from vail eagle',
#  'have weekend of dealing with your company that would say otherwise',
#  'now what flight was gone when got off plane',
#  'the proper response sorry for your wait what flight were you on so we can look into the issue that how would handle',
#  'your customer service is terrible stood inline hours no flights and hours late flightr still no bag',
#  'please upload the march on demand entertainment listing on your website airplane',
#  'so you are inadequate by accident',
#  'denver international airport',
#  'thank you for responding so quickly with helpful tool',
#  'boarding time shows min and your gate agent started at showed up at and they had to check bag',
#  'agent in las letting customers know they can help them rebook delayed flight to den',
#  'empathizes my disappointment that stclass flight nonworking entertainmnt is worth',
#  'and when that doesn work',
#  'did you have seen my message today about mcdonnell douglas dc model will hear it if you read it goodnight now',
#  'searched for mileage tickets to bom couldn find single one is saver awards see how you play earn miles but can use them',
#  'flight arrives minutes early but then have we to wait for an hour for our bags',
#  'that not the issue the fact that no one even called despite promises to confirm the bag location is',
#  'what girl gotta do to get flight name change when she bought one for mean ex boyfriend and needs girl trip stat',
#  'thank you we are signed up for notifications we shall watch and wait snowflake snowflake',
#  'still waiting to hear back my wallet was stolen from one of your planes so would appreciate resolution here',
#  'would love if someone could get me back to austin tonight and do not wish to wait til tomorrow morning',
#  'or has lost my baggage heard different things from different employees of has said nothing',
#  'cs thinks that miles can repair the damage done it will be interesting if they travel in and exp the worst flight ever',
#  'have flight out of dfw on tuesday how far in advance will you give notice if cancelled flightled',
#  'am signed up for notifications this is the first trip was not updated on not sure why this happened',
#  'thank you took care of everything and made it right that the experience used to opened the app to find flight changed',
#  'that is not in line with your responses here and now waiting until tomorrow morning because all the flights are overbooked',
#  'took the exact same aircraft in to lax days ago it fit no problem the agent today told some nonsense about policy change',
#  'your helpful agents in club helped am just out baggage fees and night of my life stop doing business with',
#  'never heard of this',
#  'doesn charge ticket change fees do they not incur the same mysterious costs that you incur',
#  'exhausted amp frustrated link to fb post abt my travel issue',
#  'was denied getting on the plane getting the chance to prove it fits not rookie read my bio',
#  'that exactly the point it fits premier access boarding group this was return ticket ve been doing this for yrs',
#  've never experienced worst customer service placing blame on codeshare partners and not assuming responsibility is unacceptable',
#  'currently on board so not now check in was terrible staff rude expensive luggage thrown around etc',
#  'fucked up then voided my ticket and kept my money not even an apology will never fly with your airline again',
#  'has the worst customer svcs this kevin rep at call center must be investigated my baggage lost and there no help but argument',
#  'should not sell tickets for on has terrible service and ua staff cannot reach silver',
#  'just got demoted from gold cuz my hubby got of the pqd tho there were enuf spent for golds discrimination angry',
#  'thank you',
#  'when will direct flights from belfast intl to newark resume from their winter break thanks',
#  'my favorite way to travel thank you',
#  'yes after this awful weather it appears can get home',
#  'yes lots you have terrible customer service at newark and despite raising complaint there we were ignored hence the tweet',
#  'lovely new plane from lga to ord but no power outlets',
#  'but if tweet the id number won that reveal my home address to anyone on the web',
#  'filed delayed bag report on saturday my flight was cancelled flightled and never went anywhere',
#  'the person is currently bettween gates and in lax',
#  'need it there before she lands so she can have the ewr baggage claim file to have it sent but the employee has not droppeditoffyet',
#  'rarely ceases to amaze for the worse hope this is the last time have to fly with you',
#  'thank you for the quick response but cannot dm you until you follow me as well',
#  'icloud it is not there yet please help',
#  'need the phone number to baggage claim in lax my mom left her phone and someone called saying they would put it there but on',
#  'did no response back',
#  'this is atrocious customer service',
#  'will not have to honor absurdly low mistake fares vía',
#  'delayed departure to check bags at gate claiming space filled and walk on to open spaces delay',
#  'you cancelled flighted our flights for no reason amp now we have been on the phone for an hour on our vacation why',
#  'that your response shaking my head back and forth with tsk you can do better from customer service to your apology',
#  'thanks it miles from rtb to europe to do multiple destination so we could stop over in us on way way back mileage diff',
#  'of course did the bag should be here by now worried',
#  'you are the worst will avoid you like the plague',
#  'is the worst airline in the world',
#  'someone needs to dm me and resolve this correctly extremely disappointed with the service received terrible management',
#  'premier gold desk changes flight waives fees gives me wrong flight now jana acosta in salt lake refuses the same service angry',
#  'will give you one thing you are consistent but unfortunately you are consistent at not doing your job well',
#  'will but right now to angry',
#  'first time flying with united also last time back to for me',
#  'used to be committed flyer until merger remember now why switched to',
#  'the least you could do is offer me ticket in coach instead of just cancelled flighting my reservation because of your glitch',
#  'saying made the flight but with poor non communication unaccounted for lost time amp lots of frustrated flyers standing around',
#  'think dm would be better',
#  'gate announcement states delay due to maintenance yet app says late flight arriving aircraft tell the truth',
#  'you are easily the worst company have ever experienced you have lost someone personal possessions amp you couldn care less',
#  'how can your app show arriving aircraft is early but departing flight is delayed due to late flight arriving aircraft',
#  'already did that at the airport and hrs late flightr its still not here you guys are really killing me today trying to stay positive',
#  'once united service levels reaches those of etihad or lets be more realistically lufthansa then ill consider it again',
#  'really someone called in sick and then someone forgot to call replacement now an hour late flight to take off',
#  'asked flight attendant what typical compensation would be amp says we might get free tv',
#  'done',
#  'thank you jh appreciate the prompt responses me and other passengers will be doing so',
#  'has been such disappointment today simply put rather unpleased with things currently flight delayed cant wait to just get home',
#  'during the same round trip my non english speaking friend was stranded twice for hours each time most staff members were rude',
#  'found group of people who actually hates people more than isis thats right united airlines',
#  'nope walked up amp down the orf terminal amp not united agent to be found showed up last minute to board us many panicked people',
#  'thank you',
#  'by the time finally get to dallas could have driven with less frustration and cheaper',
#  'trying to get to my final destination we need compensation just about hrs of personal time wasted',
#  'that guy really has no customer service clue could have spent effort clearing bins for rollerboards instead of art projects in mine',
#  'he has no priority and iove it',
#  'pleased to be premier platinum',
#  ...]

# %%
# The 'tweets_cleaned_0' list is printed to make it easier to compare the text of the tweets in the last two 
# stages of text preprocessing.

tweets_cleaned_0
# Out:
# ['What said.',
#  "plus you've added commercials to the experience... tacky.",
#  " didn' today... Must mean  need to take another trip!",
#  'it\' really aggressive to blast obnoxious "entertainment" in your guests\' faces &amp; they have little recourse',
#  "and it'  really big bad thing about it",
#  "seriously would pay $30  flight for seats that didn' have this playing. it' really the only bad thing about flying VA",
#  'yes, nearly every time  fly VX this “ear worm” won’ go away :)',
#  'Really missed  prime opportunity for Men Without Hats parody, there.',
#  "Well,  didn'…but NOW  DO! :-",
#  "it was amazing, and arrived an hour early. You're too good to me.",
#  'did you know that suicide is the second leading cause of death among teens 10-24',
#  ' &lt; pretty graphics. so much better than minimal iconography. :',
#  "This is such  great deal! Already thinking about my 2nd trip to &amp;  haven' even gone on my 1st trip yet! ;",
#  "' flying your skies again!  take all the away from travel",
#  'Thanks!',
#  'SFO-PDX schedule is still MIA.',
#  "So excited for my first cross country flight LAX to MCO 've heard nothing but great things about Virgin America.",
#  " flew from NYC to SFO last week and couldn' fully sit in my seat due to two large gentleman on either side of me. HELP!",
#  ' :redheart: flying . :smilingface::thumbsup:',
#  'you know what would be amazingly awesome? BOS-FLL PLEASE!!!!!!!  want to fly with only you.',
#  'why are your first fares in May over three times more than other carriers when all seats are available to select???',
#  ' love this graphic.',
#  ' love the hipster innovation. You are  feel good brand.',
#  'will you be making BOS&gt;LAS non stop permanently anytime soon?',
#  'you guys messed up my seating..  reserved seating with my friends and you guys gave my seat away ... :poutingface:  want free internet',
#  "status match program.  applied and it' been three weeks. Called and emailed with no response.",
#  "What happened  ur vegan food options?! At least say on ur site so  know  won' be able  eat anything for next  hrs",
#  "do you miss me? Don' worry we'll be together very soon.",
#  "amazing to me that we can' get any cold air from the vents.",
#  'LAX to EWR - Middle seat on  red eye. Such  noob maneuver.',
#  "hi!  just bked  cool birthday trip with you, but  can' add my elevate no. cause  entered my middle name during Flight Booking Problems :cryingface:",
#  'Are the hours of operation for the Club at SFO that are posted online current?',
#  'help, left expensive headphones on flight 89 IAD to LAX today. Seat 2A. No one answering &amp; number at LAX!',
#  'awaiting my return phone call, just would prefer to use your online self-service option :(',
#  'this is great news! America could start flights to Hawaii by end of year via',
#  'Nice RT : Vibe with the moodlight from takeoff to touchdown.',
#  'Moodlighting is the only way to fly! Best experience EVER! Cool and calming. :purpleheart::airplane:',
#  'Done and done! Best airline around, hands down!',
#  'when can  book my flight to Hawaii??',
#  'Your chat support is not working on your site:',
#  'View of downtown Los Angeles, the Hollywood Sign, and beyond that rain in the mountains!',
#  "Hey, first time flyer next week - excited! But ' having  hard time getting my flights added to my Elevate account. Help?",
#  'plz help me win my bid upgrade for my flight /27 LAX---&gt;SEA!!! :wineglass::thumbsup::seat::airplane:',
#  " have an unused ticket but moved to  new city where you don' fly. How can  fly with you before it expires?",
#  'are flights leaving Dallas for Seattle on time Feb 24?',
#  "' for  good reason: you rock!!",
#  'DREAM',
#  'wow this just blew my mind',
#  'After last night !  think agree',
#  'All were entertaining',
#  'Is flight 769 on it\' way? Was supposed to take off 30 minutes ago. Website still shows "On Time" not "In Flight". Thanks.',
#  'Julie Andrews all the way though was very impressive! NO to',
#  'wish you flew out of Atlanta... Soon?',
#  'Julie Andrews. Hands down.',
#  'Will flights be leaving Dallas for LA on February 24th?',
#  "hi! ' so excited about your $99 LGA-&gt;DAL deal- but 've been trying  book since last week &amp; the page never loads. thx!",
#  'you know it. Need it on my spotify stat',
#  "' Lady Gaga!!! She is amazing! :smilingfacewithsmilingeyes:",
#  '- Carrie!',
#  'New marketing song? let us know what you think?',
#  "Julie Andrews first but Lady Gaga wow' me last night. Carrie? Meh.",
#  " called  - weeks ago about adding  flights from 2014 to my Elevate...they still haven' shown up...help!",
#  'all are great , but  have to go with :smilingfacewithheart-eyes::OKhand:',
#  'Sorry, Mary Martin had it first!',
#  "love all three but you really can' beat the classics!",
#  'Flight 0736 DAL to DCA /24 :10pm. Tried to check in could not. Status please.',
#  'heyyyy guyyyys.. been trying to get through for an hour. can someone call me please? :/',
#  "Hi, Virgin! ' on hold for 40-50 minutes -- are there any earlier flights from LA to NYC tonight; earlier than 11:50pm?",
#  'Congrats on winning the award for Best Deals from an Airline (US)',
#  'everything was fine until you lost my bag',
#  'Need to change reservation. Have Virgin credit card. Do  need to modify on phone to waive change fee? Or can  do online?',
#  ' emailed your customer service team. Let me know if you need the tracking number.',
#  'hi  just booked  flight but need to add baggage, how can  do this?',
#  'your airline is awesome but your lax loft needs to step up its game. $40 for dirty tables and floors?',
#  "not worried, it' been  great ride in  new plane with great crew. All airlines should be like this.",
#  'awesome.  flew yall Sat morning. Any way we can correct my bill ?',
#  'Or watch some of the best student films in the country at 35,000 feet!',
#  'first time flying you all. do you have  different rate/policy for media Bags? Thanks',
#  'what is going on with customer service? Is there anyway to speak to  human asap? Thank you.',
#  'what happened to Doom?!',
#  "why can' you supp the biz traveler like and have customer service like",
#  "'ve applied more then once to be  member of the crew team...Im 100% interested. -",
#  "you're the best!! Whenever  (begrudgingly) use any other airline ' delayed and Late Flight :(",
#  ' have no interesting flying with you after this.  will Cancelled Flight my next four flights  planned.',
#  'it was  disappointing experience which will be shared with every business traveler  meet.',
#  '’ having trouble adding this flight my wife booked to my Elevate account. Help?',
#  "Can' bring up my reservation online using Flight Booking Problems code",
#  "Random : what' the distribution of elevate avatars?  bet that kitty has  disproportionate share",
#  ' &lt; Flying VA But Life happens and  am trying to my trip JPERHI Can you help.VA home page will not let me ?',
#  'Why is the site down? When will it be back up?',
#  '"You down with RNP?" "Yeah you know me!"',
#  'hi,  did not get points on my elevate account for my most recent flight, how do  add the flight and points to my account?',
#  ' like the TV and interesting video . Just disappointed in Cancelled Flightled flight when other flights went out to jfk on Saturday .',
#  'just landed in LAX, an hour after  should of been here. Your no Late Flight bag check is not business travel friendly',
#  'why is flight 345 redirected?',
#  "Is it me, or is your website down? BTW, your new website isn'  great user experience. Time for another redesign.",
#  " can' check in or add  bag. Your website isn' working. 've tried both desktop and mobile",
#  '- Let  scanned in passengers leave the plane than told someone to remove their bag from 1st class bin?',
#  "What is your phone number.  can' find who to call about  flight reservation.",
#  'is anyone doing anything there today? Website is useless and no one is answering the phone.',
#  'trying to add my boy Prince to my ressie. SF this Thursday from LAX',
#  'why must  traveler miss  flight to Late Flight check  bag?  missed my morning appointments and you lost my business.',
#  'check out new music',
#  "how'  direct flight FLL-&gt;SFO have unexpected layover in Vegas  fuel yet peeps next to me bought for Vegas flight.",
#  'your no Late Flight bag check just lost you my business.  missed flight and AM apt. Three other people on flight had same exp.',
#  "- amazing customer service, again! :twohearts::twohearts: RaeAnn in SF - she' the best!",
#  'called your service line and was hung up on. This is awesome.',
#  "your site is tripping. ' trying to check in and ' getting the plain text version.  am reluctant to enter any card info.",
#  ' was scheduled for SFO  DAL flight 714 today. Changed to 24th due weather. Looks like flight still on?',
#  'has getaway deals through May, from $59 one-way. Lots of cool cities',
#  'has getaway deals through May, from $59 one-way. Lots of cool cities',
#  'has getaway deals through May, from $59 one-way. Lots of cool cities',
#  'has getaway deals through May, from $59 one-way. Lots of cool cities',
#  'Have  great week :sunwithface::airplane:',
#  'come back to already. We need you to take us out of this horrible cold.',
#  'should  be concerned that  am about to fly on  plane that needs to be delayed due to  "tech stop"?',
#  'is the best airline  have flown on.Easy to change your reservation,helpful representatives &amp;  comfortable flying experience',
#  'and again! Another rep kicked butt! Naelah represents your team so beautifully!! Thank you!!!',
#  'your beautiful front-end design is down right now; but it was cool to still book my ticket / all your back-end was secure.',
#  'Love the team running Gate E9 at LAS tonight. Waited for  delayed flight, and they kept things entertaining',
#  "Use another browser! 2015 &amp;  brand with  reputation built on tech response doesn' have  cross-browser compatible website?",
#  'And now the flight Flight Booking Problems site is totally down. Folks, what is the problem?',
#  ' like the customer service but  40 min delay just for connecting passengers seems too long. VA370',
#  'thanks to your outstanding NYC-JFK crew who moved mountains to get me home to San Francisco tonight!',
#  "you have the absolute best team and customer service ever. Every time  fly with you ' delighted. Thank you!",
#  'Do you provide complimentary upgrades to first class, if there are available seats?',
#  ' need to change my flight thats scheduled in  hours and 120 min wait time on phone. Im calling intern. Help!!',
#  'completely awesome experience last month BOS-LAS nonstop. Thanks for such an awesome flight and depart time.',
#  'How can  watch the on my JFK-&gt;SFO flight?',
#  'is flight 882 Cancelled Flightled and what do  do if it is?',
#  'you are failing your customers because your check in process does not link to TSA pre-check.',
#  'us too! Terrible airline! Just gave us  hotel hotline number and said sorry',
#  'has flight number 276 from SFO to Cabo San Lucas arrived yet?',
#  'your assistance yesterday when  Cancelled Flightled our flight was to give us  hotel hotline Shame on you!',
#  'Another delayed flight?',
#  ' need to register  service dog for  first class ticket from SFO &gt; Dulles. The phone queue is an hour or longer. Pls advise',
#  'you ROCK for making it so  can watch on my flight!!',
#  ', dropped  track on you...',
#  'always!!! Xoxo',
#  "why can' we book seats on your flights when we buy them or even during check in? Creates so much anxiety!",
#  "You' think paying an extra $100 bucks RT for luggage might afford you hiring an extra hand at",
#  'best customer service rep in the world! takes the cake!!!',
#  'Can you find us  flt out of LAX that is sooner than midnight on Monday? That would be great customer service :grinningfacewithbigeyes:',
#  "please provide status for flight 769.  cant imagine it' on time as the Web indicates dude to weather here and/or Dallas",
#  'you have amazing staff &amp; super helpful as  just ran the they have spoiled me with comfort!!!',
#  ' paid the premium to fly you across the country, you Cancelled Flight my flight and offer no check fee or upgrade love? Sad face :(',
#  "question: is it not possible to book  seat for an infant under ? It' not giving me the option but we want  seat for him.",
#  "Always have it together!!! You're welcome! RT : You're so welcome.",
#  "home to in' back to !",
#  ".  don' understand why you need  DM to give me an answer on if you have  damaged luggage policy.",
#  ". does that mean you don' have  policy for destroyed luggage?",
#  'is there special assistance if  travel alone / kids and  infant? Priority boarding?',
#  'thank you for checking in. tickets are purchased and customer is happy ;-)',
#  'is your website ever coming back online?',
#  '- Is Flight 713 from Love Field to SFO definitely Cancelled Flightled for Monday, February 23?',
#  'Is flight 0769 out of LGA to DFW on time?',
#  'my drivers license is expired by  little over  month. Can  fly Friday morning using my expired license?',
#  'having problems Flight Booking Problems on the web site. keeps giving me an error and to contact by phone. phone is 30 minute wait.',
#  'How do  reschedule my Cancelled Flightled flights online? The change button is greyed out!',
#  ' rang, but there is  wait for 35 minutes!!  can book the same ticket through  vendor, fix your site',
#  'got  flight (we were told) for :50 today..,checked my email and its for ;50 TOMORROW. This is unacceptable.',
#  "our flight into lga was Cancelled Flighted. We're stuck in Dallas.  called to reschedule, told  could get  flight for today...(/)",
#  "why don' any of the pairings include red wine?! Only white is offered :(",
#  'is the website down?',
#  '- Your site seems  little wonked right now. May want to have  look. Tried on two browsers. No CSS?',
#  "' disappointed that the agent at the designated silver status check in line closed to assist all pasengers",
#  'Plans to Include Austin to its Dallas Route - TopNews Arab',
#  'Is it normal to receive no reply from Central Baggage',
#  'at Logan airport and waiting to checkin for my 9am flight. Checkin desk not open !!!!! Why?!',
#  'to jump into the Dallas-Austin market -',
#  "Beats EPS Views, Takes On VA LUV - Investor' Business Daily",
#  'Lister to my show my on Monday 1230 130',
#  'to begin Dallas-Austin in April - 88. KETR',
#  'congrats, you just got all my business from EWR to SFO/LAX. Fuck you fl1289 SFO/EWR was the clincher...',
#  " applied over  weeks ago. Haven' heard back and ' flying this week",
#  "' love to know what your policy is for damaged luggage.",
#  'Thank you for the follow',
#  "- too many apologies! You  the worse airlines! Don' even respond to your cudtomers",
#  'shame on VA for making people spend money in stranded cities when other airlines are landing at JFK! Who will reimburse me?',
#  ' DM you',
#  'can you please have flights in SJC ?  have no choice but to fly Southwest to Vegas :wearyface::loudlycryingface:',
#  'too bad you say it takes 10 to 14 days via YOUR confirmation email. When  inquired after  weeks you claim  to  weeks!',
#  'Flight from BOS &gt; LAS tomorrow was Cancelled Flightled. No notification; wait times are + hour. Will you rebook on another airline?',
#  ':smilingfacewithsunglasses: RT : You’ve met your match. Got status on another airline? Upgrade (+restr): .',
#  'Only way to fly!',
#  'If only you guys had flights from CMH.',
#  ' lot of "apologies" being thrown out to customers from what  can see.Very sad. Thanks for nothing. Worst airline ever.',
#  'for all my flight stuff wrong and did nothing about it. Had ever',
#  'Having an issue finding  missing item on  plane. Can you help me find which airport my plane headed to next?',
#  'you will match my status? Cool!',
#  "“:You've met your match.Got status on another airline? Upgrade : ” ? :hear-no-evilmonkey:",
#  "trying to book  flight with you guys and your website won' let me... about to lose my business",
#  'you suck!',
#  'thanks!',
#  "Just DM'. Same issue persisting.",
#  "Because we never rec' Cancelled Flightlation notice we were left  no options to fly out of PS. Driving to LA for  red eye Mon  kids",
#  'trying to book  flight &amp; your site is down :beamingfacewithsmilingeyes:',
#  "You have any flights flying into Boston tomorrow?  need to be home and you Cancelled Flightled my flight and didn' do anything",
#  'you stink. Flight Cancelled Flighted from PSP to JFK and no notification or ability to rebook . better',
#  " love your guy' song! We're dancing to it for our high school dance revue",
#  "Your website is down and ' trying to check in!",
#  'done! Thank you for the quick response, apparently faster than sitting on hold ;)',
#  'nervous about my flight from DC to LAX getting Cancelled Flightled tomorrow! Just sent you  DM to help me!',
#  'cool picture of another VirginAmerica plane off our wing. What  site!',
#  'Keep up the great work :)',
#  'my goodness your people field are amazing under pressure :redheart:from Texas in crisis Please fly me to NY',
#  'Thanks for  great flight from LA to Boston! Pilots did  great job landing in the snow. Can we go back to LA now?',
#  'can you please get me to the new york area before monday afternoon',
#  'Thanks so much for the awesome support, you guys rock!',
#  "seats in Row  don' recline should mention that on your website",
#  'flight 404 delayed  hours in LA due to mechanical problems. Handle like pros but you could have tossed us  free drink.',
#  'why Cancelled Flight flights today? No precipitation to be scared of! :snowflake::snowflake::snowflake:',
#  'twitter team. you guys killed it for rescheduling me asap. thank you!',
#  "You guys charged me $100 to reschedule  flight that was then Cancelled Flighted and are now refusing to refund it. What' the deal?",
#  'can’ access your website from Safari on iPhone . Seems to work on Mac and iPad. Need iPhone to add Passbook.',
#  'on iPad and iPhone, clicking the CHECKIN link in the email  received at 24hrs before flight',
#  'your mobile site is broken, shows "{{header.elevateUser.numOfPointsAvailable || \'\' | number}} Points", won\' let me checkin',
#  ' was really looking forward to my flight. can you let me know when it will be rescheduled?',
#  'why Cancelled Flight flight VX413? One sec its delayed, on my to airport, the next its Cancelled Flightled?Gonna email or call me to reschedule?',
#  ' did it but there was  problem in the link from the email for check-in. thanks',
#  'had to change to another airline to get to DC today ... Why is able to land in DC but not you? Cost me $800 ...ugh',
#  ' was so looking forward to my first flight with you today but it was Cancelled Flightled along with the subsequent one ...',
#  'when are you putting some great deals from PDX to LAS or from LAS to PDX show me your love!',
#  'wish  can afford to fly with you next Friday going back home.. love everything about your airline',
#  'how are you gonna have  deal from Dallas to DC but no deal from DC to Dallas?',
#  'it’ just  bug report, guys',
#  'hold times at call center are  bit much',
#  'Like',
#  'Site down?',
#  'You have the best flight attendant ever!!!',
#  'Awesome! RT : Watch nominated films at 35,000 feet.',
#  'thanks so much!',
#  'Trying to reset my password, email never arrives. Help?',
#  ", the only airline based in Silicon Valley! '",
#  'Very nicely done. :clappinghands:',
#  '’ looking forward to watching the Oscars on my flight home tomorrow.  might even get something bubbly to drink! ;)',
#  'What is the reason for the delay of the departure of VX 413 from JFK this afternoon?',
#  'is todays flight from Palm Springs, Ca to JFK in NY Cancelled Flightled?',
#  'hahaha :facewithtearsofjoy: YOU GUYS ARE AMAZING.  LOVE YOU GUYS!!!:growingheart:',
#  'sounds like fun !',
#  'any updates on flight 413 from Jfk &gt; Lax',
#  'spruce moose!',
#  'the CSS on your site is  404 right now, please fix. Site unusable.',
#  "We're on flight 910 Vegas to Boston today, checked in online but our bag count didn' register. Can  fix that somehow?",
#  'classiq, luv Virgin America. Greetingz',
#  "Hi, ' trying to do check-in but the website is not working.  tried  different browsers and the problem continues",
#  'Thanks for your great customer service today &amp; for helping me get all my travel sorted out!',
#  'thanks guys! Sweet route over the Rockies',
#  'love the 90s music blasting at gate in while waiting for flight to . Only if  could get an iced coffee!',
#  "- the passenger in 7D, Flt 338 that assaulted me shouldn' have flown.  trust he' banned. Crew filed report to",
#  'current bug on website shows ‘select departure city’ when selecting destination city',
#  "luggage was severely dented/missing wheel coming off baggage claim in SAN. Luggage agent Miranda ( think) wasn' any help.",
#  'thank you for the easy itinerary shift for impending weather. Quick, painless &amp; free.',
#  "If you' love to see more girls be inspired to become pilots, RT our free WOAW event March - at ABQ.",
#  'Thanks! Good times there and back! the entire flight:cocktailglass:',
#  'beats expectations, shares take off - Santa Cruz Sentinel',
#  'any plans to start flying direct from DAL to LAS?',
#  'BIG Love/gratitude.mpower / weRin VIPswagbags',
#  ", you're doing  great job adding little luxuries/aesthetics that improve the air travel experience. Thank you. Keep it up!",
#  'requested window seat and confirmed window but got stuck in middle seat. Not  good way to treat silver member:unamusedface:',
#  'Grand Budapest Hotel',
#  'This is what you missed . Next trip to the 407.',
#  ' paid for direct flight on purpose not to have to stop for fuel exhausted frequent flier and nothing for inconvenience!',
#  'there is something wrong with you website in Safari iPhone',
#  'thanks for gate checking my baggage on your full flight dfw-lax 883 and giving me early boarding too',
#  'Already checked in so the page expired :',
#  'Boo for  not refunding  seat upgrade fee  did not want to buy in the first place!',
#  'shares rise on Q4 financial results - USA TODAY',
#  'Adds Pillows Instead of Lie-Flat Seats in First Class Arms Race',
#  ' see what you did there ;)',
#  'way to take advantage of :)',
#  "you know ' flying virgin for the fight",
#  'your inflight team makes the experience !',
#  "cutest salt and pepper shaker ever. Just when  think you guys can' get any better you just do!",
#  'moved my seat with no notice. "Better seat" is cabin select not behind the row  selected:thumbsdown:',
#  'shares up on 4Q results -',
#  'fav airline',
#  'we have  hot female pilot! Sweet! DCA to SFO! :-)',
#  ":thumbsup::thumbsup::airplane::airplane::growingheart: When are you guys going to start flying to Paris? : You're welcome.”",
#  'what is your policy on flying after surgery?  am still waiting for answer so  can tell me doctor.',
#  'already contacted Central Baggage &amp; sent DM. is charging me for the dress that was in the lost suitcase',
#  'Thank you!!',
#  "Is there anything going on with the website? 've been getting  lot of errors past 30 minutes.",
#  ' think  left something on the plane yesterday. who do  call...ah!',
#  ' need you to follow back in order to DM.',
#  'Need to start flying to . :smilingfacewithsmilingeyes::grinningface::grinningfacewithbigeyes::grinningfacewithsmilingeyes:',
#  'they told to check with the airline regulation first so that is why  contacted you.',
#  ' have just checked in flight to SFO from LAX &amp; been told as Atlantic Flying Club Gold  get no benefits?!',
#  'husband and  ordered three drinks via my screen and they never came. Awesome!',
#  'soooo are you guys going to leave the seatbelt light on all flight? You can barely call this turbulence :-)',
#  'what is your policy on flying after surgery?',
#  'posts second consecutive full-year net profit -',
#  'Funny story, your website is broken, you have missing javascript and stylesheets on the checkin process.  dislike this!',
#  'would love to do more for virgin just like  do for',
#  'Results Handily Exceed Forecasts -',
#  ' applied for  position in ,and  was wondering if you guys received my application.',
#  'achieves  second year of profitability despite revenue pressure ... -',
#  'gives positive outlook, but sees increased competition -',
#  "' trying to check into my 10:50AM CT flight tmm on the desktop website and it' not working (some sort of caching bug) SOS",
#  'weather delays &gt; next few weeks ;)',
#  'check the website before you go to the airport!',
#  'Do you guys know your check-in links from emails are broken?',
#  'pilot says we expect  choppy landing in NYC due to some gusty winds / temperature of about  degrees &amp; /the windchill -',
#  "loved it. Can' wait for Monday' return flight... Mostly just to watch the inflight safety video again.",
#  "lost my luggage  days ago on flight VX 112 from LAX to IAD &amp; ' calling every day, no response.Please give me back my stuff",
#  'The Flight Booking Problems section of your website seems to be broken on Chrome. Might wanna look into that.',
#  'Hi! Just wanted to see if you have any new routes planned this year for Newark. Love flying you guys and hope to do so more!',
#  " mean. Probably inappropriate while on board.. But, it' on!",
#  "happy to spend the day together. Let' do this!",
#  'is saving my sanity right now:',
#  'missed my flight. How does standby work?',
#  '. They were very understanding and helped me out. Thx!',
#  'brought it all the way across the country today  see',
#  'thank you!  absolutely will :smilingfacewithsunglasses:',
#  'Looks like  broken link for your assets',
#  "are you ready!? Let' say it together.. 'Noooo turbulence today!' :faceblowingakiss:",
#  'the manage itinerary section of your website seems to be broken for me',
#  "can' check in, your site looks like this every time it loads",
#  'can  help this :princess: needs urgent treatment in:UnitedStates:2y old battling cancer could  help with flights :growingheart:',
#  'may start service to Hawaii from this year',
#  'Other carriers are less than half price for  round trip fare.  am stunned.',
#  'WTF is happening in PDX Late Flight March such that one way from SFO is ~$550?',
#  "add DTW and ' sold!",
#  'How about some free drinks on the flight back for the free promo?',
#  'thanks!',
#  'momma  made it! :beamingfacewithsmilingeyes::beamingfacewithsmilingeyes::beamingfacewithsmilingeyes:',
#  'please contact me about portfolio left on flight VX 27 from JFK to SFO tonite seat 7AM. Need it returned. Call 914-329-0185.',
#  'help.  was On Flight 27 from JKF tonight. seat 7C left portfolio. Need it back!!',
#  "Seattle bound. Wifey got me the duffle for vday. She'  keeper!!! Holla!!!",
#  "my luggage is gone. 've filed my paperwork, promised  call/email. Still no resolution or response from central luggage.",
#  'Debbie Baldwin gave  performance of the safety demo this evening on VX919',
#  'Thanks!',
#  'thanks for taking care of on her flight!!',
#  'Thanks for the lovely soft views! to',
#  " requested  mileage challenge for status several weeks ago online but haven' heard back. How do  get help with this?",
#  "Just trying to book tickets to NYC and facing super fun broken styling. Don' worry, 'll keep trying :)",
#  'Many Thanks for the Follow. Looking for Any Help:smilingfacewithheart-eyes: :growingheart::UnitedKingdom::growingheart::UnitedStates::growingheart: :ribbon::globeshowingAsia-Australia::ribbon:',
#  'Nice, Lofty View .',
#  'Applied for Status Match on Feb . Got confirmation email same day. Still no news though. You guys have dropped ball Late Flightly :sadbutrelievedface:',
#  'is my new go to airline',
#  'Can You Help in need of some help in :ribbon::UnitedKingdom::ribbon::UnitedStates::ribbon:',
#  ' adore you, and am so looking forward to my flight to Austin in two weeks.',
#  ' was so glad it was mentioned.  took my first virgin flight  few years back and it was  transformative experience.',
#  'Flight Booking Problems flight to uphold my status match. Do taxes on ticket count as earned status points?',
#  'trying to check-in...but looks like your site is down?',
#  'spending my birthday night with you, DAL-DCA. Get me home!',
#  'Sent  couple messages to the email you provided but to no avail. Will try again next year. Cheers.',
#  'first time flying Virgin, went to .Thanks for the smooth ride. Easily my new fav airline!',
#  'seriously, though. will there not be direct flights from SFO-FLL in may???',
#  "It' fine. Already done with my purchase. But you should try it. Just go most of the way through then go back ",
#  'not really the experience  was hoping ,  ws forced  check in  small carry on, / nothing but empty cabin space on board',
#  'wjere is our luggage slow at lax',
#  'to jump into the market',
#  ' spoke with  representative that offered no solution,  am  loyal customer who flies on as well',
#  ' am deeply disappointed that your birthday promo was not applied to  trip  booked mere days before  received the email',
#  'what happened to direct flights from SFO-FLL? Looking in May, only see connecting',
#  '.. Can you help? Left my blazer in. Kooples jacket bag at 3rd row second seat from right gate 36 T3 lax.. Flight to sfo',
#  'partners with Checkout as mobile payment method to help boost mobile conversion rates',
#  'just promoting the product is all, had  problem with southwest and recommend noneother than the best!',
#  'love you guys, but pls get some direct routes LAS to AUS!',
#  ' would like help with some flights please.',
#  'Bruh “: Turn down for what. ”',
#  "of course!  work for and ' obsessed with the entire Virgin family!!",
#  'ok! first time flying with you tonight :)',
#  'Digging the swanky pink mood lighting during the flight from NYC to SFO. Just needs  cabaret singer. Think about it!',
#  'Done, but  need the receipt ASAP. Could you please help? -000114',
#  ' have 2d and 3d embossed badges and patches superior to the ones you are currently using.',
#  'on VX399 from JFK to LA - dirty plane - not up to your standards.',
#  'on flight VX399 headed to LA from JFK - dirtiest VA plane  have ever been on. Sad for  great airline.',
#  'got it squared away. Someone picked up as soon as  tweeted. Should have tweeted sooner. :winkingface:',
#  "your Avis rental continue button doesn' work on your website to book car. Tried  times on phone. This sucks!",
#  'delayed to10.30!!',
#  'currently in minute 10 of being on hold with cust. service. Do  need to do anything to add  lap child to my reservation?',
#  'Adds Pillows Instead of Lie-Flat Seats in First Class Arms Race by',
#  '“: Of course. Have fun celebrating!” Thanks! Happy Chinese New Year!',
#  'Flight Booking Problems last second flight for next week from SFO- to SAN any chance you want to gift me  promo code since  love you guys',
#  'Comenity Bank is  joke! Please change. Nothing but constant problems with this bank',
#  ' just did, how can  DM? Do  have to also add me?',
#  "For my Grandma Ella' 80th, she would &lt;  bday greeting from your flight crew! She was  stewardess for Eastern Airlines.",
#  'Just bought tix for ATX - Dallas route - thanks for adding that! Love yr airline &amp; yr website is BEST transactional site EVER',
#  'Anytime, sugafly.',
#  "gave  credit for my Late Flight flight yesterday. Great service !!!! That'  Wow moment! Unexpected gesture!",
#  ' need  receipt for  flight change. Can you send one?',
#  ',  submitted  status match request  while back and still haven’ heard! ’ flying on Monday. Can you look / accelerate?',
#  'had me at their safety video . . . LOVED my first cross country flight.',
#  "that doesn' look to fat to me! It looks yummy!",
#  'CEO says &amp; have strayed from low cost model.',
#  ' brilliant brisk am in Boston in cue for vx363',
#  'Atlantic ploughs  lone furrow in the',
#  'Atlantic ploughs  lone furrow in the',
#  'Atlantic ploughs  lone furrow in the',
#  'omg omg:smilingfacewithheart-eyes::smilingfacewithheart-eyes: nonstop Dallas to Austin on virgin:sparkles::facescreaminginfear::airplane:',
#  'Your planes are really pretty. Just thought  should know that. :)',
#  'when are you flying to hawaii',
#  "' pulling my hair out trying to book  flight with . Your site doesn' work on iPhone or iPad.don' have  computer",
#  'thank you',
#  "Can  get some help with  support ticket? It' been 15 days.... Incident: 150202-000419 Thank you!",
#  'good to be home',
#  ' cannot even open my laptop in seat 4C and  paid  premium for this?!! Let me out of here!',
#  ' am in seat 4C and  cannot even open my laptop; and  paid extra for this seat!!',
#  '. If only you guys were starting those flights at the end of the month! Guess ’ still road tripping on Feb 27…',
#  "thanks for that. Been needing  way to make those Austin trips from DCA, and now you've come through!",
#  'announced New Route to Austin /fares from $39/way.',
#  "Really? Sprint?  thought you guys were 'kewl'! 00",
#  'this is too cool! Never been on ur planes but now  will!!',
#  'you should have 39 dollar LAX-Las fares!!!',
#  'great. Well deserved.',
#  "FYI the info.com email address you say to contact in password reset emails doesn' exist. Emails bounce.",
#  'Status match -  weeks have gone by and no news.Flt next week - hope flt will count towards requirement. Cust Svc no help!!!',
#  'your website sucks donkey dicks. Just thought you should know. All best.',
#  'You should still develop an app - then you will be my favorite airline.',
#  'all crap channels which is why  pay to watch UK tv',
#  'got it. All set - Thanks!',
#  "no ' channel this year?",
#  'Only thing  see on passbook is Virgin Mobile Mexico. How do  integrate?',
#  'Giants and Virgin America.  match made in heaven.',
#  'thank goodness!! Also, see you friday, nwk&gt;sf.. BOOM!',
#  "how come you don' have an iPhone app? Still using and making me waste paper.",
#  'Your back of seat entertainment system does not accept credit cards that have an apostrophe in the surname.',
#  'When will VX use all  LGA slots instead of  today? Adding AUS makes this less likely :(',
#  'is helping me step up my game!',
#  " luv ur people and product!  thing is  do  charge for herbal tea but not black tea? ' not  caffeine drinker",
#  "thank you! See 'all soon! ' excited to see the expansion of destinations. Spread those wings!",
#  'announces new nonstop connecting &amp; , $39 intro:',
#  'adds Austin-Dallas Love Field route.',
#  'sad to learn you no longer fly SFO &gt; PHL. Hope it returns!',
#  '- can you tweet me the Cancelled Flight/chng fee for  flight? or can  rebook under one of your affiliates? If so, who are afiliates?',
#  "has the most INCREDIBLE customer service 've ever experienced! So refreshing!",
#  'Now, when will we see VirginAmerica come to Philadelphia (PHL).',
#  ', am  dreaming? Did you really just open up  route between Dallas and Austin?! And does this mean Houston might be next?',
#  'OMG FINALLY',
#  'to start 5xweekly flights from to on 28APR',
#  "Nice to see you expanding in Texas but don' forget about us here in .  would love to see more flights out of here!",
#  "kinda sucked my earphone jack didn' work on my flight. They may want to look into that for future passengers",
#  'Very poor experience. First computer problem now seat malfunction. Stuck. Missing meeting in San Diego.',
#  'to battle on - route via',
#  'the DAL-AUS route makes my day!!!!',
#  'awesome deals DAL-AUS for only $39 each way!',
#  ' miss the in San Jose',
#  'love it, taking on in their backyard! Consumers win when biz competes.',
#  '\u200b is flying from Love to Austin now. That is most excellent news.',
#  'can we make every VX plane with ? Why should Austin be the only one getting nerd love?',
#  'please add more frequency to PDX Portland',
#  'Congrats VX on the new route! :airplane::partypopper:',
#  ' tried that. You offered to charge me an additional $1k for  new ticket or be stranded until Thurs. 1st time, last time.',
#  'can  help with flights to get  2y old battling cancer who needs treatment in :UnitedStates: :growingheart: :ribbon: :growingheart:',
#  'Never had  bad experience before, but this one took the cake. Now extortion for carry on items as well?',
#  "Had to spend  hours worrying that items in carryon would be broken/stolen since  couldn' carry them on plane or lock bag.",
#  'All of group  was told there was no more room in the bins. when  got on the plane, was room for at least  bags in my row!',
#  'Thanks for making my flight from LAX to JFK  nightmare by forcing me to check my carry on bag at the gate. ()',
#  " have lots of flights to book and your site it not working!!!! 've been on the phone waiting for over 10 minutes..........",
#  ' am all about the in flight artisanal cheese and wine pairing.',
#  'does Virgin America fly direct from Seattle to NYC or Boston?',
#  "That' classy.",
#  "' sure  lot of your 747 and 777 JFK-LHR flights go  lot faster than 513mph with  strong tailwind.",
#  "now it' just -minus 32 minutes until my Elevate  Silver upgrade window opens . :grinningfacewithbigeyes::thumbsup:",
#  'save some for 871 tomorrow AM!',
#  'Why is it taking 12 years to fly home to Dallas? Get your shit together.',
#  'club Virgin is bumping in New York',
#  'would have been  rough trip but LUCKILY we were on  flight.',
#  'is that ??:beamingfacewithsmilingeyes:',
#  '...Please come to Minneapolis St. Paul!',
#  'YES FYI MY BFF',
#  'another perfect flight. How come on your planes, the sun visors can stay down? Other carriers make you raise them?',
#  'Nice RT : The man of steel might be faster, but we have WiFi – just saying.',
#  ' love the dancing little richard. cool beans.',
#  ' don’ use Passbook =/  still love you though &lt; :) ’ll just use my email in the future.',
#  "thanks for the free birthday points! 'all are ALL RIGHT with me!",
#  'do you have an application for iOS? Was looking and only saw Virgin Mexico :( &lt;/',
#  'Man of steel flies to more cities though...and with more frequency too.',
#  'thanks so much for sharing. Just added it to my site',
#  'Good point!',
#  '.  heard he has  virgin mobile hotspot ;)',
#  'you got cheese pLate Flights too.',
#  'On all your flights?',
#  'Dad on Segway is the best part of this whole infographic!',
#  'Are there any plans for  short haul airline in Europe? Would defiantly fly with you guys :)',
#  'wifi AND better seating.',
#  "how come ABC is the only one of the network channels you don' have?",
#  'started my flight with  scolding for using an overhead bin that was then offered to the person seated next to me.',
#  ". not only was it great, but you return my calls the day after. Couldn' ask for more.",
#  "While other airlines weren' Cancelled Flighting flights into BOS, and helping their customers get home, Virgin was saying Good luck!",
#  "Dear Virgin customer, while you're stranded in SF for  days &amp; $1000cost- we'll do the very least we can to accommodate you!",
#  'should use this in their next airline commercial lol ::',
#  'Grouping Virgin in with the others now. BOS weather has exposed their actual Cus Serv model. Never Flight Booking Problems with Virgin again!',
#  "As one of the travelers affected by the Boston storm, ' shocked at Virgin' complete apathy toward their customers.",
#  'Umm so no reason as to why this is? Is there someone different  should contact (or contact me) to get  definitive answer?',
#  'Trying to make the change in advance (not just 24 hours prior)…tried it online earlier and it wanted $300 in change fees.',
#  "so loyal that ' driving to from , to fly Virgin, since you cut flights ;)",
#  'Any way to change from Main Cabin to Main Cabin Select (on same flight) without paying  change fee penalty?',
#  'you guys are perfect as always! &lt;',
#  "thanks! 'all have some of the best customer service left in the industry.",
#  'Can you give me Silver Status for 12 months?',
#  "really wish you' fly out of those fares are amazings",
#  'mood lighting on point:raisinghands: Reclining my seat, kickin up my feet:zzz:',
#  'my flight (6000) scheduled for 1pm departure still says on time but no plane at gate. Any update on how long of  delay?',
#  "my group got their Cancelled Flightlation fees waived but  can' because my ticket is booked for /18? Your reps were no help either :poutingface:",
#  'Are there any sign up bonuses to enroll in Elevate?',
#  'just got on the 1pm in Newark home to LA. Your folks at EWR are incredible',
#  'morning. If  have  question regarding elevate points &amp; flights can  DM you?',
#  'still waiting to see :disappointedface:',
#  "was wondering if you guys recieved my dm and we're able to potentially respond asap",
#  'Flying LAX to SFO and after looking at the awesome movie lineup  actually wish  was on  long haul.',
#  '“: Book out of town with fares from $59/way (+restr). ”',
#  'thanks',
#  'Thanks for taking care of that MR!! Happy customer.',
#  "still no refund or word via DM. Please resolve this issue as your Cancelled Flightled flight was useless to my assistant' trip.",
#  "Delayed due to lack of crew and now delayed again because there'  long line for deicing... Still need to improve service",
#  "thanks -- we filled it out. How' our luck with this? Is it common?",
#  'Your ERI-ORD express connections are hugely popular .. now if only we could have an ERI-EWR hop! :)',
#  'even on international flight Glasgow to the ..? Then what about orlando to Newark? All 90 mins?',
#  'you think you boarded flight AU1066 too early?  think so.',
#  " understand, but it' tough when there is no way to get to the airport / serious risk of an accident. It'  steep price.",
#  'Gate agent hooked me up with alternate flights. If you have  way to PREVENT the constant issues, that would rock.',
#  'flying gla-mco in  few weeks. How long do we have to be at airport for before departure for both international and domestic? Ta',
#  'thanks',
#  'Thanks. It is on the same ticket.',
#  'why not? Is it  law or  policy?',
#  'is the worst. Nonrefundable First class tickets? Oh because when you select Global/FC their system auto selects economy /upgrade.',
#  "So  can buy tix  days before flight but can' transfer the tix. Flawed security logic. Flawed customer service",
#  ' did start  claim but -10 weeks is unrealistic, am  really supposed to go that long with out  car seat for my child.Ridiculous!',
#  'follow me please this airline is beautifull :heartsuit:',
#  "no  don', but ' sure United have my info on its system.",
#  "if the car seat is lost should just reimburse me for  new one, this is not  pair of shoes, it'  necessity for my child",
#  'Just submitted my response on the link you sent.',
#  'yes, David Allan send an email with this number (KMM24999563V99860L0KM) and case',
#  'that totally sucks my cousin worked at PHL said',
#  'just wanted to let you know how wonderful Rosetta the gate agent was working flight 6457 Dan to Ase. Let her know she wasappreciated',
#  'yes,  paper voucher that  got on January 26th 2015',
#  'beginning of Feb  called United they said they would send another voucher by mail. Never got anything.',
#  'the internet is  great thing.  am emailing executives in your company, maybe they will respond to me in  timely manner.',
#  'Do  need to use  Chase United Club pass for my 8yr old son, or can he come in with me on my pass?',
#  'and what am  suppose to do with that number?',
#  'thats weak. See ya :wavinghand: Hey !!',
#  ' flew back  other company since United didnt have an earlier flight',
#  ' lost  voucher that  was given in Miami aeroport on jan 26.  did not use it.',
#  ' am trying to book awards for September and need flights on but they will not show even / many award seats availab',
#  " sure did.  had to drive  total of  hours to get my own bag. ' like to explain that debacle but no one wants to talk to me.",
#  "Gee that' like almost caring about ppl more than $$. Think ' more int in having  trusted adult / daughter .",
#  'See? We were told repeatedly that the pilot was Late Flight and kept getting Late Flightr. After we boarded, there was  defibrillator issue.',
#  "why no preferred security line anymore. My TSA pre-check didn' pull on my partner flight!",
#  "Airport need to indicate different gate' for terminals &amp;.",
#  'yes please!  am newly married and trying to update my last name on  preexisting international flight! It seems so easy, but...',
#  "How does United refuse to reissue  $400 lost voucher when their plane didn' take off due to mechanics?",
#  'also during the run  was instructed to do,  shattered my computer.',
#  "yes, we've been with the agents for the last 50 minutes. One of the agents have been very rude, but thankfully Ladan has been nice.",
#  "that' right- with an overnight Miami.",
#  'Have clients with an 11 hr layover at IAH (during the day). Will they have to claim &amp; recheck luggage. Or will it be taken care of?',
#  ' am trying to find out if the loaner seat is new or used,  used car seat is illegal according to safety regulations',
#  ' DMed you the details',
#  'iah to charlotte. Baggage claim rep latrice . non existent, Ignored customer then inappropriately touched customer',
#  'Kewl. Will also let them know the overhead bin over my row was "Inop".  love  good abbreve.',
#  '- thanks for your help...got me what  need, but its an issue with .  guess  sit awhile longer.',
#  '-  would have loved to respond to your website until  saw the really long form. In business the new seats are bad',
#  ' refund and flight vouchers or another flight on  different airline at your expense for today.  hour drive is very inconvenient',
#  "then why have  not received my call back its been  days...it' an infant car seat how am  supposed to go anywhere with my child",
#  'thanks again for your concern.  will contact customer care upon our return from Australia.',
#  "well sitting on the ground 'on time' but waiting for  gate....again",
#  '"Airport snow removal method ..." Keep up the good work folks, this is where Cessna\' become 747\'!',
#  "No,  need you guys to not over book planes. It' not  concern, 'll just travel with someone else moving forward.",
#  ' measly $50 -certificate is not how you appreciate loyal customers after they wait 3hrs on the tarmac during UA1116.',
#  "When will email address/username sign-on be available? It' been  while.",
#  'Thank you for that. Am  able to claim any interim expenses or is the cost of the stuff up on me?',
#  'rude rude',
#  "- Why can'  get  boarding pass for my Austrian Airlines codeshare flight. Rebook incls   hour layover &amp;  am stuck outside sec",
#  '. .. received on other flights. truly breaks guitars.',
#  "just flew to paid $100 from  third suitcase which didn' even make it on the plane! Besides for the impolite service...",
#  'My bag is still in Colo Springs.  am disabled and have to search an unfamiliar airport and look for my bag. Not  good outcome',
#  "Shame that there' no flex to tickets transfer rules. Even calling from Neurosurgery ICU isn' enough!",
#  "No. Denver said they don' handle baggage that made it to Colo. Springs. They gave me an 800 number to call. No help there either.",
#  'you guys need some serious training in customer service. Too many better options to put up with the way you guys handle ur mistakes',
#  '6533 ORD to DCA',
#  'once he found out we had  problem he avoided me like the plague. Was told "we can\' find  supervisor."',
#  "ZCC82U Cancelled Flight flight 16h in advance??? Need connect flight reschedule so the link isn' helping. Help!? Gf waited months to see me.",
#  ' will not be flying you again',
#  "in addition, my first flight was delayed an hour and ' arriving at my destination  hrs Late Flight.",
#  "Cancelled Flighted our flight, didn' rebook us on added flight, now have to drive from  Denver to KC....thanks!",
#  'your announcement for pre boarding only addresses mobility. My disability requires me to travel with  lot of stuff. Do  preboard?',
#  ' flew United last month and the experience was AWESOME!',
#  'our travel booked thru United group dept. Okc ticket agent less than willing to help with our connection in LAX.',
#  ' upset with your disability "services". When  told one of your employees  was carrying medical equipment she was very rude.',
#  "thnx for quick reply but don' think you can assist. Our intl grp will be put to considerable inconvenience today.",
#  "wont transfer flight ticket to accompany an 11 yr old who' active military mom had to have emergency brain surgery? WOW!!",
#  ' WEEKS Late FlightR AND  STILL HAVE NOT RECEIVED MY MILES FROM THE MileagePlus Gift Card $150 STARBUCKS CARD  HANDED OVER!!!',
#  "as  1k, ' always hoping for improvement.",
# ...
#  'Made the upgrade list. Will fly 1st tomorrow (for 40 min) for the first time ever! :raisinghands:',
#  'not just refunded, but for those of us who are on vacation to get  free room night to make up for making us sleep in DIA',
#  "Thanks for the reminder. It' been  fun ride.",
#  " received my luggage that also looked to be left in the snow when  arrived. ' asking for all 50 people to be refunded.",
#  "updated A320 aircraft has wifi and device entertainment but no outlets.  don' get it. How can  charge devices?",
#  'was no one between the scan and inside the plane.  just asked the people in line around me where the plane was going',
#  ' gate changes, two delays. Even the crew thinks the airline sucks',
#  "' very frustrated and have wasted  days now due to your equipment failures.",
#  "computers are down but you stopped giving updates and took my flight info off the app. That' just ridiculous keep people updated!",
#  "Soooo, it' been 15 days and you've offered no response. So  assume poor treatment by gate agents is the norm now?",
#  'Terrific. Many thanks. Looking forward to being back on UA tomorrow. Had  great flight up to Vancouver.',
#  'Calls to 800 resulted in 2hrs of hold time &amp; 2day wait to check suspect code share fare. Nothing investigated—my time wasted (/)',
#  "It' taken ~ weeks for Cust Care to respond to Case , requesting  refund for wi-fi not working. Where can  get an update?",
#  ' appreciate your efforts getting me home!',
#  "That' correct—'ve spent hours trying to book online only to receive an error when clicking final purchase button. (/)",
#  'Today was not your finest. All could have been prevented by one gate agent advising 200 passengers.',
#  'what is the real deal with the delay on flight UA 1032 from Denver to Vegas?',
#  'UA63 from Madrid arrived no agent mass confusion we sent to and fro by  UA employees. MaryJo was rude and unhelpful.',
#  "system failure again = bad trend. Software projects are like flying an airplane; there' no such thing as an emergency takeoff.",
#  'lots of reports of system failures delaying flights over the last week. Currently sitting on the tarmac at OGG for over an hour.',
#  "rebooting Chicago dispatch system, need as ' tired of sitting on planes",
#  "despite shaky connections, looks like 'll get home tonight. Great job, - was touch and go for  while..",
#  ', however, is completely under your control—the price was and still is displayed on .',
#  'the aircraft closest to gate was for the other flight and the one closest to our gate was going to Chicago.',
#  'can you tell me how to file  claim for clothing that had to be purchased?',
#  'comically on the return flight from ASE there were two United flights boarding at adjacent gates and not clear which plane to board',
#  'GRK13575M is the file reference',
#  'we would...how do  contact you to discuss?  few poor experiences with customer service but would give it  shot!',
#  'UA 746. Pacific Rim and Date Night cut out. Not constantly or randomly, but one spot, repeatably.',
#  'Been trying since 1230 to file  report.',
#  " send an email about my bad experience and you send back  generic response. Yet another reason why 'll never fly with you again.",
#  'My mom left her Kindle on flight 1544 today. Burgundy case with  light. Seat 27D. Did anyone find it?',
#  'here is the ticket 0162424965446 please refund my unnecessary upgrade fee',
#  "is horrible!! They lost our carseat and expect us to use  loner carseat, safety regulations say it' illegal to use  used car seat",
#  'thank you.',
#  "Decisions Decisions : We' love for you to try our service. We offer status match too. ^KP”",
#  "Need more info on that! : We have great amenity kits. PJ' not included. We status match AA. ^KP”",
#  ':  don\' care that  link showed me  "wrong" price on your site—it\' your site &amp; responsibility to ensure correctness.',
#  'Do you have any flights with lie flat seating from STL to PDX around the date of March ?',
#  "He needs to get to home the 24th, they're telling him it'll be the 25th night. Is there compensation or anything that can be done?",
#  "“: The baggage fee is waived for Premier members. Please see . ^JP” what' the point of membership?",
#  'wonderful bag claim people - finally have my bag. But why did  catch earlier flight? Original flight just landed.',
#  'Dmed you. Thank you',
#  "thanks we'll be in touch!",
#  "Thanks to Karen Salisbury at IAH for amazing customer service! Found my daughter' bag lost on UA1516. Made her day!",
#  ' days Late Flightr and my bag has not left IAD, United is not helping at all. Everyone tells me  different story',
#  "hi, when do direct flights from Houston to Reno begin? Don' see any days in March?",
#  "like continental' chicken feat fairs",
#  'can you assist with current flight status for flt 1016 out of DFW tomorrow at :55am?',
#  ' left my comment with customer care. Thanks for contacting me.',
#  'how do you lose  gate checked bag DEN to ORD? Direct flight. Ugh.',
#  "caught earlier flight to ORD. Gate checked bag, and you've lost it at 'Hare. original flight lands in 20minutes. !",
#  "Yes!! Thanks so much!!! :purpleheart:“: We see you spoke with our Reservations team and they've reinstated the flight. Thanks. ^EY”",
#  'captain "on behalf of the front office, welcome on board.".... Never heard that before.  laughed...hard.',
#  'Can you please follow for  Dm on  missing bag?',
#  'to be clear on my luggage comment,  am referencing the photo attached. Flight 6232 to JAC',
#  'These are great fares!!!!!',
#  ' left an item on the plane and have been calling non stop and no one has been answering can you please help',
#  "awesome 'll book my next Christmas vacatinn this December any other ways you want to devalue mileage plus.",
#  "what'  good number to call to speak with someone about how you can fix what you did to 50 people and their luggage on Saturday?",
#  'THANK ! Secured room for the night Thx to VERY helpful customer service rep . Dorns..  thanked her.. Can  ?',
#  "where' my damn bag??",
#  'well someone should tell that to the employees at the Denver baggage claim. Still no bag!!!!',
#  'Greetings. UA Club member here. Any idea if  can use the Air Canada Lounge at YVR. Flying UA tomorrow.',
#  'how is Mexico not international from the us?',
#  "diverted and missed our connecting flight. Was just told that my bag is on it' way to MSY. If you only had people that cared",
#  "Male agnt in LAS threatens Canadian cust when cust takes pic of him at gate after agents announce can' help rebook. ?",
#  'we just want to go home tonight - why did you Cancelled Flight the last leg of our reserv. /out our permission??!',
#  'Stressed and rude agents. Overwhelmed by delyd flight LAS-DEN 1657. Yelling at several people. Not pretty. This is ??',
#  'landed in Boston at  last night. The 15 hours of traveling was rough tho.',
#  'FAIL You Cancelled Flightled our flight frm GJT and then used our reserv home to IAH (from SEA) for reFlight Booking Problems /out OUR PERMISSION!!',
#  'Just sent thank  RT : Please DM your confirmation number if reFlight Booking Problems is needed. Thank you. ^EY',
#  'has made my no fly list. Other airlines wait when connector Late Flight. Stuck in IAH.',
#  'so what’ the deal? Do  provide voucher for overnight or am  cozy on the floor at ?',
#  'also, the mere fact that  have to go online to issue  statement vice calling and talking to some directly is one good example.',
#  'thank you.  flew into Newark from Vail/Eagle.',
#  ' have  weekend of dealing with your company that would say otherwise.',
#  'now what?!? flight was gone when  got off plane!',
#  "the proper response: sorry for your wait, what flight were you on so we can look into the issue. That' how would handle.",
#  'your customer service is terrible! Stood inline  hours no flights and  hours Late Flightr still no bag',
#  'please upload the March on-demand entertainment listing on your website! :airplane:',
#  'So you are inadequate by accident?',
#  'Denver International Airport',
#  'Thank you for responding so quickly with  helpful tool!',
#  'boarding time shows 35 min and your gate agent started at 45. showed up at :00 and they had to check bag.',
#  "Agent in LAS letting 20 customers know they can' help them rebook delayed flight to DEN",
#  'empathizes / my disappointment that 1stClass flight /nonworking entertainmnt is worth $50.',
#  "...and when that doesn' work...",
#  'did you have seen my message today?? About  mcdonnell Douglas dc 10 model??  will hear it if you read it, Goodnight now',
#  "searched for mileage tickets to BOM couldn' find  single one is saver awards -  see how you play. Earn miles but can' use them.",
#  'flight arrives 30 minutes early, but then have we to wait for an hour for our bags.',
#  "That' not the issue. The fact that no one even called (despite promises) to confirm the bag' location is.",
#  "what'  girl gotta do to get  flight name change when SHE bought one for  mean ex boyfriend and needs  girl' trip stat?!",
#  'thank you. We are signed up for notifications. We shall watch and wait! :snowflake::snowflake:',
#  'still waiting to hear back. My wallet was stolen from one of your planes so would appreciate  resolution here',
#  ' would love if someone could get me back to Austin tonight and  do not wish to wait til tomorrow morning.',
#  'or has lost my baggage… heard different things from different employees of . has said nothing.',
#  'cs thinks that miles can repair the damage done, it will be interesting if they travel in and exp the worst flight ever!',
#  ' have  0530 flight out of DFW on Tuesday. How far in advance will you give notice if Cancelled Flightled?',
#  ' am signed up for notifications. This is the first trip  was not updated on. Not sure why this happened.',
#  "Thank you. Took care of everything and made it right. That' the experience ' used to. Opened the app to find flight changed.",
#  "that is not in line with your responses here. And now ' waiting until tomorrow morning because all the flights are overbooked.",
#  ' took the exact same aircraft in to LAX  days ago. It fit, no problem. The agent today told some nonsense about  policy change',
#  'your helpful agents in Club helped.  am just out baggage fees and  night of my life.stop doing business with',
#  'never heard of this?',
#  'doesn\' charge ticket change fees. Do they not incur the same mysterious "costs" that you incur, ?',
#  'Exhausted &amp; frustrated! Link to  FB post abt my travel issue',
#  " was denied getting on the plane / getting the chance to prove it fits. ' not  rookie. Read my bio.",
#  "that' exactly the point. It fits. ' premier access. Boarding group . This was  return ticket. 've been doing this for 15 yrs",
#  "'ve never experienced worst customer service. Placing blame on codeshare partners and not assuming responsibility is unacceptable",
#  'currently on board so not now. Check in was terrible. Staff rude. Expensive luggage thrown around etc.',
#  'fucked up, then voided my ticket, and KEPT MY MONEY. Not even an apology.  will never fly with your airline again.',
#  "has the WORST customer svcs! This Kevin rep at call center must be investigated. My baggage' lost and there' no help but argument!",
#  'should NOT sell tickets for on . has terrible service and UA staff cannot reach Silver',
#  'Just got demoted from Gold cuz my hubby got 100% of the PQD, tho there were enuf $ spent for  Golds..discrimination/angry.',
#  'Thank you!',
#  'When will direct flights from Belfast Intl to Newark resume from their winter break? Thanks.',
#  'My favorite way to travel! Thank you!',
#  'yes, after this awful weather it appears  can get home',
#  'yes lots. You have terrible customer service at Newark and despite raising  complaint there we were ignored hence the tweet',
#  'Lovely new plane from LGA to ORD but no power outlets?',
#  "but if  tweet the ID number, won' that reveal my home address to anyone on the web?",
#  ' filed  delayed bag report on Saturday! my flight was Cancelled Flightled and  never went anywhere!',
#  'the person is currently bettween gates 71A and 73 in LAX',
#  ' need it there before she lands so she can have the EWR baggage claim file to have it sent but the employee has not droppeditoffyet',
#  'rarely ceases to amaze...for the worse.  hope this is the last time  "have" to fly with you.',
#  'thank you for the quick response but  cannot dm you until you follow me as well',
#  'iCloud it is not there yet -- PLEASE HELP 917 703 1472',
#  ' need the phone number to baggage claim in LAX, my mom left her phone and someone called saying they would put it there but on',
#  ' did... no response back',
#  'this is atrocious customer service.',
#  'will not have to honor absurdly low mistake fares. vía',
#  'delayed departure to check bags at gate claiming space filled and walk on to open spaces  delay',
#  'you Cancelled Flighted our flights for no reason &amp; now we have been on the phone for AN HOUR on our vacation. Why?',
#  "THAT' your response? Shaking my head back and forth with  tsk. You can do better-from customer service to your apology",
#  "thanks! It' 35K miles from RTB to Europe, to do  multiple destination so we could stop over in US on way/way back- mileage diff?",
#  'of course  did. The bag should be here by now :(',
#  'you are the worst.  will avoid you like the plague.',
#  'is the worst airline in the world.',
#  'someone needs to DM me and resolve this correctly. Extremely disappointed with the service  received. Terrible management.',
#  'Premier Gold desk changes flight. Waives fees. Gives me wrong flight. Now Jana Acosta in Salt Lake refuses the same service. Angry.',
#  ' will give you one thing, you are consistent but unfortunately you are consistent at not doing your job well',
#  " will but right now ' to angry",
#  'first time flying with United. Also last time. back to for me.',
#  ' used to be  committed flyer until merger.  remember now why  switched to',
#  'the least you could do is offer me  ticket in coach instead of just Cancelled Flighting my reservation because of your glitch!!!',
#  "' saying  made the flight but with poor/non-communication, unaccounted for lost time &amp; lots of frustrated flyers standing around",
#  ' think DM would be better',
#  'gate announcement states delay due to maintenance yet app says Late Flight arriving aircraft tell the truth!',
#  "you are easily the worst company  have ever experienced. You have lost someone' personal possessions &amp; you couldn' care less!....",
#  'how can your app show arriving aircraft is early but departing flight is delayed due to Late Flight arriving aircraft?',
#  'already did that at the airport and 12 hrs Late Flightr its still not here! you guys are really killing me today. trying to stay positive..',
#  "once united' service levels reaches those of Etihad or lets be more realistically Lufthansa then ill consider it again",
#  'really? Someone called in sick and then someone FORGOT to call  replacement?! Now an hour Late Flight to take off.',
#  'Asked Flight attendant what typical compensation would be &amp; says we might get free TV.',
#  'done',
#  'Thank you, ^JH, appreciate the prompt responses--me and other passengers will be doing so.',
#  'has been such  disappointment today. Simply put. Rather unpleased with things currently. Flight delayed; cant wait to just get home',
#  'During the same round trip, my NON-English speaking friend was stranded TWICE for 12+ hours each time! Most staff members were rude.',
#  'found  group of people who actually hates people more than ISIS, thats right United Airlines.',
#  'Nope. Walked up &amp; down the ORF terminal, &amp; not  United agent to be found. Showed up last minute to board us. Many panicked people',
#  'thank you',
#  'by the time  finally get to Dallas  could have driven with less frustration and cheaper.',
#  "' trying to get to my final destination, we need compensation. Just about 2hrs of personal time wasted.",
#  'that guy really has no customer service clue.Could have spent effort clearing bins for rollerboards instead of art projects in mine!',
#  'he has no priority and Iove it',
#  'Pleased to be  Premier Platinum',
#  ...]

# %%
# Last stage of preprocessing tweets: each of the tweets' token is lemmatized
# Lemmatization --> the process of grouping together the different inflected forms of a word so they
# can be analysed as a single item.

tweets_cleaned_2=[]

for sentence in tweets_cleaned_1:
    lem = lemmatize_sentence(sentence)
    lem = ' '.join(lem)
    tweets_cleaned_2.append(lem)

# %%
# The list containing each of the pre-processed tweets is printed to verify that the previous process has been
# performed correctly.

tweets_cleaned_2
# Out:
# ['what say',
#  'plus you have add commercial to the experience tacky',
#  'didn today must mean need to take another trip',
#  'it really aggressive to blast obnoxious entertainment in your guest face amp they have little recourse',
#  'and it really big bad thing about it',
#  'seriously would pay flight for seat that didn have this playing it really the only bad thing about fly va',
#  'yes nearly every time fly vx this ear worm win go away simple_smile',
#  'really missed prime opportunity for men without hat parody there',
#  'well didn but now do',
#  'it be amaze and arrive an hour early you re too good to me',
#  'do you know that suicide be the second leading cause of death among teen',
#  'lt pretty graphic so much good than minimal iconography',
#  'this be such great deal already think about my nd trip to amp haven even go on my st trip yet',
#  'fly your sky again take all the away from travel',
#  'thanks',
#  'sfo pdx schedule be still mia',
#  'so excited for my first cross country flight lax to mco ve heard nothing but great thing about virgin america',
#  'flew from nyc to sfo last week and couldn fully sit in my seat due to two large gentleman on either side of me help',
#  'redheart fly smilingface thumbsup',
#  'you know what would be amazingly awesome bos fll please want to fly with only you',
#  'why be your first fare in may over three time more than other carrier when all seat be available to select',
#  'love this graphic',
#  'love the hipster innovation you be feel good brand',
#  'will you be make bos gt la non stop permanently anytime soon',
#  'you guy mess up my seating reserve seat with my friend and you guy give my seat away poutingface want free internet',
#  'status match program apply and it be three week call and email with no response',
#  'what happen ur vegan food option at least say on ur site so know won be able eat anything for next hr',
#  'do you miss me don worry we will be together very soon',
#  'amaze to me that we can get any cold air from the vent',
#  'lax to ewr middle seat on red eye such noob maneuver',
#  'hi just bked cool birthday trip with you but can add my elevate no cause enter my middle name during flight book problem cryingface',
#  'be the hour of operation for the club at sfo that be post online current',
#  'help leave expensive headphone on flight iad to lax today seat no one answer amp number at lax',
#  'await my return phone call just would prefer to use your online self service option worry',
#  'this be great news america could start flight to hawaii by end of year via',
#  'nice rt vibe with the moodlight from takeoff to touchdown',
#  'moodlighting be the only way to fly best experience ever cool and calm purpleheart airplane',
#  'do and do best airline around hand down',
#  'when can book my flight to hawaii',
#  'your chat support be not work on your site',
#  'view of downtown los angel the hollywood sign and beyond that rain in the mountain',
#  'hey first time flyer next week excite but have hard time get my flight add to my elevate account help',
#  'plz help me win my bid upgrade for my flight lax gt sea wineglass thumbsup seat airplane',
#  'have an unused ticket but move to new city where you don fly how can fly with you before it expire',
#  'be flight leave dallas for seattle on time feb',
#  'for good reason you rock',
#  'dream',
#  'wow this just blow my mind',
#  'after last night think agree',
#  'all be entertain',
#  'be flight on it way be suppose to take off minute ago website still show on time not in flight thanks',
#  'julie andrews all the way though be very impressive no to',
#  'wish you fly out of atlanta soon',
#  'julie andrews hand down',
#  'will flight be leave dallas for la on february th',
#  'hi so excited about your lga gtwinkal deal but ve be try book since last week amp the page never load thx',
#  'you know it need it on my spotify stat',
#  'lady gaga she be amazing smilingfacewithsmilingeyes',
#  'carrie',
#  'new marketing song let u know what you think',
#  'julie andrew first but lady gaga wow me last night carrie meh',
#  'call week ago about add flight from to my elevate they still haven show up help',
#  'all be great but have to go with smilingfacewithheart eye okhand',
#  'sorry mary martin have it first',
#  'love all three but you really can beat the classic',
#  'flight dal to dca pm try to check in could not status please',
#  'heyyyy guyyyys be try to get through for an hour can someone call me please',
#  'hi virgin on hold for minute be there any early flight from la to nyc tonight earlier than pm',
#  'congrats on win the award for best deal from an airline u',
#  'everything be fine until you lose my bag',
#  'need to change reservation have virgin credit card do need to modify on phone to waive change fee or can do online',
#  'email your customer service team let me know if you need the tracking number',
#  'hi just book flight but need to add baggage how can do this',
#  'your airline be awesome but your lax loft need to step up it game for dirty table and floor',
#  'not worry it be great ride in new plane with great crew all airline should be like this',
#  'awesome fly yall sat morning any way we can correct my bill',
#  'or watch some of the best student film in the country at foot',
#  'first time fly you all do you have different rate policy for medium bag thanks',
#  'what be go on with customer service be there anyway to speak to human asap thank you',
#  'what happen to doom',
#  'why can you supp the biz traveler like and have customer service like',
#  've apply more then once to be member of the crew team im interested',
#  'you re the best whenever begrudgingly use any other airline delay and late flight worry',
#  'have no interesting fly with you after this will cancel flight my next four flight plan',
#  'it be disappoint experience which will be share with every business traveler meet',
#  'have trouble add this flight my wife book to my elevate account help',
#  'can bring up my reservation online use flight book problem code',
#  'random what the distribution of elevate avatar bet that kitty have disproportionate share',
#  'lt fly va but life happens and be try to my trip jperhi can you help va home page will not let me',
#  'why be the site down when will it be back up',
#  'you down with rnp yeah you know me',
#  'hi do not get point on my elevate account for my most recent flight how do add the flight and point to my account',
#  'like the tv and interesting video just disappoint in cancelled flightled flight when other flight go out to jfk on saturday',
#  'just land in lax an hour after should of be here your no late flight bag check be not business travel friendly',
#  'why be flight redirect',
#  'be it me or be your website down btw your new website isn great user experience time for another redesign',
#  'can check in or add bag your website isn work ve try both desktop and mobile',
#  'let scan in passenger leave the plane than tell someone to remove their bag from st class bin',
#  'what be your phone number can find who to call about flight reservation',
#  'be anyone do anything there today website be useless and no one be answer the phone',
#  'try to add my boy prince to my ressie sf this thursday from lax',
#  'why must traveler miss flight to late flight check bag miss my morning appointment and you lose my business',
#  'check out new music',
#  'how direct flight fll gt sfo have unexpected layover in vega fuel yet peeps next to me buy for vega flight',
#  'your no late flight bag check just lose you my business miss flight and be apt three other people on flight have same exp',
#  'amaze customer service again twohearts twohearts raeann in sf she the best',
#  'call your service line and be hang up on this be awesome',
#  'your site be trip try to check in and get the plain text version be reluctant to enter any card info',
#  'be schedule for sfo dal flight today change to th due weather look like flight still on',
#  'have getaway deal through may from one way lot of cool city',
#  'have getaway deal through may from one way lot of cool city',
#  'have getaway deal through may from one way lot of cool city',
#  'have getaway deal through may from one way lot of cool city',
#  'have great week sunwithface airplane',
#  'come back to already we need you to take u out of this horrible cold',
#  'should be concern that be about to fly on plane that need to be delay due to tech stop',
#  'be the best airline have fly on easy to change your reservation helpful representative amp comfortable fly experience',
#  'and again another rep kick butt naelah represent your team so beautifully thank you',
#  'your beautiful front end design be down right now but it be cool to still book my ticket all your back end be secure',
#  'love the team run gate at la tonight wait for delayed flight and they keep thing entertain',
#  'use another browser amp brand with reputation build on tech response doesn have cross browser compatible website',
#  'and now the flight flight book problem site be totally down folk what be the problem',
#  'like the customer service but min delay just for connect passenger seem too long va',
#  'thanks to your outstanding nyc jfk crew who move mountain to get me home to san francisco tonight',
#  'you have the absolute best team and customer service ever every time fly with you delight thank you',
#  'do you provide complimentary upgrade to first class if there be available seat',
#  'need to change my flight thats schedule in hour and min wait time on phone im call intern help',
#  'completely awesome experience last month bos las nonstop thanks for such an awesome flight and depart time',
#  'how can watch the on my jfk gt sfo flight',
#  'be flight cancel flightled and what do do if it be',
#  'you be fail your customer because your check in process do not link to tsa pre check',
#  'u too terrible airline just give u hotel hotline number and say sorry',
#  'have flight number from sfo to cabo san lucas arrive yet',
#  'your assistance yesterday when cancel flightled our flight be to give u hotel hotline shame on you',
#  'another delayed flight',
#  'need to register service dog for first class ticket from sfo gt dull the phone queue be an hour or long pls advise',
#  'you rock for make it so can watch on my flight',
#  'drop track on you',
#  'always xoxo',
#  'why can we book seat on your flight when we buy them or even during check in creates so much anxiety',
#  'you think pay an extra buck rt for luggage might afford you hire an extra hand at',
#  'best customer service rep in the world take the cake',
#  'can you find u flt out of lax that be sooner than midnight on monday that would be great customer service grinningfacewithbigeyes',
#  'please provide status for flight cant imagine it on time a the web indicate dude to weather here and or dallas',
#  'you have amazing staff amp super helpful a just run the they have spoil me with comfort',
#  'pay the premium to fly you across the country you cancel flight my flight and offer no check fee or upgrade love sad face worry',
#  'question be it not possible to book seat for an infant under it not give me the option but we want seat for him',
#  'always have it together you re welcome rt you re so welcome',
#  'home to in back to',
#  'don understand why you need dm to give me an answer on if you have damage luggage policy',
#  'do that mean you don have policy for destroyed luggage',
#  'be there special assistance if travel alone kid and infant priority boarding',
#  'thank you for check in ticket be purchase and customer be happy wink',
#  'be your website ever come back online',
#  'be flight from love field to sfo definitely cancel flightled for monday february',
#  'be flight out of lga to dfw on time',
#  'my driver license be expire by little over month can fly friday morning use my expired license',
#  'have problem flight book problem on the web site keep give me an error and to contact by phone phone be minute wait',
#  'how do reschedule my cancel flightled flight online the change button be grey out',
#  'rang but there be wait for minute can book the same ticket through vendor fix your site',
#  'get flight we be tell for today check my email and it for tomorrow this be unacceptable',
#  'our flight into lga be cancel flight we re stick in dallas call to reschedule told could get flight for today',
#  'why don any of the pairing include red wine only white be offer worried',
#  'be the website down',
#  'your site seem little wonk right now may want to have look try on two browser no cs',
#  'disappoint that the agent at the designate silver status check in line close to assist all pasengers',
#  'plan to include austin to it dallas route topnews arab',
#  'be it normal to receive no reply from central baggage',
#  'at logan airport and wait to checkin for my be flight checkin desk not open why',
#  'to jump into the dallas austin market',
#  'beat eps view take on va luv investor business daily',
#  'lister to my show my on monday',
#  'to begin dallas austin in april ketr',
#  'congrats you just get all my business from ewr to sfo lax fuck you fl sfo ewr be the clincher',
#  'apply over week ago haven hear back and fly this week',
#  'love to know what your policy be for damage luggage',
#  'thank you for the follow',
#  'too many apology you the bad airline don even respond to your cudtomers',
#  'shame on va for make people spend money in stranded city when other airline be land at jfk who will reimburse me',
#  'dm you',
#  'can you please have flight in sjc have no choice but to fly southwest to vegas wearyface loudlycryingface',
#  'too bad you say it take to day via your confirmation email when inquire after week you claim to week',
#  'flight from bos gt la tomorrow be cancel flightled no notification wait time be hour will you rebook on another airline',
#  'smilingfacewithsunglasses rt you ve meet your match get status on another airline upgrade restr',
#  'only way to fly',
#  'if only you guy have flight from cmh',
#  'lot of apology be throw out to customer from what can see very sad thanks for nothing bad airline ever',
#  'for all my flight stuff wrong and do nothing about it have ever',
#  'have an issue find miss item on plane can you help me find which airport my plane head to next',
#  'you will match my status cool',
#  'you ve meet your match get status on another airline upgrade hear no evilmonkey',
#  'try to book flight with you guy and your website win let me about to lose my business',
#  'you suck',
#  'thanks',
#  'just dm same issue persist',
#  'because we never rec cancelled flightlation notice we be leave no option to fly out of p drive to la for red eye mon kid',
#  'try to book flight amp your site be down beamingfacewithsmilingeyes',
#  'you have any flight fly into boston tomorrow need to be home and you cancel flightled my flight and didn do anything',
#  'you stink flight cancel flight from psp to jfk and no notification or ability to rebook good',
#  'love your guy song we re dance to it for our high school dance revue',
#  'your website be down and try to check in',
#  'do thank you for the quick response apparently faster than sit on hold wink',
#  'nervous about my flight from dc to lax get cancel flightled tomorrow just send you dm to help me',
#  'cool picture of another virginamerica plane off our wing what site',
#  'keep up the great work simple_smile',
#  'my goodness your people field be amaze under pressure redheart from texas in crisis please fly me to ny',
#  'thanks for great flight from la to boston pilot do great job landing in the snow can we go back to la now',
#  'can you please get me to the new york area before monday afternoon',
#  'thanks so much for the awesome support you guy rock',
#  'seat in row don recline should mention that on your website',
#  'flight delayed hour in la due to mechanical problem handle like pro but you could have toss u free drink',
#  'why cancelled flight flight today no precipitation to be scar of snowflake snowflake snowflake',
#  'twitter team you guy kill it for reschedule me asap thank you',
#  'you guy charge me to reschedule flight that be then cancel flight and be now refuse to refund it what the deal',
#  'can access your website from safari on iphone seem to work on mac and ipad need iphone to add passbook',
#  'on ipad and iphone click the checkin link in the email receive at hr before flight',
#  'your mobile site be break show header elevateuser numofpointsavailable number point win let me checkin',
#  'be really look forward to my flight can you let me know when it will be reschedule',
#  'why cancelled flight flight vx one sec it delay on my to airport the next it cancel flightled gon na email or call me to reschedule',
#  'do it but there be problem in the link from the email for check in thanks',
#  'have to change to another airline to get to dc today why be able to land in dc but not you cost me ugh',
#  'be so look forward to my first flight with you today but it be cancel flightled along with the subsequent one',
#  'when be you put some great deal from pdx to las or from la to pdx show me your love',
#  'wish can afford to fly with you next friday go back home love everything about your airline',
#  'how be you gon na have deal from dallas to dc but no deal from dc to dallas',
#  'it just bug report guy',
#  'hold time at call center be bit much',
#  'like',
#  'site down',
#  'you have the best flight attendant ever',
#  'awesome rt watch nominate film at foot',
#  'thanks so much',
#  'try to reset my password email never arrive help',
#  'the only airline base in silicon valley',
#  'very nicely do clappinghands',
#  'look forward to watch the oscar on my flight home tomorrow might even get something bubbly to drink wink',
#  'what be the reason for the delay of the departure of vx from jfk this afternoon',
#  'be todays flight from palm spring ca to jfk in ny cancel flightled',
#  'hahaha facewithtearsofjoy you guy be amaze love you guy growingheart',
#  'sound like fun',
#  'any update on flight from jfk gt lax',
#  'spruce moose',
#  'the cs on your site be right now please fix site unusable',
#  'we re on flight vega to boston today check in online but our bag count didn register can fix that somehow',
#  'classiq luv virgin america greetingz',
#  'hi try to do check in but the website be not work try different browser and the problem continue',
#  'thanks for your great customer service today amp for help me get all my travel sort out',
#  'thanks guy sweet route over the rockies',
#  'love the music blasting at gate in while wait for flight to only if could get an iced coffee',
#  'the passenger in flt that assault me shouldn have fly trust he ban crew file report to',
#  'current bug on website show select departure city when select destination city',
#  'luggage be severely dented miss wheel come off baggage claim in san luggage agent miranda think wasn any help',
#  'thank you for the easy itinerary shift for impend weather quick painless amp free',
#  'if you love to see more girl be inspire to become pilot rt our free woaw event march at abq',
#  'thanks good time there and back the entire flight cocktailglass',
#  'beat expectation share take off santa cruz sentinel',
#  'any plan to start fly direct from dal to las',
#  'big love gratitude mpower werin vipswagbags',
#  'you re do great job add little luxury aesthetic that improve the air travel experience thank you keep it up',
#  'request window seat and confirm window but get stick in middle seat not good way to treat silver member unamusedface',
#  'grand budapest hotel',
#  'this be what you miss next trip to the',
#  'pay for direct flight on purpose not to have to stop for fuel exhaust frequent flier and nothing for inconvenience',
#  'there be something wrong with you website in safari iphone',
#  'thanks for gate checking my baggage on your full flight dfw lax and give me early boarding too',
#  'already check in so the page expire',
#  'boo for not refund seat upgrade fee do not want to buy in the first place',
#  'share rise on financial result usa today',
#  'add pillow instead of lie flat seat in first class arm race',
#  'see what you do there wink',
#  'way to take advantage of simple_smile',
#  'you know fly virgin for the fight',
#  'your inflight team make the experience',
#  'cutest salt and pepper shaker ever just when think you guy can get any good you just do',
#  'move my seat with no notice well seat be cabin select not behind the row select thumbsdown',
#  'share up on result',
#  'fav airline',
#  'we have hot female pilot sweet dca to sfo simple_smile',
#  'thumbsup thumbsup airplane airplane growingheart when be you guys go to start fly to paris you re welcome',
#  'what be your policy on fly after surgery be still wait for answer so can tell me doctor',
#  'already contacted central baggage amp send dm be charge me for the dress that be in the lost suitcase',
#  'thank you',
#  'be there anything go on with the website ve be get lot of error past minute',
#  'think leave something on the plane yesterday who do call ah',
#  'need you to follow back in order to dm',
#  'need to start fly to smilingfacewithsmilingeyes grinningface grinningfacewithbigeyes grinningfacewithsmilingeyes',
#  'they tell to check with the airline regulation first so that be why contact you',
#  'have just check in flight to sfo from lax amp be tell a atlantic fly club gold get no benefit',
#  'husband and order three drink via my screen and they never come awesome',
#  'soooo be you guys go to leave the seatbelt light on all flight you can barely call this turbulence simple_smile',
#  'what be your policy on fly after surgery',
#  'post second consecutive full year net profit',
#  'funny story your website be break you have miss javascript and stylesheets on the checkin process dislike this',
#  'would love to do more for virgin just like do for',
#  'result handily exceed forecast',
#  'apply for position in and be wonder if you guy receive my application',
#  'achieves second year of profitability despite revenue pressure',
#  'give positive outlook but see increase competition',
#  'try to check into my be ct flight tmm on the desktop website and it not work some sort of cache bug so',
#  'weather delay gt next few week wink',
#  'check the website before you go to the airport',
#  'do you guy know your check in link from email be break',
#  'pilot say we expect choppy landing in nyc due to some gusty wind temperature of about degree amp the windchill',
#  'love it can wait for monday return flight mostly just to watch the inflight safety video again',
#  'lose my luggage day ago on flight vx from lax to iad amp call every day no response please give me back my stuff',
#  'the flight book problem section of your website seem to be break on chrome might wan na look into that',
#  'hi just want to see if you have any new route plan this year for newark love fly you guy and hope to do so more',
#  'mean probably inappropriate while on board but it on',
#  'happy to spend the day together let do this',
#  'be save my sanity right now',
#  'miss my flight how do standby work',
#  'they be very understanding and help me out thx',
#  'bring it all the way across the country today see',
#  'thank you absolutely will smilingfacewithsunglasses',
#  'look like broken link for your asset',
#  'be you ready let say it together noooo turbulence today faceblowingakiss',
#  'the manage itinerary section of your website seem to be break for me',
#  'can check in your site look like this every time it load',
#  'can help this princess need urgent treatment in unitedstates old battling cancer could help with flight growingheart',
#  'may start service to hawaii from this year',
#  'other carrier be less than half price for round trip fare be stun',
#  'wtf be happen in pdx late flight march such that one way from sfo be',
#  'add dtw and sell',
#  'how about some free drink on the flight back for the free promo',
#  'thanks',
#  'momma make it beamingfacewithsmilingeyes beamingfacewithsmilingeyes beamingfacewithsmilingeyes',
#  'please contact me about portfolio leave on flight vx from jfk to sfo tonite seat be need it return call',
#  'help be on flight from jkf tonight seat leave portfolio need it back',
#  'seattle bound wifey get me the duffle for vday she keeper holla',
#  'my luggage be go ve file my paperwork promise call email still no resolution or response from central luggage',
#  'debbie baldwin give performance of the safety demo this evening on vx',
#  'thanks',
#  'thanks for take care of on her flight',
#  'thanks for the lovely soft view to',
#  'request mileage challenge for status several week ago online but haven hear back how do get help with this',
#  'just try to book ticket to nyc and face super fun break style don worry ll keep try simple_smile',
#  'many thanks for the follow look for any help smilingfacewithheart eye growingheart unitedkingdom growingheart unitedstates growingheart ribbon globeshowingasia australia ribbon',
#  'nice lofty view',
#  'apply for status match on feb get confirmation email same day still no news though you guy have drop ball late flightly sadbutrelievedface',
#  'be my new go to airline',
#  'can you help in need of some help in ribbon unitedkingdom ribbon unitedstates ribbon',
#  'adore you and be so look forward to my flight to austin in two week',
#  'be so glad it be mention take my first virgin flight few year back and it be transform experience',
#  'flight book problem flight to uphold my status match do tax on ticket count a earned status point',
#  'try to check in but look like your site be down',
#  'spending my birthday night with you dal dca get me home',
#  'sent couple message to the email you provide but to no avail will try again next year cheer',
#  'first time fly virgin go to thanks for the smooth ride easily my new fav airline',
#  'seriously though will there not be direct flight from sfo fll in may',
#  'it fine already do with my purchase but you should try it just go most of the way through then go back',
#  'not really the experience be hop ws force check in small carry on nothing but empty cabin space on board',
#  'wjere be our luggage slow at lax',
#  'to jump into the market',
#  'spoke with representative that offer no solution be loyal customer who fly on as well',
#  'be deeply disappointed that your birthday promo be not apply to trip book mere day before receive the email',
#  'what happen to direct flight from sfo fll look in may only see connect',
#  'can you help leave my blazer in kooples jacket bag at rd row second seat from right gate lax flight to sfo',
#  'partner with checkout a mobile payment method to help boost mobile conversion rate',
#  'just promote the product be all have problem with southwest and recommend noneother than the best',
#  'love you guy but pls get some direct route las to aus',
#  'would like help with some flight please',
#  'bruh turn down for what',
#  'of course work for and obsess with the entire virgin family',
#  'ok first time fly with you tonight simple_smile',
#  'dig the swanky pink mood light during the flight from nyc to sfo just need cabaret singer think about it',
#  'do but need the receipt asap could you please help',
#  'have and emboss badge and patch superior to the one you be currently use',
#  'on vx from jfk to la dirty plane not up to your standard',
#  'on flight vx head to la from jfk dirty va plane have ever be on sad for great airline',
#  'get it square away someone pick up as soon a tweet should have tweet sooner winkingface',
#  'your avis rental continue button doesn work on your website to book car try time on phone this suck',
#  'delay to',
#  'currently in minute of be on hold with cust service do need to do anything to add lap child to my reservation',
#  'add pillow instead of lie flat seat in first class arm race by',
#  'of course have fun celebrate thanks happy chinese new year',
#  'flight book problem last second flight for next week from sfo to san any chance you want to gift me promo code since love you guy',
#  'comenity bank be joke please change nothing but constant problem with this bank',
#  'just do how can dm do have to also add me',
#  'for my grandma ella th she would lt bday greet from your flight crew she be stewardess for eastern airline',
#  'just buy tix for atx dallas route thanks for add that love yr airline amp yr website be best transact site ever',
#  'anytime sugafly',
#  'give credit for my late flight flight yesterday great service that wow moment unexpected gesture',
#  'need receipt for flight change can you send one',
#  'submit status match request while back and still haven heard fly on monday can you look accelerate',
#  'have me at their safety video love my first cross country flight',
#  'that doesn look to fat to me it look yummy',
#  'ceo say amp have stray from low cost model',
#  'brilliant brisk be in boston in cue for vx',
#  'atlantic plough lone furrow in the',
#  'atlantic plough lone furrow in the',
#  'atlantic plough lone furrow in the',
#  'omg omg smilingfacewithheart eye smilingfacewithheart eye nonstop dallas to austin on virgin sparkle facescreaminginfear airplane',
#  'your plane be really pretty just think should know that simple_smile',
#  'when be you fly to hawaii',
#  'pull my hair out try to book flight with your site doesn work on iphone or ipad don have computer',
#  'thank you',
#  'can get some help with support ticket it be day incident thank you',
#  'good to be home',
#  'can not even open my laptop in seat and pay premium for this let me out of here',
#  'be in seat and can not even open my laptop and pay extra for this seat',
#  'if only you guy be start those flight at the end of the month guess still road trip on feb',
#  'thanks for that be need way to make those austin trip from dca and now you have come through',
#  'announce new route to austin fare from way',
#  'really sprint thought you guy be kewl',
#  'this be too cool never be on ur plane but now will',
#  'you should have dollar lax la fare',
#  'great well deserve',
#  'fyi the info com email address you say to contact in password reset email doesn exist email bounce',
#  'status match week have go by and no news flt next week hope flt will count towards requirement cust svc no help',
#  'your website suck donkey dick just think you should know all best',
#  'you should still develop an app then you will be my favorite airline',
#  'all crap channel which be why pay to watch uk tv',
#  'get it all set thanks',
#  'no channel this year',
#  'only thing see on passbook be virgin mobile mexico how do integrate',
#  'giant and virgin america match make in heaven',
#  'thank goodness also see you friday nwk gt sf boom',
#  'how come you don have an iphone app still use and make me waste paper',
#  'your back of seat entertainment system do not accept credit card that have an apostrophe in the surname',
#  'when will vx use all lga slot instead of today add aus make this less likely worried',
#  'be help me step up my game',
#  'luv ur people and product thing be do charge for herbal tea but not black tea not caffeine drinker',
#  'thank you see all soon excite to see the expansion of destination spread those wing',
#  'announces new nonstop connecting amp intro',
#  'add austin dallas love field route',
#  'sad to learn you no longer fly sfo gt phl hope it return',
#  'can you tweet me the cancelled flight chng fee for flight or can rebook under one of your affiliate if so who be afiliates',
#  'have the most incredible customer service ve ever experience so refreshing',
#  'now when will we see virginamerica come to philadelphia phl',
#  'be dream do you really just open up route between dallas and austin and do this mean houston might be next',
#  'omg finally',
#  'to start xweekly flight from to on apr',
#  'nice to see you expand in texas but don forget about u here in would love to see more flight out of here',
#  'kinda suck my earphone jack didn work on my flight they may want to look into that for future passenger',
#  'very poor experience first computer problem now seat malfunction stick miss meeting in san diego',
#  'to battle on route via',
#  'the dal au route make my day',
#  'awesome deal dal au for only each way',
#  'miss the in san jose',
#  'love it take on in their backyard consumer win when biz competes',
#  'be fly from love to austin now that be most excellent news',
#  'can we make every vx plane with why should austin be the only one get nerd love',
#  'please add more frequency to pdx portland',
#  'congrats vx on the new route airplane partypopper',
#  'try that you offer to charge me an additional for new ticket or be strand until thurs st time last time',
#  'can help with flight to get old battling cancer who need treatment in unitedstates growingheart ribbon growingheart',
#  'never have bad experience before but this one take the cake now extortion for carry on item a well',
#  'have to spend hour worry that item in carryon would be break steal since couldn carry them on plane or lock bag',
#  'all of group be tell there be no more room in the bin when get on the plane be room for at least bag in my row',
#  'thanks for make my flight from lax to jfk nightmare by force me to check my carry on bag at the gate',
#  'have lot of flight to book and your site it not work ve be on the phone wait for over minute',
#  'be all about the in flight artisan cheese and wine pairing',
#  'do virgin america fly direct from seattle to nyc or boston',
#  'that classy',
#  'sure lot of your and jfk lhr flight go lot fast than mph with strong tailwind',
#  'now it just minus minute until my elevate silver upgrade window open grinningfacewithbigeyes thumbsup',
#  'save some for tomorrow be',
#  'why be it take year to fly home to dallas get your shit together',
#  'club virgin be bump in new york',
#  'would have be rough trip but luckily we be on flight',
#  'be that beamingfacewithsmilingeyes',
#  'please come to minneapolis st paul',
#  'yes fyi my bff',
#  'another perfect flight how come on your plane the sun visor can stay down other carrier make you raise them',
#  'nice rt the man of steel might be faster but we have wifi just say',
#  'love the dancing little richard cool bean',
#  'don use passbook still love you though lt simple_smile ll just use my email in the future',
#  'thanks for the free birthday point all be all right with me',
#  'do you have an application for io be look and only saw virgin mexico worry lt',
#  'man of steel fly to more city though and with more frequency too',
#  'thanks so much for share just add it to my site',
#  'good point',
#  'heard he have virgin mobile hotspot wink',
#  'you get cheese plate flight too',
#  'on all your flight',
#  'dad on segway be the best part of this whole infographic',
#  'be there any plan for short haul airline in europe would defiantly fly with you guy simple_smile',
#  'wifi and good seating',
#  'how come abc be the only one of the network channel you don have',
#  'start my flight with scold for use an overhead bin that be then offer to the person seat next to me',
#  'not only be it great but you return my call the day after couldn ask for more',
#  'while other airline weren cancel flight flight into bos and help their customer get home virgin be say good luck',
#  'dear virgin customer while you re strand in sf for day amp cost we will do the very least we can to accommodate you',
#  'should use this in their next airline commercial lol',
#  'group virgin in with the other now bos weather have expose their actual cu serv model never flight book problem with virgin again',
#  'a one of the traveler affect by the boston storm shock at virgin complete apathy toward their customer',
#  'umm so no reason a to why this be be there someone different should contact or contact me to get definitive answer',
#  'try to make the change in advance not just hour prior try it online earlier and it want in change fee',
#  'so loyal that drive to from to fly virgin since you cut flight wink',
#  'any way to change from main cabin to main cabin select on same flight without pay change fee penalty',
#  'you guy be perfect a always lt',
#  'thanks all have some of the best customer service leave in the industry',
#  'can you give me silver status for month',
#  'really wish you fly out of those fare be amazings',
#  'mood light on point raisinghands recline my seat kickin up my foot zzz',
#  'my flight schedule for pm departure still say on time but no plane at gate any update on how long of delay',
#  'my group get their cancelled flightlation fee waive but can because my ticket be book for your rep be no help either poutingface',
#  'be there any sign up bonus to enroll in elevate',
#  'just get on the pm in newark home to la your folk at ewr be incredible',
#  'morning if have question regard elevate point amp flight can dm you',
#  'still wait to see disappointedface',
#  'be wonder if you guy recieved my dm and we re able to potentially respond asap',
#  'fly lax to sfo and after look at the awesome movie lineup actually wish be on long haul',
#  'book out of town with fare from way restr',
#  'thanks',
#  'thanks for take care of that mr happy customer',
#  'still no refund or word via dm please resolve this issue a your cancel flightled flight be useless to my assistant trip',
#  'delay due to lack of crew and now delay again because there long line for deice still need to improve service',
#  'thanks we fill it out how our luck with this be it common',
#  'your eri ord express connection be hugely popular now if only we could have an eri ewr hop simple_smile',
#  'even on international flight glasgow to the then what about orlando to newark all min',
#  'you think you board flight au too early think so',
#  'understand but it tough when there be no way to get to the airport serious risk of an accident it steep price',
#  'gate agent hook me up with alternate flight if you have way to prevent the constant issue that would rock',
#  'fly gla mco in few week how long do we have to be at airport for before departure for both international and domestic ta',
#  'thanks',
#  'thanks it be on the same ticket',
#  'why not be it law or policy',
#  'be the bad nonrefundable first class ticket oh because when you select global fc their system auto selects economy upgrade',
#  'so can buy tix day before flight but can transfer the tix flaw security logic flaw customer service',
#  'do start claim but week be unrealistic be really suppose to go that long with out car seat for my child ridiculous',
#  'follow me please this airline be beautiful heartsuit',
#  'no don but sure united have my info on it system',
#  'if the car seat be lose should just reimburse me for new one this be not pair of shoe it necessity for my child',
#  'just submit my response on the link you send',
#  'yes david allan send an email with this number kmm l km and case',
#  'that totally suck my cousin work at phl say',
#  'just want to let you know how wonderful rosetta the gate agent be work flight dan to ase let her know she wasappreciated',
#  'yes paper voucher that get on january th',
#  'beginning of feb call unite they say they would send another voucher by mail never get anything',
#  'the internet be great thing be email executive in your company maybe they will respond to me in timely manner',
#  'do need to use chase united club pas for my yr old son or can he come in with me on my pas',
#  'and what be suppose to do with that number',
#  'thats weak see ya wavinghand hey',
#  'flew back other company since united didnt have an early flight',
#  'lose voucher that be give in miami aeroport on jan do not use it',
#  'be try to book award for september and need flight on but they will not show even many award seat availab',
#  'sure do have to drive total of hour to get my own bag like to explain that debacle but no one want to talk to me',
#  'gee that like almost care about ppl more than think more int in have trust adult daughter',
#  'see we be tell repeatedly that the pilot be late flight and keep get late flightr after we board there be defibrillator issue',
#  'why no preferred security line anymore my tsa pre check didn pull on my partner flight',
#  'airport need to indicate different gate for terminal amp',
#  'yes please be newly marry and try to update my last name on preexist international flight it seem so easy but',
#  'how do united refuse to reissue lose voucher when their plane didn take off due to mechanic',
#  'also during the run be instruct to do shatter my computer',
#  'yes we have be with the agent for the last minute one of the agent have be very rude but thankfully ladan have be nice',
#  'that right with an overnight miami',
#  'have client with an hr layover at iah during the day will they have to claim amp recheck luggage or will it be take care of',
#  'be try to find out if the loaner seat be new or use used car seat be illegal accord to safety regulation',
#  'dmed you the detail',
#  'iah to charlotte baggage claim rep latrice non existent ignore customer then inappropriately touch customer',
#  'kewl will also let them know the overhead bin over my row be inop love good abbreve',
#  'thanks for your help get me what need but it an issue with guess sit awhile longer',
#  'would have love to respond to your website until saw the really long form in business the new seat be bad',
#  'refund and flight voucher or another flight on different airline at your expense for today hour drive be very inconvenient',
#  'then why have not receive my call back it be day it an infant car seat how be suppose to go anywhere with my child',
#  'thanks again for your concern will contact customer care upon our return from australia',
#  'well sit on the ground on time but wait for gate again',
#  'airport snow removal method keep up the good work folk this be where cessna become',
#  'no need you guy to not over book plane it not concern ll just travel with someone els move forward',
#  'measly certificate be not how you appreciate loyal customer after they wait hr on the tarmac during ua',
#  'when will email address username sign on be available it be while',
#  'thank you for that be able to claim any interim expense or be the cost of the stuff up on me',
#  'rude rude',
#  'why can get boarding pas for my austrian airline codeshare flight rebook incls hour layover amp be stick outside sec',
#  'receive on other flight truly break guitar',
#  'just fly to pay from third suitcase which didn even make it on the plane besides for the impolite service',
#  'my bag be still in colo spring be disabled and have to search an unfamiliar airport and look for my bag not good outcome',
#  'shame that there no flex to ticket transfer rule even call from neurosurgery icu isn enough',
#  'no denver say they don handle baggage that make it to colo spring they give me an number to call no help there either',
#  'you guy need some serious training in customer service too many good option to put up with the way you guy handle ur mistake',
#  'ord to dca',
#  'once he find out we have problem he avoid me like the plague be tell we can find supervisor',
#  'zcc cancel flight flight in advance need connect flight reschedule so the link isn help help gf waited month to see me',
#  'will not be fly you again',
#  'in addition my first flight be delay an hour and arriving at my destination hr late flight',
#  'cancel flight our flight didn rebook u on added flight now have to drive from denver to kc thanks',
#  'your announcement for pre board only address mobility my disability require me to travel with lot of stuff do preboard',
#  'flew unite last month and the experience be awesome',
#  'our travel book thru united group dept okc ticket agent less than willing to help with our connection in lax',
#  'upset with your disability service when tell one of your employee be carry medical equipment she be very rude',
#  'thnx for quick reply but don think you can assist our intl grp will be put to considerable inconvenience today',
#  'wont transfer flight ticket to accompany an yr old who active military mom have to have emergency brain surgery wow',
#  'week late flightr and still have not receive my mile from the mileageplus gift card starbucks card hand over',
#  'a always hop for improvement',
#  'not yet complain about the guy who check my luggage in a he be throw the bag around unfortunate coincidence hope',
#  'okc ticket agent roger mclarren sp less than helpful with our intl group travel problem can find supervisor for help',
#  'mobile apps need construction from the ground up for each o category it expensive to get right',
#  'another fail for the united ticket agent in okc less than helpful and could care less about our problem american here we come',
#  'which also have work wc in coach good thing this bird land ahead of schedule have to use the wc stat',
#  'the o isn control by me but rather app be new',
#  'just send an email to customer care tell them may have to break up with you cryingface sincerely hope they can help me',
#  'silly fly delta today your united club staff and attendant be surly and unhelpful and always seem bother by pesky folk',
#  'what be your phone number can find who to call about flight reservation',
#  'well you can fix me miss my buddy th bday because of negligence but you can attempt to make up for it',
#  'why be to believe they will help when customer service couldn like say want number to someone who can fix what you do',
#  'they help me at the baggage service desk say bc tsa screening be down in fll not all bag make it but bag will be in ewr',
#  'mobile board pas disappear from phone while stand in line to board second time this week hmm',
#  'for the record rozana at newark be lovely and helpful',
#  'it be last night ord lga',
#  'thx for update',
#  'thank you',
#  'dm these nut',
#  'have to explain to very over eager flight attendant try to ask about my vision that my be not guide dog',
#  'what the point of ask for detail about when you book if your flight crew doesn read them continue',
#  'try but no one be available in bogota and everyone be rude in houston be stick for hour because of you guy',
#  'ua la to iad mechanical problem again take off have to land for fix delayed again',
#  'despite my bag not make it to newark good informative email track update help',
#  'what go on with ua outbound flight last thurs be delay hrs how long will this delay be',
#  'ua iad to las mechanical problem switch aircraft delay hour',
#  'crash try to check in',
#  'wow what deal again plus seat available easy change to make customer happy',
#  'thanks for the info already know',
#  'airline trouble this winter amp not get good customer service contact we negotiate resolution for you',
#  'on to logan board gong show due to lax carry on enforcement bin full of coat no room for bag need good system',
#  'thank you',
#  'blackmail me into pay extra or have my return ticket nullify in san francisco airport terrible service from rep',
#  'be there an email address can reach too long for dm',
#  'disappoint that didnt honor my credit give to me for ur mistake take my business elsewhere victoryhand out',
#  'ua still wait suppose to depart',
#  'it be credit from my last trip that never come in the mail',
#  'ok it now be month wait to hear from airline give them quite bit more than the day request terrible service',
#  'do this process ever end still wait for the reply since month',
#  'what go on with your website flight booking problem three ticket today and ve be boot off the system umpteen time',
#  'how do get my account number if your website say email be unavailable',
#  'so do need to book two one way in order for her to fly a an unaccompanied minor',
#  'receive bag last night be still miss the other one',
#  'you will need to upgrade the seat too even in economy plus it like sit on concrete bench',
#  'pls help baby hannah get the life save surgery she require she need your help pls donate rt',
#  'bet you wont honour them like mine ey',
#  'nd flight also delay no pilot but they board be so we can just sit here',
#  'guess that too much ask huh',
#  'but it hard to stay upset at someone when they at least try to show remorse',
#  'by the way simple apology go long way even if it hollow one it obvious that you don care about me or my well be',
#  'this isn one time thing either it shock pattern of repeat neglect and disrespect',
#  'finger cross amp it all intact very disappointed with this experience a before this we be actually say we enjoy use you',
#  'it an incredibly easy fix but you would rather stay in your comfort zone while get force out of mine',
#  'ours in july you have zero excuse for this you have an out of date system that cause problem like this',
# ...
#  'delay den cle because they have to manually enter baggage tag really worst cust service day for this ker',
#  'why tell u flight be delay then tell u it on time again with min to spare don say it delay unless you re sure',
#  'yes in lusaka zambia my guess be the bag never make the plane at iad',
#  'where be my flight voucher',
#  'late flight to denver late flight to newark let not even get into the disaster that be check bag unacceptable',
#  'have once again let me down don think ve ever fly with them and not have problem bad airline period',
#  'yes file claim amp hope to receive by luggage by be ridiculous a have to purchase item to go to sleep amp no reimbursement',
#  'ua ord lhr bag be be load min late flight frigid air into cabin plane feel like fall apart upgrade long haul fleet',
#  'flight attendant never serve me my beverage tea and not once check up on me what give',
#  'load balance system apparently down major impact on all airline flight be this',
#  'after our unscheduled refueling stop and miss connect flight we home look ward to our bed and big pb amp sandwich',
#  'spent hundred to rectify the situation and you guy go quiet',
#  'ua sit at ewr nearly an hour after sked pilot say computer down but no clue when we will leave can you help',
#  'so that it it just end there come on travel for literally an extra day and half because of this',
#  'make the upgrade list will fly st tomorrow for min for the first time ever raisinghands',
#  'not just refund but for those of u who be on vacation to get free room night to make up for make u sleep in dia',
#  'thanks for the reminder it be fun ride',
#  'receive my luggage that also look to be leave in the snow when arrive ask for all people to be refund',
#  'update aircraft have wifi and device entertainment but no outlet don get it how can charge device',
#  'be no one between the scan and inside the plane just ask the people in line around me where the plane be go',
#  'gate change two delay even the crew think the airline suck',
#  'very frustrated and have waste day now due to your equipment failure',
#  'computer be down but you stop give update and take my flight info off the app that just ridiculous keep people update',
#  'soooo it be day and you have offer no response so assume poor treatment by gate agent be the norm now',
#  'terrific many thanks look forward to be back on ua tomorrow have great flight up to vancouver',
#  'call to result in hr of hold time amp day wait to check suspect code share fare nothing investigate my time waste',
#  'it take week for cust care to respond to case request refund for wi fi not work where can get an update',
#  'appreciate your effort get me home',
#  'that correct ve spent hour try to book online only to receive an error when click final purchase button',
#  'today be not your fine all could have be prevent by one gate agent advise passenger',
#  'what be the real deal with the delay on flight ua from denver to vegas',
#  'ua from madrid arrive no agent mass confusion we send to and fro by ua employee maryjo be rude and unhelpful',
#  'system failure again bad trend software project be like fly an airplane there no such thing a an emergency takeoff',
#  'lot of report of system failure delay flight over the last week currently sit on the tarmac at ogg for over an hour',
#  'reboot chicago dispatch system need a tire of sit on plane',
#  'despite shaky connection look like ll get home tonight great job be touch and go for while',
#  'however be completely under your control the price be and still be display on',
#  'the aircraft closest to gate be for the other flight and the one closest to our gate be go to chicago',
#  'can you tell me how to file claim for clothing that have to be purchase',
#  'comically on the return flight from ase there be two united flight board at adjacent gate and not clear which plane to board',
#  'grk be the file reference',
#  'we would how do contact you to discuss few poor experience with customer service but would give it shot',
#  'ua pacific rim and date night cut out not constantly or randomly but one spot repeat',
#  'be try since to file report',
#  'send an email about my bad experience and you send back generic response yet another reason why ll never fly with you again',
#  'my mom leave her kindle on flight today burgundy case with light seat do anyone find it',
#  'here be the ticket please refund my unnecessary upgrade fee',
#  'be horrible they lose our carseat and expect u to use loner carseat safety regulation say it illegal to use used car seat',
#  'thank you',
#  'decision decision we love for you to try our service we offer status match too kp',
#  'need more info on that we have great amenity kit pj not include we status match aa kp',
#  'don care that link show me wrong price on your site it your site amp responsibility to ensure correctness',
#  'do you have any flight with lie flat seating from stl to pdx around the date of march',
#  'he need to get to home the th they be tell him it will be the th night be there compensation or anything that can be do',
#  'the baggage fee be waive for premier member please see jp what the point of membership',
#  'wonderful bag claim people finally have my bag but why do catch early flight original flight just land',
#  'dmed you thank you',
#  'thanks we will be in touch',
#  'thanks to karen salisbury at iah for amaze customer service find my daughter bag lose on ua make her day',
#  'day late flightr and my bag have not leave iad unite be not help at all everyone tell me different story',
#  'hi when do direct flight from houston to reno begin don see any day in march',
#  'like continental chicken feat fair',
#  'can you assist with current flight status for flt out of dfw tomorrow at be',
#  'leave my comment with customer care thanks for contact me',
#  'how do you lose gate check bag den to ord direct flight ugh',
#  'catch earlier flight to ord gate check bag and you have lose it at hare original flight land in minute',
#  'yes thanks so much purpleheart we see you speak with our reservation team and they have reinstate the flight thanks ey',
#  'captain on behalf of the front office welcome on board never hear that before laughed hard',
#  'can you please follow for dm on miss bag',
#  'to be clear on my luggage comment be reference the photo attach flight to jac',
#  'these be great fare',
#  'leave an item on the plane and have be call non stop and no one have be answer can you please help',
#  'awesome ll book my next christmas vacatinn this december any other way you want to devalue mileage plus',
#  'what good number to call to speak with someone about how you can fix what you do to people and their luggage on saturday',
#  'thank secure room for the night thx to very helpful customer service rep dorns thank her can',
#  'where my damn bag',
#  'well someone should tell that to the employee at the denver baggage claim still no bag',
#  'greeting ua club member here any idea if can use the air canada lounge at yvr fly ua tomorrow',
#  'how be mexico not international from the u',
#  'divert and miss our connect flight be just tell that my bag be on it way to msy if you only have people that care',
#  'male agnt in la threatens canadian cust when cust take pic of him at gate after agent announce can help rebook',
#  'we just want to go home tonight why do you cancel flight the last leg of our reserv out our permission',
#  'stress and rude agent overwhelm by delyd flight la den yelling at several people not pretty this be',
#  'land in boston at last night the hour of travel be rough tho',
#  'fail you cancel flightled our flight frm gjt and then use our reserv home to iah from sea for reflight booking problem out our permission',
#  'just send thank rt please dm your confirmation number if reflight booking problem be need thank you ey',
#  'have make my no fly list other airline wait when connector late flight stuck in iah',
#  'so what the deal do provide voucher for overnight or be cozy on the floor at',
#  'also the mere fact that have to go online to issue statement vice call and talk to some directly be one good example',
#  'thank you fly into newark from vail eagle',
#  'have weekend of deal with your company that would say otherwise',
#  'now what flight be go when get off plane',
#  'the proper response sorry for your wait what flight be you on so we can look into the issue that how would handle',
#  'your customer service be terrible stood inline hour no flight and hour late flightr still no bag',
#  'please upload the march on demand entertainment list on your website airplane',
#  'so you be inadequate by accident',
#  'denver international airport',
#  'thank you for respond so quickly with helpful tool',
#  'boarding time show min and your gate agent start at show up at and they have to check bag',
#  'agent in la let customer know they can help them rebook delay flight to den',
#  'empathizes my disappointment that stclass flight nonworking entertainmnt be worth',
#  'and when that doesn work',
#  'do you have see my message today about mcdonnell douglas dc model will hear it if you read it goodnight now',
#  'search for mileage ticket to bom couldn find single one be saver award see how you play earn mile but can use them',
#  'flight arrive minute early but then have we to wait for an hour for our bag',
#  'that not the issue the fact that no one even call despite promise to confirm the bag location be',
#  'what girl get ta do to get flight name change when she buy one for mean ex boyfriend and need girl trip stat',
#  'thank you we be sign up for notification we shall watch and wait snowflake snowflake',
#  'still wait to hear back my wallet be steal from one of your plane so would appreciate resolution here',
#  'would love if someone could get me back to austin tonight and do not wish to wait til tomorrow morning',
#  'or have lose my baggage heard different thing from different employee of have say nothing',
#  'c think that mile can repair the damage do it will be interest if they travel in and exp the bad flight ever',
#  'have flight out of dfw on tuesday how far in advance will you give notice if cancel flightled',
#  'be sign up for notification this be the first trip be not update on not sure why this happen',
#  'thank you take care of everything and make it right that the experience use to open the app to find flight changed',
#  'that be not in line with your response here and now wait until tomorrow morning because all the flight be overbooked',
#  'take the exact same aircraft in to lax day ago it fit no problem the agent today tell some nonsense about policy change',
#  'your helpful agent in club help be just out baggage fee and night of my life stop do business with',
#  'never heard of this',
#  'doesn charge ticket change fee do they not incur the same mysterious cost that you incur',
#  'exhaust amp frustrate link to fb post abt my travel issue',
#  'be deny get on the plane get the chance to prove it fit not rookie read my bio',
#  'that exactly the point it fit premier access board group this be return ticket ve be do this for yr',
#  've never experience bad customer service place blame on codeshare partner and not assume responsibility be unacceptable',
#  'currently on board so not now check in be terrible staff rude expensive luggage throw around etc',
#  'fuck up then void my ticket and keep my money not even an apology will never fly with your airline again',
#  'have the bad customer svcs this kevin rep at call center must be investigate my baggage lose and there no help but argument',
#  'should not sell ticket for on have terrible service and ua staff can not reach silver',
#  'just get demote from gold cuz my hubby get of the pqd tho there be enuf spent for gold discrimination angry',
#  'thank you',
#  'when will direct flight from belfast intl to newark resume from their winter break thanks',
#  'my favorite way to travel thank you',
#  'yes after this awful weather it appear can get home',
#  'yes lot you have terrible customer service at newark and despite raise complaint there we be ignore hence the tweet',
#  'lovely new plane from lga to ord but no power outlet',
#  'but if tweet the id number win that reveal my home address to anyone on the web',
#  'file delayed bag report on saturday my flight be cancel flightled and never go anywhere',
#  'the person be currently bettween gate and in lax',
#  'need it there before she land so she can have the ewr baggage claim file to have it send but the employee have not droppeditoffyet',
#  'rarely cease to amaze for the bad hope this be the last time have to fly with you',
#  'thank you for the quick response but can not dm you until you follow me a well',
#  'icloud it be not there yet please help',
#  'need the phone number to baggage claim in lax my mom leave her phone and someone call say they would put it there but on',
#  'do no response back',
#  'this be atrocious customer service',
#  'will not have to honor absurdly low mistake fare vía',
#  'delay departure to check bag at gate claim space fill and walk on to open space delay',
#  'you cancel flight our flight for no reason amp now we have be on the phone for an hour on our vacation why',
#  'that your response shake my head back and forth with tsk you can do well from customer service to your apology',
#  'thanks it mile from rtb to europe to do multiple destination so we could stop over in u on way way back mileage diff',
#  'of course do the bag should be here by now worried',
#  'you be the bad will avoid you like the plague',
#  'be the bad airline in the world',
#  'someone need to dm me and resolve this correctly extremely disappointed with the service receive terrible management',
#  'premier gold desk change flight waive fee give me wrong flight now jana acosta in salt lake refuse the same service angry',
#  'will give you one thing you be consistent but unfortunately you be consistent at not do your job well',
#  'will but right now to angry',
#  'first time fly with unite also last time back to for me',
#  'use to be commit flyer until merger remember now why switch to',
#  'the least you could do be offer me ticket in coach instead of just cancel flight my reservation because of your glitch',
#  'say make the flight but with poor non communication unaccounted for lose time amp lot of frustrated flyer stand around',
#  'think dm would be good',
#  'gate announcement state delay due to maintenance yet app say late flight arrive aircraft tell the truth',
#  'you be easily the bad company have ever experience you have lose someone personal possession amp you couldn care less',
#  'how can your app show arrive aircraft be early but depart flight be delay due to late flight arriving aircraft',
#  'already do that at the airport and hr late flightr it still not here you guy be really kill me today try to stay positive',
#  'once united service level reach those of etihad or let be more realistically lufthansa then ill consider it again',
#  'really someone call in sick and then someone forget to call replacement now an hour late flight to take off',
#  'ask flight attendant what typical compensation would be amp say we might get free tv',
#  'do',
#  'thank you jh appreciate the prompt responses me and other passenger will be do so',
#  'have be such disappointment today simply put rather unpleased with thing currently flight delay cant wait to just get home',
#  'during the same round trip my non english speaking friend be strand twice for hour each time most staff member be rude',
#  'find group of people who actually hat people more than isi thats right unite airline',
#  'nope walk up amp down the orf terminal amp not united agent to be find show up last minute to board u many panic people',
#  'thank you',
#  'by the time finally get to dallas could have drive with less frustration and cheap',
#  'try to get to my final destination we need compensation just about hr of personal time waste',
#  'that guy really have no customer service clue could have spend effort clearing bin for rollerboards instead of art project in mine',
#  'he have no priority and iove it',
#  'please to be premier platinum',
#  ...]

# %%
# The 'tweets_cleaned_1' list is printed to make it easier to compare the text of the tweets in the last two
# stages of text preprocessing.

tweets_cleaned_1
# Out:
# ['what said',
#  'plus you have added commercials to the experience tacky',
#  'didn today must mean need to take another trip',
#  'it really aggressive to blast obnoxious entertainment in your guests faces amp they have little recourse',
#  'and it really big bad thing about it',
#  'seriously would pay flight for seats that didn have this playing it really the only bad thing about flying va',
#  'yes nearly every time fly vx this ear worm won go away simple_smile',
#  'really missed prime opportunity for men without hats parody there',
#  'well didn but now do',
#  'it was amazing and arrived an hour early you re too good to me',
#  'did you know that suicide is the second leading cause of death among teens',
#  'lt pretty graphics so much better than minimal iconography',
#  'this is such great deal already thinking about my nd trip to amp haven even gone on my st trip yet',
#  'flying your skies again take all the away from travel',
#  'thanks',
#  'sfo pdx schedule is still mia',
#  'so excited for my first cross country flight lax to mco ve heard nothing but great things about virgin america',
#  'flew from nyc to sfo last week and couldn fully sit in my seat due to two large gentleman on either side of me help',
#  'redheart flying smilingface thumbsup',
#  'you know what would be amazingly awesome bos fll please want to fly with only you',
#  'why are your first fares in may over three times more than other carriers when all seats are available to select',
#  'love this graphic',
#  'love the hipster innovation you are feel good brand',
#  'will you be making bos gt las non stop permanently anytime soon',
#  'you guys messed up my seating reserved seating with my friends and you guys gave my seat away poutingface want free internet',
#  'status match program applied and it been three weeks called and emailed with no response',
#  'what happened ur vegan food options at least say on ur site so know won be able eat anything for next hrs',
#  'do you miss me don worry we will be together very soon',
#  'amazing to me that we can get any cold air from the vents',
#  'lax to ewr middle seat on red eye such noob maneuver',
#  'hi just bked cool birthday trip with you but can add my elevate no cause entered my middle name during flight booking problems cryingface',
#  'are the hours of operation for the club at sfo that are posted online current',
#  'help left expensive headphones on flight iad to lax today seat no one answering amp number at lax',
#  'awaiting my return phone call just would prefer to use your online self service option worried',
#  'this is great news america could start flights to hawaii by end of year via',
#  'nice rt vibe with the moodlight from takeoff to touchdown',
#  'moodlighting is the only way to fly best experience ever cool and calming purpleheart airplane',
#  'done and done best airline around hands down',
#  'when can book my flight to hawaii',
#  'your chat support is not working on your site',
#  'view of downtown los angeles the hollywood sign and beyond that rain in the mountains',
#  'hey first time flyer next week excited but having hard time getting my flights added to my elevate account help',
#  'plz help me win my bid upgrade for my flight lax gt sea wineglass thumbsup seat airplane',
#  'have an unused ticket but moved to new city where you don fly how can fly with you before it expires',
#  'are flights leaving dallas for seattle on time feb',
#  'for good reason you rock',
#  'dream',
#  'wow this just blew my mind',
#  'after last night think agree',
#  'all were entertaining',
#  'is flight on it way was supposed to take off minutes ago website still shows on time not in flight thanks',
#  'julie andrews all the way though was very impressive no to',
#  'wish you flew out of atlanta soon',
#  'julie andrews hands down',
#  'will flights be leaving dallas for la on february th',
#  'hi so excited about your lga gtwinkal deal but ve been trying book since last week amp the page never loads thx',
#  'you know it need it on my spotify stat',
#  'lady gaga she is amazing smilingfacewithsmilingeyes',
#  'carrie',
#  'new marketing song let us know what you think',
#  'julie andrews first but lady gaga wow me last night carrie meh',
#  'called weeks ago about adding flights from to my elevate they still haven shown up help',
#  'all are great but have to go with smilingfacewithheart eyes okhand',
#  'sorry mary martin had it first',
#  'love all three but you really can beat the classics',
#  'flight dal to dca pm tried to check in could not status please',
#  'heyyyy guyyyys been trying to get through for an hour can someone call me please',
#  'hi virgin on hold for minutes are there any earlier flights from la to nyc tonight earlier than pm',
#  'congrats on winning the award for best deals from an airline us',
#  'everything was fine until you lost my bag',
#  'need to change reservation have virgin credit card do need to modify on phone to waive change fee or can do online',
#  'emailed your customer service team let me know if you need the tracking number',
#  'hi just booked flight but need to add baggage how can do this',
#  'your airline is awesome but your lax loft needs to step up its game for dirty tables and floors',
#  'not worried it been great ride in new plane with great crew all airlines should be like this',
#  'awesome flew yall sat morning any way we can correct my bill',
#  'or watch some of the best student films in the country at feet',
#  'first time flying you all do you have different rate policy for media bags thanks',
#  'what is going on with customer service is there anyway to speak to human asap thank you',
#  'what happened to doom',
#  'why can you supp the biz traveler like and have customer service like',
#  've applied more then once to be member of the crew team im interested',
#  'you re the best whenever begrudgingly use any other airline delayed and late flight worried',
#  'have no interesting flying with you after this will cancelled flight my next four flights planned',
#  'it was disappointing experience which will be shared with every business traveler meet',
#  'having trouble adding this flight my wife booked to my elevate account help',
#  'can bring up my reservation online using flight booking problems code',
#  'random what the distribution of elevate avatars bet that kitty has disproportionate share',
#  'lt flying va but life happens and am trying to my trip jperhi can you help va home page will not let me',
#  'why is the site down when will it be back up',
#  'you down with rnp yeah you know me',
#  'hi did not get points on my elevate account for my most recent flight how do add the flight and points to my account',
#  'like the tv and interesting video just disappointed in cancelled flightled flight when other flights went out to jfk on saturday',
#  'just landed in lax an hour after should of been here your no late flight bag check is not business travel friendly',
#  'why is flight redirected',
#  'is it me or is your website down btw your new website isn great user experience time for another redesign',
#  'can check in or add bag your website isn working ve tried both desktop and mobile',
#  'let scanned in passengers leave the plane than told someone to remove their bag from st class bin',
#  'what is your phone number can find who to call about flight reservation',
#  'is anyone doing anything there today website is useless and no one is answering the phone',
#  'trying to add my boy prince to my ressie sf this thursday from lax',
#  'why must traveler miss flight to late flight check bag missed my morning appointments and you lost my business',
#  'check out new music',
#  'how direct flight fll gt sfo have unexpected layover in vegas fuel yet peeps next to me bought for vegas flight',
#  'your no late flight bag check just lost you my business missed flight and am apt three other people on flight had same exp',
#  'amazing customer service again twohearts twohearts raeann in sf she the best',
#  'called your service line and was hung up on this is awesome',
#  'your site is tripping trying to check in and getting the plain text version am reluctant to enter any card info',
#  'was scheduled for sfo dal flight today changed to th due weather looks like flight still on',
#  'has getaway deals through may from one way lots of cool cities',
#  'has getaway deals through may from one way lots of cool cities',
#  'has getaway deals through may from one way lots of cool cities',
#  'has getaway deals through may from one way lots of cool cities',
#  'have great week sunwithface airplane',
#  'come back to already we need you to take us out of this horrible cold',
#  'should be concerned that am about to fly on plane that needs to be delayed due to tech stop',
#  'is the best airline have flown on easy to change your reservation helpful representatives amp comfortable flying experience',
#  'and again another rep kicked butt naelah represents your team so beautifully thank you',
#  'your beautiful front end design is down right now but it was cool to still book my ticket all your back end was secure',
#  'love the team running gate at las tonight waited for delayed flight and they kept things entertaining',
#  'use another browser amp brand with reputation built on tech response doesn have cross browser compatible website',
#  'and now the flight flight booking problems site is totally down folks what is the problem',
#  'like the customer service but min delay just for connecting passengers seems too long va',
#  'thanks to your outstanding nyc jfk crew who moved mountains to get me home to san francisco tonight',
#  'you have the absolute best team and customer service ever every time fly with you delighted thank you',
#  'do you provide complimentary upgrades to first class if there are available seats',
#  'need to change my flight thats scheduled in hours and min wait time on phone im calling intern help',
#  'completely awesome experience last month bos las nonstop thanks for such an awesome flight and depart time',
#  'how can watch the on my jfk gt sfo flight',
#  'is flight cancelled flightled and what do do if it is',
#  'you are failing your customers because your check in process does not link to tsa pre check',
#  'us too terrible airline just gave us hotel hotline number and said sorry',
#  'has flight number from sfo to cabo san lucas arrived yet',
#  'your assistance yesterday when cancelled flightled our flight was to give us hotel hotline shame on you',
#  'another delayed flight',
#  'need to register service dog for first class ticket from sfo gt dulles the phone queue is an hour or longer pls advise',
#  'you rock for making it so can watch on my flight',
#  'dropped track on you',
#  'always xoxo',
#  'why can we book seats on your flights when we buy them or even during check in creates so much anxiety',
#  'you think paying an extra bucks rt for luggage might afford you hiring an extra hand at',
#  'best customer service rep in the world takes the cake',
#  'can you find us flt out of lax that is sooner than midnight on monday that would be great customer service grinningfacewithbigeyes',
#  'please provide status for flight cant imagine it on time as the web indicates dude to weather here and or dallas',
#  'you have amazing staff amp super helpful as just ran the they have spoiled me with comfort',
#  'paid the premium to fly you across the country you cancelled flight my flight and offer no check fee or upgrade love sad face worried',
#  'question is it not possible to book seat for an infant under it not giving me the option but we want seat for him',
#  'always have it together you re welcome rt you re so welcome',
#  'home to in back to',
#  'don understand why you need dm to give me an answer on if you have damaged luggage policy',
#  'does that mean you don have policy for destroyed luggage',
#  'is there special assistance if travel alone kids and infant priority boarding',
#  'thank you for checking in tickets are purchased and customer is happy wink',
#  'is your website ever coming back online',
#  'is flight from love field to sfo definitely cancelled flightled for monday february',
#  'is flight out of lga to dfw on time',
#  'my drivers license is expired by little over month can fly friday morning using my expired license',
#  'having problems flight booking problems on the web site keeps giving me an error and to contact by phone phone is minute wait',
#  'how do reschedule my cancelled flightled flights online the change button is greyed out',
#  'rang but there is wait for minutes can book the same ticket through vendor fix your site',
#  'got flight we were told for today checked my email and its for tomorrow this is unacceptable',
#  'our flight into lga was cancelled flighted we re stuck in dallas called to reschedule told could get flight for today',
#  'why don any of the pairings include red wine only white is offered worried',
#  'is the website down',
#  'your site seems little wonked right now may want to have look tried on two browsers no css',
#  'disappointed that the agent at the designated silver status check in line closed to assist all pasengers',
#  'plans to include austin to its dallas route topnews arab',
#  'is it normal to receive no reply from central baggage',
#  'at logan airport and waiting to checkin for my am flight checkin desk not open why',
#  'to jump into the dallas austin market',
#  'beats eps views takes on va luv investor business daily',
#  'lister to my show my on monday',
#  'to begin dallas austin in april ketr',
#  'congrats you just got all my business from ewr to sfo lax fuck you fl sfo ewr was the clincher',
#  'applied over weeks ago haven heard back and flying this week',
#  'love to know what your policy is for damaged luggage',
#  'thank you for the follow',
#  'too many apologies you the worse airlines don even respond to your cudtomers',
#  'shame on va for making people spend money in stranded cities when other airlines are landing at jfk who will reimburse me',
#  'dm you',
#  'can you please have flights in sjc have no choice but to fly southwest to vegas wearyface loudlycryingface',
#  'too bad you say it takes to days via your confirmation email when inquired after weeks you claim to weeks',
#  'flight from bos gt las tomorrow was cancelled flightled no notification wait times are hour will you rebook on another airline',
#  'smilingfacewithsunglasses rt you ve met your match got status on another airline upgrade restr',
#  'only way to fly',
#  'if only you guys had flights from cmh',
#  'lot of apologies being thrown out to customers from what can see very sad thanks for nothing worst airline ever',
#  'for all my flight stuff wrong and did nothing about it had ever',
#  'having an issue finding missing item on plane can you help me find which airport my plane headed to next',
#  'you will match my status cool',
#  'you ve met your match got status on another airline upgrade hear no evilmonkey',
#  'trying to book flight with you guys and your website won let me about to lose my business',
#  'you suck',
#  'thanks',
#  'just dm same issue persisting',
#  'because we never rec cancelled flightlation notice we were left no options to fly out of ps driving to la for red eye mon kids',
#  'trying to book flight amp your site is down beamingfacewithsmilingeyes',
#  'you have any flights flying into boston tomorrow need to be home and you cancelled flightled my flight and didn do anything',
#  'you stink flight cancelled flighted from psp to jfk and no notification or ability to rebook better',
#  'love your guy song we re dancing to it for our high school dance revue',
#  'your website is down and trying to check in',
#  'done thank you for the quick response apparently faster than sitting on hold wink',
#  'nervous about my flight from dc to lax getting cancelled flightled tomorrow just sent you dm to help me',
#  'cool picture of another virginamerica plane off our wing what site',
#  'keep up the great work simple_smile',
#  'my goodness your people field are amazing under pressure redheart from texas in crisis please fly me to ny',
#  'thanks for great flight from la to boston pilots did great job landing in the snow can we go back to la now',
#  'can you please get me to the new york area before monday afternoon',
#  'thanks so much for the awesome support you guys rock',
#  'seats in row don recline should mention that on your website',
#  'flight delayed hours in la due to mechanical problems handle like pros but you could have tossed us free drink',
#  'why cancelled flight flights today no precipitation to be scared of snowflake snowflake snowflake',
#  'twitter team you guys killed it for rescheduling me asap thank you',
#  'you guys charged me to reschedule flight that was then cancelled flighted and are now refusing to refund it what the deal',
#  'can access your website from safari on iphone seems to work on mac and ipad need iphone to add passbook',
#  'on ipad and iphone clicking the checkin link in the email received at hrs before flight',
#  'your mobile site is broken shows header elevateuser numofpointsavailable number points won let me checkin',
#  'was really looking forward to my flight can you let me know when it will be rescheduled',
#  'why cancelled flight flight vx one sec its delayed on my to airport the next its cancelled flightled gonna email or call me to reschedule',
#  'did it but there was problem in the link from the email for check in thanks',
#  'had to change to another airline to get to dc today why is able to land in dc but not you cost me ugh',
#  'was so looking forward to my first flight with you today but it was cancelled flightled along with the subsequent one',
#  'when are you putting some great deals from pdx to las or from las to pdx show me your love',
#  'wish can afford to fly with you next friday going back home love everything about your airline',
#  'how are you gonna have deal from dallas to dc but no deal from dc to dallas',
#  'it just bug report guys',
#  'hold times at call center are bit much',
#  'like',
#  'site down',
#  'you have the best flight attendant ever',
#  'awesome rt watch nominated films at feet',
#  'thanks so much',
#  'trying to reset my password email never arrives help',
#  'the only airline based in silicon valley',
#  'very nicely done clappinghands',
#  'looking forward to watching the oscars on my flight home tomorrow might even get something bubbly to drink wink',
#  'what is the reason for the delay of the departure of vx from jfk this afternoon',
#  'is todays flight from palm springs ca to jfk in ny cancelled flightled',
#  'hahaha facewithtearsofjoy you guys are amazing love you guys growingheart',
#  'sounds like fun',
#  'any updates on flight from jfk gt lax',
#  'spruce moose',
#  'the css on your site is right now please fix site unusable',
#  'we re on flight vegas to boston today checked in online but our bag count didn register can fix that somehow',
#  'classiq luv virgin america greetingz',
#  'hi trying to do check in but the website is not working tried different browsers and the problem continues',
#  'thanks for your great customer service today amp for helping me get all my travel sorted out',
#  'thanks guys sweet route over the rockies',
#  'love the music blasting at gate in while waiting for flight to only if could get an iced coffee',
#  'the passenger in flt that assaulted me shouldn have flown trust he banned crew filed report to',
#  'current bug on website shows select departure city when selecting destination city',
#  'luggage was severely dented missing wheel coming off baggage claim in san luggage agent miranda think wasn any help',
#  'thank you for the easy itinerary shift for impending weather quick painless amp free',
#  'if you love to see more girls be inspired to become pilots rt our free woaw event march at abq',
#  'thanks good times there and back the entire flight cocktailglass',
#  'beats expectations shares take off santa cruz sentinel',
#  'any plans to start flying direct from dal to las',
#  'big love gratitude mpower werin vipswagbags',
#  'you re doing great job adding little luxuries aesthetics that improve the air travel experience thank you keep it up',
#  'requested window seat and confirmed window but got stuck in middle seat not good way to treat silver member unamusedface',
#  'grand budapest hotel',
#  'this is what you missed next trip to the',
#  'paid for direct flight on purpose not to have to stop for fuel exhausted frequent flier and nothing for inconvenience',
#  'there is something wrong with you website in safari iphone',
#  'thanks for gate checking my baggage on your full flight dfw lax and giving me early boarding too',
#  'already checked in so the page expired',
#  'boo for not refunding seat upgrade fee did not want to buy in the first place',
#  'shares rise on financial results usa today',
#  'adds pillows instead of lie flat seats in first class arms race',
#  'see what you did there wink',
#  'way to take advantage of simple_smile',
#  'you know flying virgin for the fight',
#  'your inflight team makes the experience',
#  'cutest salt and pepper shaker ever just when think you guys can get any better you just do',
#  'moved my seat with no notice better seat is cabin select not behind the row selected thumbsdown',
#  'shares up on results',
#  'fav airline',
#  'we have hot female pilot sweet dca to sfo simple_smile',
#  'thumbsup thumbsup airplane airplane growingheart when are you guys going to start flying to paris you re welcome',
#  'what is your policy on flying after surgery am still waiting for answer so can tell me doctor',
#  'already contacted central baggage amp sent dm is charging me for the dress that was in the lost suitcase',
#  'thank you',
#  'is there anything going on with the website ve been getting lot of errors past minutes',
#  'think left something on the plane yesterday who do call ah',
#  'need you to follow back in order to dm',
#  'need to start flying to smilingfacewithsmilingeyes grinningface grinningfacewithbigeyes grinningfacewithsmilingeyes',
#  'they told to check with the airline regulation first so that is why contacted you',
#  'have just checked in flight to sfo from lax amp been told as atlantic flying club gold get no benefits',
#  'husband and ordered three drinks via my screen and they never came awesome',
#  'soooo are you guys going to leave the seatbelt light on all flight you can barely call this turbulence simple_smile',
#  'what is your policy on flying after surgery',
#  'posts second consecutive full year net profit',
#  'funny story your website is broken you have missing javascript and stylesheets on the checkin process dislike this',
#  'would love to do more for virgin just like do for',
#  'results handily exceed forecasts',
#  'applied for position in and was wondering if you guys received my application',
#  'achieves second year of profitability despite revenue pressure',
#  'gives positive outlook but sees increased competition',
#  'trying to check into my am ct flight tmm on the desktop website and it not working some sort of caching bug sos',
#  'weather delays gt next few weeks wink',
#  'check the website before you go to the airport',
#  'do you guys know your check in links from emails are broken',
#  'pilot says we expect choppy landing in nyc due to some gusty winds temperature of about degrees amp the windchill',
#  'loved it can wait for monday return flight mostly just to watch the inflight safety video again',
#  'lost my luggage days ago on flight vx from lax to iad amp calling every day no response please give me back my stuff',
#  'the flight booking problems section of your website seems to be broken on chrome might wanna look into that',
#  'hi just wanted to see if you have any new routes planned this year for newark love flying you guys and hope to do so more',
#  'mean probably inappropriate while on board but it on',
#  'happy to spend the day together let do this',
#  'is saving my sanity right now',
#  'missed my flight how does standby work',
#  'they were very understanding and helped me out thx',
#  'brought it all the way across the country today see',
#  'thank you absolutely will smilingfacewithsunglasses',
#  'looks like broken link for your assets',
#  'are you ready let say it together noooo turbulence today faceblowingakiss',
#  'the manage itinerary section of your website seems to be broken for me',
#  'can check in your site looks like this every time it loads',
#  'can help this princess needs urgent treatment in unitedstates old battling cancer could help with flights growingheart',
#  'may start service to hawaii from this year',
#  'other carriers are less than half price for round trip fare am stunned',
#  'wtf is happening in pdx late flight march such that one way from sfo is',
#  'add dtw and sold',
#  'how about some free drinks on the flight back for the free promo',
#  'thanks',
#  'momma made it beamingfacewithsmilingeyes beamingfacewithsmilingeyes beamingfacewithsmilingeyes',
#  'please contact me about portfolio left on flight vx from jfk to sfo tonite seat am need it returned call',
#  'help was on flight from jkf tonight seat left portfolio need it back',
#  'seattle bound wifey got me the duffle for vday she keeper holla',
#  'my luggage is gone ve filed my paperwork promised call email still no resolution or response from central luggage',
#  'debbie baldwin gave performance of the safety demo this evening on vx',
#  'thanks',
#  'thanks for taking care of on her flight',
#  'thanks for the lovely soft views to',
#  'requested mileage challenge for status several weeks ago online but haven heard back how do get help with this',
#  'just trying to book tickets to nyc and facing super fun broken styling don worry ll keep trying simple_smile',
#  'many thanks for the follow looking for any help smilingfacewithheart eyes growingheart unitedkingdom growingheart unitedstates growingheart ribbon globeshowingasia australia ribbon',
#  'nice lofty view',
#  'applied for status match on feb got confirmation email same day still no news though you guys have dropped ball late flightly sadbutrelievedface',
#  'is my new go to airline',
#  'can you help in need of some help in ribbon unitedkingdom ribbon unitedstates ribbon',
#  'adore you and am so looking forward to my flight to austin in two weeks',
#  'was so glad it was mentioned took my first virgin flight few years back and it was transformative experience',
#  'flight booking problems flight to uphold my status match do taxes on ticket count as earned status points',
#  'trying to check in but looks like your site is down',
#  'spending my birthday night with you dal dca get me home',
#  'sent couple messages to the email you provided but to no avail will try again next year cheers',
#  'first time flying virgin went to thanks for the smooth ride easily my new fav airline',
#  'seriously though will there not be direct flights from sfo fll in may',
#  'it fine already done with my purchase but you should try it just go most of the way through then go back',
#  'not really the experience was hoping ws forced check in small carry on nothing but empty cabin space on board',
#  'wjere is our luggage slow at lax',
#  'to jump into the market',
#  'spoke with representative that offered no solution am loyal customer who flies on as well',
#  'am deeply disappointed that your birthday promo was not applied to trip booked mere days before received the email',
#  'what happened to direct flights from sfo fll looking in may only see connecting',
#  'can you help left my blazer in kooples jacket bag at rd row second seat from right gate lax flight to sfo',
#  'partners with checkout as mobile payment method to help boost mobile conversion rates',
#  'just promoting the product is all had problem with southwest and recommend noneother than the best',
#  'love you guys but pls get some direct routes las to aus',
#  'would like help with some flights please',
#  'bruh turn down for what',
#  'of course work for and obsessed with the entire virgin family',
#  'ok first time flying with you tonight simple_smile',
#  'digging the swanky pink mood lighting during the flight from nyc to sfo just needs cabaret singer think about it',
#  'done but need the receipt asap could you please help',
#  'have and embossed badges and patches superior to the ones you are currently using',
#  'on vx from jfk to la dirty plane not up to your standards',
#  'on flight vx headed to la from jfk dirtiest va plane have ever been on sad for great airline',
#  'got it squared away someone picked up as soon as tweeted should have tweeted sooner winkingface',
#  'your avis rental continue button doesn work on your website to book car tried times on phone this sucks',
#  'delayed to',
#  'currently in minute of being on hold with cust service do need to do anything to add lap child to my reservation',
#  'adds pillows instead of lie flat seats in first class arms race by',
#  'of course have fun celebrating thanks happy chinese new year',
#  'flight booking problems last second flight for next week from sfo to san any chance you want to gift me promo code since love you guys',
#  'comenity bank is joke please change nothing but constant problems with this bank',
#  'just did how can dm do have to also add me',
#  'for my grandma ella th she would lt bday greeting from your flight crew she was stewardess for eastern airlines',
#  'just bought tix for atx dallas route thanks for adding that love yr airline amp yr website is best transactional site ever',
#  'anytime sugafly',
#  'gave credit for my late flight flight yesterday great service that wow moment unexpected gesture',
#  'need receipt for flight change can you send one',
#  'submitted status match request while back and still haven heard flying on monday can you look accelerate',
#  'had me at their safety video loved my first cross country flight',
#  'that doesn look to fat to me it looks yummy',
#  'ceo says amp have strayed from low cost model',
#  'brilliant brisk am in boston in cue for vx',
#  'atlantic ploughs lone furrow in the',
#  'atlantic ploughs lone furrow in the',
#  'atlantic ploughs lone furrow in the',
#  'omg omg smilingfacewithheart eyes smilingfacewithheart eyes nonstop dallas to austin on virgin sparkles facescreaminginfear airplane',
#  'your planes are really pretty just thought should know that simple_smile',
#  'when are you flying to hawaii',
#  'pulling my hair out trying to book flight with your site doesn work on iphone or ipad don have computer',
#  'thank you',
#  'can get some help with support ticket it been days incident thank you',
#  'good to be home',
#  'cannot even open my laptop in seat and paid premium for this let me out of here',
#  'am in seat and cannot even open my laptop and paid extra for this seat',
#  'if only you guys were starting those flights at the end of the month guess still road tripping on feb',
#  'thanks for that been needing way to make those austin trips from dca and now you have come through',
#  'announced new route to austin fares from way',
#  'really sprint thought you guys were kewl',
#  'this is too cool never been on ur planes but now will',
#  'you should have dollar lax las fares',
#  'great well deserved',
#  'fyi the info com email address you say to contact in password reset emails doesn exist emails bounce',
#  'status match weeks have gone by and no news flt next week hope flt will count towards requirement cust svc no help',
#  'your website sucks donkey dicks just thought you should know all best',
#  'you should still develop an app then you will be my favorite airline',
#  'all crap channels which is why pay to watch uk tv',
#  'got it all set thanks',
#  'no channel this year',
#  'only thing see on passbook is virgin mobile mexico how do integrate',
#  'giants and virgin america match made in heaven',
#  'thank goodness also see you friday nwk gt sf boom',
#  'how come you don have an iphone app still using and making me waste paper',
#  'your back of seat entertainment system does not accept credit cards that have an apostrophe in the surname',
#  'when will vx use all lga slots instead of today adding aus makes this less likely worried',
#  'is helping me step up my game',
#  'luv ur people and product thing is do charge for herbal tea but not black tea not caffeine drinker',
#  'thank you see all soon excited to see the expansion of destinations spread those wings',
#  'announces new nonstop connecting amp intro',
#  'adds austin dallas love field route',
#  'sad to learn you no longer fly sfo gt phl hope it returns',
#  'can you tweet me the cancelled flight chng fee for flight or can rebook under one of your affiliates if so who are afiliates',
#  'has the most incredible customer service ve ever experienced so refreshing',
#  'now when will we see virginamerica come to philadelphia phl',
#  'am dreaming did you really just open up route between dallas and austin and does this mean houston might be next',
#  'omg finally',
#  'to start xweekly flights from to on apr',
#  'nice to see you expanding in texas but don forget about us here in would love to see more flights out of here',
#  'kinda sucked my earphone jack didn work on my flight they may want to look into that for future passengers',
#  'very poor experience first computer problem now seat malfunction stuck missing meeting in san diego',
#  'to battle on route via',
#  'the dal aus route makes my day',
#  'awesome deals dal aus for only each way',
#  'miss the in san jose',
#  'love it taking on in their backyard consumers win when biz competes',
#  'is flying from love to austin now that is most excellent news',
#  'can we make every vx plane with why should austin be the only one getting nerd love',
#  'please add more frequency to pdx portland',
#  'congrats vx on the new route airplane partypopper',
#  'tried that you offered to charge me an additional for new ticket or be stranded until thurs st time last time',
#  'can help with flights to get old battling cancer who needs treatment in unitedstates growingheart ribbon growingheart',
#  'never had bad experience before but this one took the cake now extortion for carry on items as well',
#  'had to spend hours worrying that items in carryon would be broken stolen since couldn carry them on plane or lock bag',
#  'all of group was told there was no more room in the bins when got on the plane was room for at least bags in my row',
#  'thanks for making my flight from lax to jfk nightmare by forcing me to check my carry on bag at the gate',
#  'have lots of flights to book and your site it not working ve been on the phone waiting for over minutes',
#  'am all about the in flight artisanal cheese and wine pairing',
#  'does virgin america fly direct from seattle to nyc or boston',
#  'that classy',
#  'sure lot of your and jfk lhr flights go lot faster than mph with strong tailwind',
#  'now it just minus minutes until my elevate silver upgrade window opens grinningfacewithbigeyes thumbsup',
#  'save some for tomorrow am',
#  'why is it taking years to fly home to dallas get your shit together',
#  'club virgin is bumping in new york',
#  'would have been rough trip but luckily we were on flight',
#  'is that beamingfacewithsmilingeyes',
#  'please come to minneapolis st paul',
#  'yes fyi my bff',
#  'another perfect flight how come on your planes the sun visors can stay down other carriers make you raise them',
#  'nice rt the man of steel might be faster but we have wifi just saying',
#  'love the dancing little richard cool beans',
#  'don use passbook still love you though lt simple_smile ll just use my email in the future',
#  'thanks for the free birthday points all are all right with me',
#  'do you have an application for ios was looking and only saw virgin mexico worried lt',
#  'man of steel flies to more cities though and with more frequency too',
#  'thanks so much for sharing just added it to my site',
#  'good point',
#  'heard he has virgin mobile hotspot wink',
#  'you got cheese plate flights too',
#  'on all your flights',
#  'dad on segway is the best part of this whole infographic',
#  'are there any plans for short haul airline in europe would defiantly fly with you guys simple_smile',
#  'wifi and better seating',
#  'how come abc is the only one of the network channels you don have',
#  'started my flight with scolding for using an overhead bin that was then offered to the person seated next to me',
#  'not only was it great but you return my calls the day after couldn ask for more',
#  'while other airlines weren cancelled flighting flights into bos and helping their customers get home virgin was saying good luck',
#  'dear virgin customer while you re stranded in sf for days amp cost we will do the very least we can to accommodate you',
#  'should use this in their next airline commercial lol',
#  'grouping virgin in with the others now bos weather has exposed their actual cus serv model never flight booking problems with virgin again',
#  'as one of the travelers affected by the boston storm shocked at virgin complete apathy toward their customers',
#  'umm so no reason as to why this is is there someone different should contact or contact me to get definitive answer',
#  'trying to make the change in advance not just hours prior tried it online earlier and it wanted in change fees',
#  'so loyal that driving to from to fly virgin since you cut flights wink',
#  'any way to change from main cabin to main cabin select on same flight without paying change fee penalty',
#  'you guys are perfect as always lt',
#  'thanks all have some of the best customer service left in the industry',
#  'can you give me silver status for months',
#  'really wish you fly out of those fares are amazings',
#  'mood lighting on point raisinghands reclining my seat kickin up my feet zzz',
#  'my flight scheduled for pm departure still says on time but no plane at gate any update on how long of delay',
#  'my group got their cancelled flightlation fees waived but can because my ticket is booked for your reps were no help either poutingface',
#  'are there any sign up bonuses to enroll in elevate',
#  'just got on the pm in newark home to la your folks at ewr are incredible',
#  'morning if have question regarding elevate points amp flights can dm you',
#  'still waiting to see disappointedface',
#  'was wondering if you guys recieved my dm and we re able to potentially respond asap',
#  'flying lax to sfo and after looking at the awesome movie lineup actually wish was on long haul',
#  'book out of town with fares from way restr',
#  'thanks',
#  'thanks for taking care of that mr happy customer',
#  'still no refund or word via dm please resolve this issue as your cancelled flightled flight was useless to my assistant trip',
#  'delayed due to lack of crew and now delayed again because there long line for deicing still need to improve service',
#  'thanks we filled it out how our luck with this is it common',
#  'your eri ord express connections are hugely popular now if only we could have an eri ewr hop simple_smile',
#  'even on international flight glasgow to the then what about orlando to newark all mins',
#  'you think you boarded flight au too early think so',
#  'understand but it tough when there is no way to get to the airport serious risk of an accident it steep price',
#  'gate agent hooked me up with alternate flights if you have way to prevent the constant issues that would rock',
#  'flying gla mco in few weeks how long do we have to be at airport for before departure for both international and domestic ta',
#  'thanks',
#  'thanks it is on the same ticket',
#  'why not is it law or policy',
#  'is the worst nonrefundable first class tickets oh because when you select global fc their system auto selects economy upgrade',
#  'so can buy tix days before flight but can transfer the tix flawed security logic flawed customer service',
#  'did start claim but weeks is unrealistic am really supposed to go that long with out car seat for my child ridiculous',
#  'follow me please this airline is beautifull heartsuit',
#  'no don but sure united have my info on its system',
#  'if the car seat is lost should just reimburse me for new one this is not pair of shoes it necessity for my child',
#  'just submitted my response on the link you sent',
#  'yes david allan send an email with this number kmm l km and case',
#  'that totally sucks my cousin worked at phl said',
#  'just wanted to let you know how wonderful rosetta the gate agent was working flight dan to ase let her know she wasappreciated',
#  'yes paper voucher that got on january th',
#  'beginning of feb called united they said they would send another voucher by mail never got anything',
#  'the internet is great thing am emailing executives in your company maybe they will respond to me in timely manner',
#  'do need to use chase united club pass for my yr old son or can he come in with me on my pass',
#  'and what am suppose to do with that number',
#  'thats weak see ya wavinghand hey',
#  'flew back other company since united didnt have an earlier flight',
#  'lost voucher that was given in miami aeroport on jan did not use it',
#  'am trying to book awards for september and need flights on but they will not show even many award seats availab',
#  'sure did had to drive total of hours to get my own bag like to explain that debacle but no one wants to talk to me',
#  'gee that like almost caring about ppl more than think more int in having trusted adult daughter',
#  'see we were told repeatedly that the pilot was late flight and kept getting late flightr after we boarded there was defibrillator issue',
#  'why no preferred security line anymore my tsa pre check didn pull on my partner flight',
#  'airport need to indicate different gate for terminals amp',
#  'yes please am newly married and trying to update my last name on preexisting international flight it seems so easy but',
#  'how does united refuse to reissue lost voucher when their plane didn take off due to mechanics',
#  'also during the run was instructed to do shattered my computer',
#  'yes we have been with the agents for the last minutes one of the agents have been very rude but thankfully ladan has been nice',
#  'that right with an overnight miami',
#  'have clients with an hr layover at iah during the day will they have to claim amp recheck luggage or will it be taken care of',
#  'am trying to find out if the loaner seat is new or used used car seat is illegal according to safety regulations',
#  'dmed you the details',
#  'iah to charlotte baggage claim rep latrice non existent ignored customer then inappropriately touched customer',
#  'kewl will also let them know the overhead bin over my row was inop love good abbreve',
#  'thanks for your help got me what need but its an issue with guess sit awhile longer',
#  'would have loved to respond to your website until saw the really long form in business the new seats are bad',
#  'refund and flight vouchers or another flight on different airline at your expense for today hour drive is very inconvenient',
#  'then why have not received my call back its been days it an infant car seat how am supposed to go anywhere with my child',
#  'thanks again for your concern will contact customer care upon our return from australia',
#  'well sitting on the ground on time but waiting for gate again',
#  'airport snow removal method keep up the good work folks this is where cessna become',
#  'no need you guys to not over book planes it not concern ll just travel with someone else moving forward',
#  'measly certificate is not how you appreciate loyal customers after they wait hrs on the tarmac during ua',
#  'when will email address username sign on be available it been while',
#  'thank you for that am able to claim any interim expenses or is the cost of the stuff up on me',
#  'rude rude',
#  'why can get boarding pass for my austrian airlines codeshare flight rebook incls hour layover amp am stuck outside sec',
#  'received on other flights truly breaks guitars',
#  'just flew to paid from third suitcase which didn even make it on the plane besides for the impolite service',
#  'my bag is still in colo springs am disabled and have to search an unfamiliar airport and look for my bag not good outcome',
#  'shame that there no flex to tickets transfer rules even calling from neurosurgery icu isn enough',
#  'no denver said they don handle baggage that made it to colo springs they gave me an number to call no help there either',
#  'you guys need some serious training in customer service too many better options to put up with the way you guys handle ur mistakes',
#  'ord to dca',
#  'once he found out we had problem he avoided me like the plague was told we can find supervisor',
#  'zcc cancelled flight flight in advance need connect flight reschedule so the link isn helping help gf waited months to see me',
#  'will not be flying you again',
#  'in addition my first flight was delayed an hour and arriving at my destination hrs late flight',
#  'cancelled flighted our flight didn rebook us on added flight now have to drive from denver to kc thanks',
#  'your announcement for pre boarding only addresses mobility my disability requires me to travel with lot of stuff do preboard',
#  'flew united last month and the experience was awesome',
#  'our travel booked thru united group dept okc ticket agent less than willing to help with our connection in lax',
#  'upset with your disability services when told one of your employees was carrying medical equipment she was very rude',
#  'thnx for quick reply but don think you can assist our intl grp will be put to considerable inconvenience today',
#  'wont transfer flight ticket to accompany an yr old who active military mom had to have emergency brain surgery wow',
#  'weeks late flightr and still have not received my miles from the mileageplus gift card starbucks card handed over',
#  'as always hoping for improvement',
#  'not yet complained about the guy who checked my luggage in as he was throwing the bags around unfortunate coincidence hope',
#  'okc ticket agent roger mclarren sp less than helpful with our intl group travel problems can find supervisor for help',
#  'mobile apps need construction from the ground up for each os category it expensive to get right',
#  'another fail for the united ticket agents in okc less than helpful and could care less about our problems american here we come',
#  'which also had working wc in coach good thing this bird landed ahead of schedule have to use the wc stat',
#  'the os isn controlled by me but rather app is new',
#  'just sent an email to customer care telling them may have to break up with you cryingface sincerely hope they can help me',
#  'silly flying delta today your united club staff and attendants are surly and unhelpful and always seem bothered by pesky folk',
#  'what is your phone number can find who to call about flight reservation',
#  'well you can fix me missing my buddies th bday because of negligence but you can attempt to make up for it',
#  'why am to believe they will help when customer service couldn like said want number to someone who can fix what you did',
#  'they helped me at the baggage service desk said bc tsa screening was down in fll not all bags made it but bag will be in ewr',
#  'mobile boarding pass disappeared from phone while standing in line to board second time this week hmm',
#  'for the record rozana at newark was lovely and helpful',
#  'it was last night ord lga',
#  'thx for update',
#  'thank you',
#  'dm these nuts',
#  'had to explain to very over eager flight attendant trying to ask about my vision that my was not guide dog',
#  'what the point of asking for details about when you book if your flight crew doesn read them continued',
#  'tried but no one was available in bogota and everyone was rude in houston was stuck for hours because of you guys',
#  'ua las to iad mechanical problems again took off had to land for fix delayed again',
#  'despite my bag not making it to newark good informative email tracking updates help',
#  'what going on with ua outbound flight last thurs was delayed hrs how long will this delay be',
#  'ua iad to las mechanical problems switched aircraft delayed hours',
#  'crashed trying to check in',
#  'wow what deal again plus seats available easy change to make customer happy',
#  'thanks for the info already knew',
#  'airline trouble this winter amp not getting good customer service contact we negotiate resolutions for you',
#  'on to logan boarding gong show due to lax carry on enforcement bins full of coats no room for bags need better system',
#  'thank you',
#  'blackmailed me into paying extra or having my return ticket nullified in san francisco airport terrible service from rep',
# ...
#  'ua ord lhr bags are being loaded min late flight frigid air into cabin plane feels like falling apart upgrade long haul fleet',
#  'flight attendant never served me my beverage tea and not once checked up on me what gives',
#  'load balancing system apparently down major impact on all airlines flights was this',
#  'after our unscheduled refueling stop and missing connecting flights we home looking ward to our bed and big pb amp sandwich',
#  'spent hundreds to rectify the situation and you guys go quiet',
#  'ua sitting at ewr nearly an hour after sked pilot says computers down but no clue when we will leave can you help',
#  'so that it it just ends there come on traveled for literally an extra day and half because of this',
#  'made the upgrade list will fly st tomorrow for min for the first time ever raisinghands',
#  'not just refunded but for those of us who are on vacation to get free room night to make up for making us sleep in dia',
#  'thanks for the reminder it been fun ride',
#  'received my luggage that also looked to be left in the snow when arrived asking for all people to be refunded',
#  'updated aircraft has wifi and device entertainment but no outlets don get it how can charge devices',
#  'was no one between the scan and inside the plane just asked the people in line around me where the plane was going',
#  'gate changes two delays even the crew thinks the airline sucks',
#  'very frustrated and have wasted days now due to your equipment failures',
#  'computers are down but you stopped giving updates and took my flight info off the app that just ridiculous keep people updated',
#  'soooo it been days and you have offered no response so assume poor treatment by gate agents is the norm now',
#  'terrific many thanks looking forward to being back on ua tomorrow had great flight up to vancouver',
#  'calls to resulted in hrs of hold time amp day wait to check suspect code share fare nothing investigated my time wasted',
#  'it taken weeks for cust care to respond to case requesting refund for wi fi not working where can get an update',
#  'appreciate your efforts getting me home',
#  'that correct ve spent hours trying to book online only to receive an error when clicking final purchase button',
#  'today was not your finest all could have been prevented by one gate agent advising passengers',
#  'what is the real deal with the delay on flight ua from denver to vegas',
#  'ua from madrid arrived no agent mass confusion we sent to and fro by ua employees maryjo was rude and unhelpful',
#  'system failure again bad trend software projects are like flying an airplane there no such thing as an emergency takeoff',
#  'lots of reports of system failures delaying flights over the last week currently sitting on the tarmac at ogg for over an hour',
#  'rebooting chicago dispatch system need as tired of sitting on planes',
#  'despite shaky connections looks like ll get home tonight great job was touch and go for while',
#  'however is completely under your control the price was and still is displayed on',
#  'the aircraft closest to gate was for the other flight and the one closest to our gate was going to chicago',
#  'can you tell me how to file claim for clothing that had to be purchased',
#  'comically on the return flight from ase there were two united flights boarding at adjacent gates and not clear which plane to board',
#  'grk is the file reference',
#  'we would how do contact you to discuss few poor experiences with customer service but would give it shot',
#  'ua pacific rim and date night cut out not constantly or randomly but one spot repeatably',
#  'been trying since to file report',
#  'send an email about my bad experience and you send back generic response yet another reason why ll never fly with you again',
#  'my mom left her kindle on flight today burgundy case with light seat did anyone find it',
#  'here is the ticket please refund my unnecessary upgrade fee',
#  'is horrible they lost our carseat and expect us to use loner carseat safety regulations say it illegal to use used car seat',
#  'thank you',
#  'decisions decisions we love for you to try our service we offer status match too kp',
#  'need more info on that we have great amenity kits pj not included we status match aa kp',
#  'don care that link showed me wrong price on your site it your site amp responsibility to ensure correctness',
#  'do you have any flights with lie flat seating from stl to pdx around the date of march',
#  'he needs to get to home the th they are telling him it will be the th night is there compensation or anything that can be done',
#  'the baggage fee is waived for premier members please see jp what the point of membership',
#  'wonderful bag claim people finally have my bag but why did catch earlier flight original flight just landed',
#  'dmed you thank you',
#  'thanks we will be in touch',
#  'thanks to karen salisbury at iah for amazing customer service found my daughter bag lost on ua made her day',
#  'days late flightr and my bag has not left iad united is not helping at all everyone tells me different story',
#  'hi when do direct flights from houston to reno begin don see any days in march',
#  'like continental chicken feat fairs',
#  'can you assist with current flight status for flt out of dfw tomorrow at am',
#  'left my comment with customer care thanks for contacting me',
#  'how do you lose gate checked bag den to ord direct flight ugh',
#  'caught earlier flight to ord gate checked bag and you have lost it at hare original flight lands in minutes',
#  'yes thanks so much purpleheart we see you spoke with our reservations team and they have reinstated the flight thanks ey',
#  'captain on behalf of the front office welcome on board never heard that before laughed hard',
#  'can you please follow for dm on missing bag',
#  'to be clear on my luggage comment am referencing the photo attached flight to jac',
#  'these are great fares',
#  'left an item on the plane and have been calling non stop and no one has been answering can you please help',
#  'awesome ll book my next christmas vacatinn this december any other ways you want to devalue mileage plus',
#  'what good number to call to speak with someone about how you can fix what you did to people and their luggage on saturday',
#  'thank secured room for the night thx to very helpful customer service rep dorns thanked her can',
#  'where my damn bag',
#  'well someone should tell that to the employees at the denver baggage claim still no bag',
#  'greetings ua club member here any idea if can use the air canada lounge at yvr flying ua tomorrow',
#  'how is mexico not international from the us',
#  'diverted and missed our connecting flight was just told that my bag is on it way to msy if you only had people that cared',
#  'male agnt in las threatens canadian cust when cust takes pic of him at gate after agents announce can help rebook',
#  'we just want to go home tonight why did you cancelled flight the last leg of our reserv out our permission',
#  'stressed and rude agents overwhelmed by delyd flight las den yelling at several people not pretty this is',
#  'landed in boston at last night the hours of traveling was rough tho',
#  'fail you cancelled flightled our flight frm gjt and then used our reserv home to iah from sea for reflight booking problems out our permission',
#  'just sent thank rt please dm your confirmation number if reflight booking problems is needed thank you ey',
#  'has made my no fly list other airlines wait when connector late flight stuck in iah',
#  'so what the deal do provide voucher for overnight or am cozy on the floor at',
#  'also the mere fact that have to go online to issue statement vice calling and talking to some directly is one good example',
#  'thank you flew into newark from vail eagle',
#  'have weekend of dealing with your company that would say otherwise',
#  'now what flight was gone when got off plane',
#  'the proper response sorry for your wait what flight were you on so we can look into the issue that how would handle',
#  'your customer service is terrible stood inline hours no flights and hours late flightr still no bag',
#  'please upload the march on demand entertainment listing on your website airplane',
#  'so you are inadequate by accident',
#  'denver international airport',
#  'thank you for responding so quickly with helpful tool',
#  'boarding time shows min and your gate agent started at showed up at and they had to check bag',
#  'agent in las letting customers know they can help them rebook delayed flight to den',
#  'empathizes my disappointment that stclass flight nonworking entertainmnt is worth',
#  'and when that doesn work',
#  'did you have seen my message today about mcdonnell douglas dc model will hear it if you read it goodnight now',
#  'searched for mileage tickets to bom couldn find single one is saver awards see how you play earn miles but can use them',
#  'flight arrives minutes early but then have we to wait for an hour for our bags',
#  'that not the issue the fact that no one even called despite promises to confirm the bag location is',
#  'what girl gotta do to get flight name change when she bought one for mean ex boyfriend and needs girl trip stat',
#  'thank you we are signed up for notifications we shall watch and wait snowflake snowflake',
#  'still waiting to hear back my wallet was stolen from one of your planes so would appreciate resolution here',
#  'would love if someone could get me back to austin tonight and do not wish to wait til tomorrow morning',
#  'or has lost my baggage heard different things from different employees of has said nothing',
#  'cs thinks that miles can repair the damage done it will be interesting if they travel in and exp the worst flight ever',
#  'have flight out of dfw on tuesday how far in advance will you give notice if cancelled flightled',
#  'am signed up for notifications this is the first trip was not updated on not sure why this happened',
#  'thank you took care of everything and made it right that the experience used to opened the app to find flight changed',
#  'that is not in line with your responses here and now waiting until tomorrow morning because all the flights are overbooked',
#  'took the exact same aircraft in to lax days ago it fit no problem the agent today told some nonsense about policy change',
#  'your helpful agents in club helped am just out baggage fees and night of my life stop doing business with',
#  'never heard of this',
#  'doesn charge ticket change fees do they not incur the same mysterious costs that you incur',
#  'exhausted amp frustrated link to fb post abt my travel issue',
#  'was denied getting on the plane getting the chance to prove it fits not rookie read my bio',
#  'that exactly the point it fits premier access boarding group this was return ticket ve been doing this for yrs',
#  've never experienced worst customer service placing blame on codeshare partners and not assuming responsibility is unacceptable',
#  'currently on board so not now check in was terrible staff rude expensive luggage thrown around etc',
#  'fucked up then voided my ticket and kept my money not even an apology will never fly with your airline again',
#  'has the worst customer svcs this kevin rep at call center must be investigated my baggage lost and there no help but argument',
#  'should not sell tickets for on has terrible service and ua staff cannot reach silver',
#  'just got demoted from gold cuz my hubby got of the pqd tho there were enuf spent for golds discrimination angry',
#  'thank you',
#  'when will direct flights from belfast intl to newark resume from their winter break thanks',
#  'my favorite way to travel thank you',
#  'yes after this awful weather it appears can get home',
#  'yes lots you have terrible customer service at newark and despite raising complaint there we were ignored hence the tweet',
#  'lovely new plane from lga to ord but no power outlets',
#  'but if tweet the id number won that reveal my home address to anyone on the web',
#  'filed delayed bag report on saturday my flight was cancelled flightled and never went anywhere',
#  'the person is currently bettween gates and in lax',
#  'need it there before she lands so she can have the ewr baggage claim file to have it sent but the employee has not droppeditoffyet',
#  'rarely ceases to amaze for the worse hope this is the last time have to fly with you',
#  'thank you for the quick response but cannot dm you until you follow me as well',
#  'icloud it is not there yet please help',
#  'need the phone number to baggage claim in lax my mom left her phone and someone called saying they would put it there but on',
#  'did no response back',
#  'this is atrocious customer service',
#  'will not have to honor absurdly low mistake fares vía',
#  'delayed departure to check bags at gate claiming space filled and walk on to open spaces delay',
#  'you cancelled flighted our flights for no reason amp now we have been on the phone for an hour on our vacation why',
#  'that your response shaking my head back and forth with tsk you can do better from customer service to your apology',
#  'thanks it miles from rtb to europe to do multiple destination so we could stop over in us on way way back mileage diff',
#  'of course did the bag should be here by now worried',
#  'you are the worst will avoid you like the plague',
#  'is the worst airline in the world',
#  'someone needs to dm me and resolve this correctly extremely disappointed with the service received terrible management',
#  'premier gold desk changes flight waives fees gives me wrong flight now jana acosta in salt lake refuses the same service angry',
#  'will give you one thing you are consistent but unfortunately you are consistent at not doing your job well',
#  'will but right now to angry',
#  'first time flying with united also last time back to for me',
#  'used to be committed flyer until merger remember now why switched to',
#  'the least you could do is offer me ticket in coach instead of just cancelled flighting my reservation because of your glitch',
#  'saying made the flight but with poor non communication unaccounted for lost time amp lots of frustrated flyers standing around',
#  'think dm would be better',
#  'gate announcement states delay due to maintenance yet app says late flight arriving aircraft tell the truth',
#  'you are easily the worst company have ever experienced you have lost someone personal possessions amp you couldn care less',
#  'how can your app show arriving aircraft is early but departing flight is delayed due to late flight arriving aircraft',
#  'already did that at the airport and hrs late flightr its still not here you guys are really killing me today trying to stay positive',
#  'once united service levels reaches those of etihad or lets be more realistically lufthansa then ill consider it again',
#  'really someone called in sick and then someone forgot to call replacement now an hour late flight to take off',
#  'asked flight attendant what typical compensation would be amp says we might get free tv',
#  'done',
#  'thank you jh appreciate the prompt responses me and other passengers will be doing so',
#  'has been such disappointment today simply put rather unpleased with things currently flight delayed cant wait to just get home',
#  'during the same round trip my non english speaking friend was stranded twice for hours each time most staff members were rude',
#  'found group of people who actually hates people more than isis thats right united airlines',
#  'nope walked up amp down the orf terminal amp not united agent to be found showed up last minute to board us many panicked people',
#  'thank you',
#  'by the time finally get to dallas could have driven with less frustration and cheaper',
#  'trying to get to my final destination we need compensation just about hrs of personal time wasted',
#  'that guy really has no customer service clue could have spent effort clearing bins for rollerboards instead of art projects in mine',
#  'he has no priority and iove it',
#  'pleased to be premier platinum',
#  ...]

# %%
# The 'target_tweet' Data Frame is created. It contains the text of each of the tweets in the 'tweet' column 
# and its respective polarity (positive or negative). 
# This process is used to verify that the previous processes have been executed correctly. 
# Each tweet contains its respective tag -> polarity.

data_target_tweet = {'target': target, 'tweet': tweets_cleaned_2}
target_tweet = pd.DataFrame(data=data_target_tweet)
target_tweet
# Out:
#          target                                              tweet
# 0      positive                                           what say
# 1      positive  plus you have add commercial to the experience...
# 2      positive     didn today must mean need to take another trip
# 3      negative  it really aggressive to blast obnoxious entert...
# 4      negative               and it really big bad thing about it
# 5      negative  seriously would pay flight for seat that didn ...
# 6      positive  yes nearly every time fly vx this ear worm win...
# 7      positive  really missed prime opportunity for men withou...
# 8      positive                               well didn but now do
# 9      positive  it be amaze and arrive an hour early you re to...
# 10     positive  do you know that suicide be the second leading...
# 11     positive  lt pretty graphic so much good than minimal ic...
# 12     positive  this be such great deal already think about my...
# 13     positive   fly your sky again take all the away from travel
# 14     positive                                             thanks
# 15     negative                      sfo pdx schedule be still mia
# 16     positive  so excited for my first cross country flight l...
# 17     negative  flew from nyc to sfo last week and couldn full...
# 18     positive                  redheart fly smilingface thumbsup
# 19     positive  you know what would be amazingly awesome bos f...
# 20     negative  why be your first fare in may over three time ...
# 21     positive                                  love this graphic
# 22     positive  love the hipster innovation you be feel good b...
# 23     positive  will you be make bos gt la non stop permanentl...
# 24     negative  you guy mess up my seating reserve seat with m...
# 25     negative  status match program apply and it be three wee...
# 26     negative  what happen ur vegan food option at least say ...
# 27     positive  do you miss me don worry we will be together v...
# 28     negative  amaze to me that we can get any cold air from ...
# 29     positive  lax to ewr middle seat on red eye such noob ma...
# ...         ...                                                ...
# 14610  negative  understand the weather issue but you can expec...
# 14611  positive    guarantee no retribution if so be glad to share
# 14612  negative  friend be have flight cancel flightlations out...
# 14613  negative  use the call back feature with an operator reg...
# 14614  negative  need to be at work tomorrow at be therefore th...
# 14615  negative  ugh dump u in dfw no luggage then cancel fligh...
# 14616  negative  cancel flight my flight doesn send an email te...
# 14617  positive                           dming you now big thanks
# 14618  negative  be overweight so you pull dozen passenger off ...
# 14619  positive  love your company and your staff be amaze they...
# 14620  negative  wait hr for c to call me back re why flt be cx...
# 14621  negative  ve be on hold for min about my cancelled fligh...
# 14622  negative  just need place to sleep when land without acc...
# 14623  positive  love the new plane for the jfk lax run maybe o...
# 14624  negative  call me chairman or call me emerald after what...
# 14625  positive          flight be great fantastic cabin crew land
# 14626  negative  flight nyc buenos air have be delay since yest...
# 14627  negative  flight cancel flightled can go home until tomo...
# 14628  positive  thank you customer relation will review your c...
# 14629  negative  how do change my flight if the phone system ke...
# 14630  positive                                       thanks he be
# 14631  negative  thx for nothing on get u out of the country an...
# 14632  positive  george that doesn look good please follow this...
# 14633  negative  my flight be cancel flightled leaving tomorrow...
# 14634  negative                 right on cue with the delay okhand
# 14635  positive    thank you we get on different flight to chicago
# 14636  negative  leave over minute late flight no warning or co...
# 14637  positive                   please bring american airline to
# 14638  negative  you have my money you change my flight and don...
# 14639  positive  we have ppl so we need know how many seat be o...
#
# [14640 rows x 2 columns]

# %%
# The data (tweets_cleaned_2) is divided into a training set (80%) and a test set (20%).
# The TF-IDF model is created --> convert a collection of raw documents to a matrix of TF-IDF features.
# The training set and the test set are vectorized.

y= target
X_train, X_test, y_train, y_test = train_test_split(tweets_cleaned_2, y, train_size=0.8, test_size= 0.2, random_state=0)
from sklearn.feature_extraction.text import TfidfVectorizer
# Create feature vectors
vectorizer = TfidfVectorizer(min_df = 5,
                             max_df = 0.8,
                             sublinear_tf = True,
                             use_idf = True)
train_vectors = vectorizer.fit_transform(X_train)
test_vectors = vectorizer.transform(X_test)

# %%
# The SVM (Support Vector Machine) classifier is applied to train with the data from the training set. 
# Subsequently, its degree of accuracy is checked by predicting the labels of the test set

# Training the classifier. 
classifier = svm.SVC(kernel= 'linear')
classifier.fit(train_vectors, y_train)

# Testing model performance.
y_predicted = classifier.predict(test_vectors)

# %%
# The results of the SVM classifier are printed to proceed with its evaluation.

# SVM Classifier. 
print(confusion_matrix(y_test,y_predicted))  
print(classification_report(y_test, y_predicted))  
print(accuracy_score(y_test, y_predicted))
# Out:
# [[1673  197]
#  [ 263  795]]
#              precision    recall  f1-score   support
#
#    negative       0.86      0.89      0.88      1870
#    positive       0.80      0.75      0.78      1058
#
# avg / total       0.84      0.84      0.84      2928
#
# 0.842896174863388

# %%
# The graphic representation of the results of the SVM classifier is created.
# Plot --> Confusion Matrix: SVM.

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion Matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Confusion Matrix (normalized)")
    else:
        print('Confusion Matrix (no-normalized)')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="yellow" if cm[i, j] > thresh else "blue")

    plt.ylabel('Test')
    plt.xlabel('Prediction')
    plt.tight_layout()


# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_predicted)

# Plot 
plt.figure(figsize=(15, 10))
plt.subplot(221)
plot_confusion_matrix(cnf_matrix, classes=['neg', 'pos'],
                      title='Confusion Matrix (no-normalized)')
plt.subplot(222)
plot_confusion_matrix(cnf_matrix, classes=['neg', 'pos'],
                      normalize = True,
                      title='Confusion Matrix (normalized)')

plt.subplots_adjust(top=1, bottom=0.1, left=0.1, right=0.95, hspace=0.5,
                    wspace=0.3)

plt.show()
# Out:
# Confusion Matrix (no-normalized)
# [[1673  197]
#  [ 263  795]]
# Confusion Matrix (normalized)
# [[0.89465241 0.10534759]
#  [0.24858223 0.75141777]]

# %%
# The Logistic Regression classifier is applied to train with the data from the training set. 
# Subsequently, its degree of accuracy is checked by predicting the labels of the test set.

# Training the classifier 
classifier = LogisticRegression()  
classifier.fit(train_vectors, y_train) 

# Testing model performance
y_predicted=classifier.predict(test_vectors)

# %%
# The results of the Logistic Regression classifier are printed to proceed with its evaluation.
# Logistic Regression Classifier.

print(confusion_matrix(y_test,y_predicted))  
print(classification_report(y_test,y_predicted))  
print(accuracy_score(y_test, y_predicted))
# Out:
# [[1692  178]
#  [ 302  756]]
#              precision    recall  f1-score   support
#
#    negative       0.85      0.90      0.88      1870
#    positive       0.81      0.71      0.76      1058
#
# avg / total       0.83      0.84      0.83      2928
#
# 0.8360655737704918

# %%
# The graphic representation of the results of the Random Forest classifier is created
# Plot --> Confusion Matrix: Logistic Regression
cnf_matrix_lr = confusion_matrix(y_test, y_predicted)

# Plot non-normalized confusion matrix
plt.figure(figsize=(15, 10))
plt.subplot(221)
plot_confusion_matrix(cnf_matrix_lr, classes=['neg', 'pos'],
                      title='Confusion Matrix (no-normalized)')
plt.subplot(222)
plot_confusion_matrix(cnf_matrix_lr, classes=['neg',  'pos'],
                      normalize = True,
                      title='Confusion Matrix (normalized)')

plt.subplots_adjust(top=1, bottom=0.1, left=0.1, right=0.95, hspace=0.5,
                    wspace=0.3)

plt.show()
# Out:
# Confusion Matrix (no-normalized)
# [[1692  178]
#  [ 302  756]]
# Confusion Matrix (normalized)
# [[0.90481283 0.09518717]
#  [0.28544423 0.71455577]]

# %%
# The Random Forest classifier is applied to train with the data from the training set. 
# Subsequently, its degree of accuracy is checked by predicting the labels of the test set

# Training the classifier 
classifier = RandomForestClassifier(n_estimators=2000, random_state=0)  
classifier.fit(train_vectors, y_train) 

# Testing model performance
y_predicted=classifier.predict(test_vectors)

# %%
# The results of the Random Forest classifier are printed to proceed with its evaluation.

# Random Forest Classifier
print(confusion_matrix(y_test,y_predicted))  
print(classification_report(y_test,y_predicted))  
print(accuracy_score(y_test, y_predicted))
# Out:
# [[1714  156]
#  [ 407  651]]
#              precision    recall  f1-score   support
#
#    negative       0.81      0.92      0.86      1870
#    positive       0.81      0.62      0.70      1058
#
# avg / total       0.81      0.81      0.80      2928
#
# 0.8077185792349727

# %%
# The graphic representation of the results of the Random Forest classifier is created
# Plot --> Confusion Matrix: Random Forest
cnf_matrix_lr = confusion_matrix(y_test, y_predicted)

# Plot non-normalized confusion matrix
plt.figure(figsize=(15, 10))
plt.subplot(221)
plot_confusion_matrix(cnf_matrix_lr, classes=['neg', 'pos'],
                      title='Confusion Matrix (no-normalized)')
plt.subplot(222)
plot_confusion_matrix(cnf_matrix_lr, classes=['neg',  'pos'],
                      normalize = True,
                      title='Confusion Matrix (normalized)')

plt.subplots_adjust(top=1, bottom=0.1, left=0.1, right=0.95, hspace=0.5,
                    wspace=0.3)

plt.show()
# Out:
# Confusion Matrix (no-normalized)
# [[1714  156]
#  [ 407  651]]
# Confusion Matrix (normalized)
# [[0.91657754 0.08342246]
#  [0.38468809 0.61531191]]
